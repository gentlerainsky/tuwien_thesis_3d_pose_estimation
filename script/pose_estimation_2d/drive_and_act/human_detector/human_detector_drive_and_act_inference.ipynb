# %%
from modules.human_detector.main import detect_person
# datasubset = 'inner_mirror'
datasubset = 'a_column_driver'
detect_person(
    config_path='./modules/human_detector/config/faster_rcnn.py',
    # pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
    #     "faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth",
    pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
        "faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth",
    checkpoint_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
        "faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth",
    dataset_root_path=f'/root/data/processed/drive_and_act/{datasubset}',
    device='cuda:0',
    working_directory=f'./mmengine_workdir/human_detector_drive_and_act/{datasubset}',
    log_level='INFO'
)
# Out:
# 01/29 17:25:42 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1862383602
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1862383602
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 01/29 17:25:42 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[
#             103.53,
#             116.28,
#             123.675,
#         ],
#         std=[
#             1.0,
#             1.0,
#             1.0,
#         ],
#         bgr_to_rgb=False,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[
#                 8,
#             ],
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=1,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)),
#     _scope_='mmdet')
# dataset_type = 'CocoDataset'
# data_root = '/root/data/processed/drive_and_act/a_column_driver'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='RandomChoiceResize',
#         scales=[
#             (
#                 1333,
#                 640,
#             ),
#             (
#                 1333,
#                 672,
#             ),
#             (
#                 1333,
#                 704,
#             ),
#             (
#                 1333,
#                 736,
#             ),
#             (
#                 1333,
#                 768,
#             ),
#             (
#                 1333,
#                 800,
#             ),
#         ],
#         keep_ratio=True,
#         _scope_='mmdet'),
#     dict(type='RandomFlip', prob=0.5, _scope_='mmdet'),
#     dict(type='PackDetInputs', _scope_='mmdet'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='PackDetInputs',
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         _scope_='mmdet'),
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmdet'),
#     batch_sampler=dict(type='AspectRatioBatchSampler', _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/drive_and_act/a_column_driver',
#         ann_file='annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='RandomChoiceResize',
#                 scales=[
#                     (
#                         1333,
#                         640,
#                     ),
#                     (
#                         1333,
#                         672,
#                     ),
#                     (
#                         1333,
#                         704,
#                     ),
#                     (
#                         1333,
#                         736,
#                     ),
#                     (
#                         1333,
#                         768,
#                     ),
#                     (
#                         1333,
#                         800,
#                     ),
#                 ],
#                 keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs'),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/drive_and_act/a_column_driver',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/drive_and_act/a_column_driver',
#         ann_file='annotations/person_keypoints_test.json',
#         data_prefix=dict(img='images/test/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/drive_and_act/a_column_driver/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/drive_and_act/a_column_driver/annotations/person_keypoints_test.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# train_cfg = dict(
#     type='EpochBasedTrainLoop', max_epochs=1, val_interval=1, _scope_='mmdet')
# val_cfg = dict(type='ValLoop', _scope_='mmdet')
# test_cfg = dict(type='TestLoop', _scope_='mmdet')
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.001,
#         by_epoch=False,
#         begin=0,
#         end=500,
#         _scope_='mmdet'),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[
#             8,
#             11,
#         ],
#         gamma=0.1,
#         _scope_='mmdet'),
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     _scope_='mmdet')
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmdet'),
#     logger=dict(type='LoggerHook', interval=500, _scope_='mmdet'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmdet'),
#     checkpoint=dict(type='CheckpointHook', interval=1, _scope_='mmdet'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmdet'),
#     visualization=dict(type='DetVisualizationHook', _scope_='mmdet'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmdet'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmdet')
# log_processor = dict(
#     type='LogProcessor', window_size=50, by_epoch=True, _scope_='mmdet')
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth'
# resume = False
# metainfo = dict(
#     classes=('person', ), palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#     ])
# work_dir = './mmengine_workdir/human_detector_drive_and_act/a_column_driver'
# wandb: Currently logged in as: gentlerainsky. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/workspace/mmengine_workdir/human_detector_drive_and_act/a_column_driver/20240129_172541/vis_data/wandb/run-20240129_172544-46wvniiu</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/46wvniiu' target="_blank">faithful-snow-118</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/46wvniiu' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/46wvniiu</a>
# 01/29 17:25:50 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 01/29 17:25:50 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 01/29 17:25:50 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 	image_set = train, start at = 2024-01-29 17:25:51.131927
# /root/data/processed/drive_and_act/a_column_driver/images/train/32328.jpg has mask with 0.4651579260826111
# /root/data/processed/drive_and_act/a_column_driver/images/train/3254.jpg has mask with 0.44954192638397217
# 		time = 2024-01-29 17:26:23.411112
# 			progress = 500/40159 = 0.0125
# /root/data/processed/drive_and_act/a_column_driver/images/train/3250.jpg has mask with 0.4306797385215759
# 		time = 2024-01-29 17:26:55.723213
# 			progress = 1000/40159 = 0.0249
# /root/data/processed/drive_and_act/a_column_driver/images/train/2299.jpg has mask with 0.2949662506580353
# /root/data/processed/drive_and_act/a_column_driver/images/train/3294.jpg has mask with 0.4583098888397217
# 		time = 2024-01-29 17:27:28.535263
# 			progress = 1500/40159 = 0.0374
# 		time = 2024-01-29 17:28:01.264638
# 			progress = 2000/40159 = 0.0498
# 		time = 2024-01-29 17:28:35.044498
# 			progress = 2500/40159 = 0.0623
# /root/data/processed/drive_and_act/a_column_driver/images/train/5037.jpg has mask with 0.45283642411231995
# 		time = 2024-01-29 17:29:09.082277
# 			progress = 3000/40159 = 0.0747
# 		time = 2024-01-29 17:29:43.018308
# 			progress = 3500/40159 = 0.0872
# 		time = 2024-01-29 17:30:16.984275
# 			progress = 4000/40159 = 0.0996
# /root/data/processed/drive_and_act/a_column_driver/images/train/32330.jpg has mask with 0.45202144980430603
# 		time = 2024-01-29 17:30:50.946169
# 			progress = 4500/40159 = 0.1121
# 		time = 2024-01-29 17:31:25.150592
# 			progress = 5000/40159 = 0.1245
# 		time = 2024-01-29 17:31:59.057361
# 			progress = 5500/40159 = 0.1370
# /root/data/processed/drive_and_act/a_column_driver/images/train/21841.jpg has mask with 0.27617812156677246
# 		time = 2024-01-29 17:32:32.931161
# 			progress = 6000/40159 = 0.1494
# /root/data/processed/drive_and_act/a_column_driver/images/train/24940.jpg has mask with 0.4952000379562378
# /root/data/processed/drive_and_act/a_column_driver/images/train/932.jpg has mask with 0.4315115213394165
# 		time = 2024-01-29 17:33:06.950662
# 			progress = 6500/40159 = 0.1619
# /root/data/processed/drive_and_act/a_column_driver/images/train/557.jpg has mask with 0.42009714245796204
# /root/data/processed/drive_and_act/a_column_driver/images/train/933.jpg has mask with 0.47457191348075867
# 		time = 2024-01-29 17:33:40.822594
# 			progress = 7000/40159 = 0.1743
# /root/data/processed/drive_and_act/a_column_driver/images/train/31800.jpg has mask with 0.365371972322464
# 		time = 2024-01-29 17:34:15.473251
# 			progress = 7500/40159 = 0.1868
# /root/data/processed/drive_and_act/a_column_driver/images/train/5590.jpg has mask with 0.3733186423778534
# 		time = 2024-01-29 17:34:49.561446
# 			progress = 8000/40159 = 0.1992
# /root/data/processed/drive_and_act/a_column_driver/images/train/3296.jpg has mask with 0.4647458791732788
# 		time = 2024-01-29 17:35:23.233955
# 			progress = 8500/40159 = 0.2117
# /root/data/processed/drive_and_act/a_column_driver/images/train/8838.jpg has mask with 0.48440876603126526
# /root/data/processed/drive_and_act/a_column_driver/images/train/35584.jpg has mask with 0.4568532109260559
# /root/data/processed/drive_and_act/a_column_driver/images/train/31421.jpg has mask with 0.43409809470176697
# 		time = 2024-01-29 17:35:57.728330
# 			progress = 9000/40159 = 0.2241
# /root/data/processed/drive_and_act/a_column_driver/images/train/3297.jpg has mask with 0.4692569971084595
# 		time = 2024-01-29 17:36:31.508943
# 			progress = 9500/40159 = 0.2366
# /root/data/processed/drive_and_act/a_column_driver/images/train/35580.jpg has mask with 0.34925392270088196
# /root/data/processed/drive_and_act/a_column_driver/images/train/25561.jpg has mask with 0.39925310015678406
# problematic images = /root/data/processed/drive_and_act/a_column_driver/images/train/4462.jpg
# 		time = 2024-01-29 17:37:05.641562
# 			progress = 10000/40159 = 0.2490
# /root/data/processed/drive_and_act/a_column_driver/images/train/22339.jpg has mask with 0.1839328110218048
# 		time = 2024-01-29 17:37:39.443157
# 			progress = 10500/40159 = 0.2615
# 		time = 2024-01-29 17:38:14.204933
# 			progress = 11000/40159 = 0.2739
# problematic images = /root/data/processed/drive_and_act/a_column_driver/images/train/37013.jpg
# 		time = 2024-01-29 17:38:48.437167
# 			progress = 11500/40159 = 0.2864
# /root/data/processed/drive_and_act/a_column_driver/images/train/3277.jpg has mask with 0.2556406259536743
# 		time = 2024-01-29 17:39:23.200807
# 			progress = 12000/40159 = 0.2988
# 		time = 2024-01-29 17:39:57.462933
# 			progress = 12500/40159 = 0.3113
# /root/data/processed/drive_and_act/a_column_driver/images/train/35587.jpg has mask with 0.30422428250312805
# 		time = 2024-01-29 17:40:31.014338
# 			progress = 13000/40159 = 0.3237
# /root/data/processed/drive_and_act/a_column_driver/images/train/35576.jpg has mask with 0.3708495795726776
# /root/data/processed/drive_and_act/a_column_driver/images/train/3233.jpg has mask with 0.4684963524341583
# 		time = 2024-01-29 17:41:05.136737
# 			progress = 13500/40159 = 0.3362
# /root/data/processed/drive_and_act/a_column_driver/images/train/35586.jpg has mask with 0.489522248506546
# 		time = 2024-01-29 17:41:39.293776
# 			progress = 14000/40159 = 0.3486
# /root/data/processed/drive_and_act/a_column_driver/images/train/35583.jpg has mask with 0.43519559502601624
# 		time = 2024-01-29 17:42:13.681077
# 			progress = 14500/40159 = 0.3611
# /root/data/processed/drive_and_act/a_column_driver/images/train/35585.jpg has mask with 0.4647887051105499
# /root/data/processed/drive_and_act/a_column_driver/images/train/3264.jpg has mask with 0.23571592569351196
# /root/data/processed/drive_and_act/a_column_driver/images/train/8854.jpg has mask with 0.4847138822078705
# 		time = 2024-01-29 17:42:48.255555
# 			progress = 15000/40159 = 0.3735
# /root/data/processed/drive_and_act/a_column_driver/images/train/3842.jpg has mask with 0.4092612862586975
# 		time = 2024-01-29 17:43:22.382460
# 			progress = 15500/40159 = 0.3860
# 		time = 2024-01-29 17:43:56.092911
# 			progress = 16000/40159 = 0.3984
# 		time = 2024-01-29 17:44:29.917388
# 			progress = 16500/40159 = 0.4109
# /root/data/processed/drive_and_act/a_column_driver/images/train/3278.jpg has mask with 0.26170244812965393
# /root/data/processed/drive_and_act/a_column_driver/images/train/3265.jpg has mask with 0.48215940594673157
# 		time = 2024-01-29 17:45:03.549862
# 			progress = 17000/40159 = 0.4233
# 		time = 2024-01-29 17:45:37.327407
# 			progress = 17500/40159 = 0.4358
# 		time = 2024-01-29 17:46:11.132686
# 			progress = 18000/40159 = 0.4482
# /root/data/processed/drive_and_act/a_column_driver/images/train/11472.jpg has mask with 0.48320823907852173
# /root/data/processed/drive_and_act/a_column_driver/images/train/35581.jpg has mask with 0.391686350107193
# 		time = 2024-01-29 17:46:44.979025
# 			progress = 18500/40159 = 0.4607
# /root/data/processed/drive_and_act/a_column_driver/images/train/3301.jpg has mask with 0.34607383608818054
# 		time = 2024-01-29 17:47:18.821729
# 			progress = 19000/40159 = 0.4731
# 		time = 2024-01-29 17:47:53.312355
# 			progress = 19500/40159 = 0.4856
# /root/data/processed/drive_and_act/a_column_driver/images/train/3249.jpg has mask with 0.48116761445999146
# 		time = 2024-01-29 17:48:27.295787
# 			progress = 20000/40159 = 0.4980
# 		time = 2024-01-29 17:49:01.020151
# 			progress = 20500/40159 = 0.5105
# /root/data/processed/drive_and_act/a_column_driver/images/train/14039.jpg has mask with 0.3600897789001465
# /root/data/processed/drive_and_act/a_column_driver/images/train/36192.jpg has mask with 0.41319164633750916
# 		time = 2024-01-29 17:49:34.749663
# 			progress = 21000/40159 = 0.5229
# /root/data/processed/drive_and_act/a_column_driver/images/train/9417.jpg has mask with 0.3762015104293823
# 		time = 2024-01-29 17:50:08.702059
# 			progress = 21500/40159 = 0.5354
# /root/data/processed/drive_and_act/a_column_driver/images/train/5767.jpg has mask with 0.31419122219085693
# 		time = 2024-01-29 17:50:42.628990
# 			progress = 22000/40159 = 0.5478
# /root/data/processed/drive_and_act/a_column_driver/images/train/34219.jpg has mask with 0.3998459279537201
# 		time = 2024-01-29 17:51:16.460993
# 			progress = 22500/40159 = 0.5603
# /root/data/processed/drive_and_act/a_column_driver/images/train/33533.jpg has mask with 0.37188756465911865
# /root/data/processed/drive_and_act/a_column_driver/images/train/3266.jpg has mask with 0.292732834815979
# 		time = 2024-01-29 17:51:50.686586
# 			progress = 23000/40159 = 0.5727
# 		time = 2024-01-29 17:52:24.224107
# 			progress = 23500/40159 = 0.5852
# /root/data/processed/drive_and_act/a_column_driver/images/train/29734.jpg has mask with 0.39662355184555054
# 		time = 2024-01-29 17:52:57.947061
# 			progress = 24000/40159 = 0.5976
# /root/data/processed/drive_and_act/a_column_driver/images/train/26872.jpg has mask with 0.4497831165790558
# 		time = 2024-01-29 17:53:31.946352
# 			progress = 24500/40159 = 0.6101
# 		time = 2024-01-29 17:54:06.059236
# 			progress = 25000/40159 = 0.6225
# /root/data/processed/drive_and_act/a_column_driver/images/train/33014.jpg has mask with 0.3580973446369171
# 		time = 2024-01-29 17:54:39.722064
# 			progress = 25500/40159 = 0.6350
# 		time = 2024-01-29 17:55:13.675776
# 			progress = 26000/40159 = 0.6474
# /root/data/processed/drive_and_act/a_column_driver/images/train/3279.jpg has mask with 0.4425392746925354
# 		time = 2024-01-29 17:55:47.975838
# 			progress = 26500/40159 = 0.6599
# /root/data/processed/drive_and_act/a_column_driver/images/train/3300.jpg has mask with 0.36165177822113037
# 		time = 2024-01-29 17:56:21.715259
# 			progress = 27000/40159 = 0.6723
# /root/data/processed/drive_and_act/a_column_driver/images/train/537.jpg has mask with 0.44220787286758423
# /root/data/processed/drive_and_act/a_column_driver/images/train/35578.jpg has mask with 0.3657287657260895
# 		time = 2024-01-29 17:56:55.810733
# 			progress = 27500/40159 = 0.6848
# 		time = 2024-01-29 17:57:29.503747
# 			progress = 28000/40159 = 0.6972
# /root/data/processed/drive_and_act/a_column_driver/images/train/3232.jpg has mask with 0.33946532011032104
# 		time = 2024-01-29 17:58:02.973580
# 			progress = 28500/40159 = 0.7097
# 		time = 2024-01-29 17:58:36.979131
# 			progress = 29000/40159 = 0.7221
# /root/data/processed/drive_and_act/a_column_driver/images/train/32717.jpg has mask with 0.31412941217422485
# 		time = 2024-01-29 17:59:11.105996
# 			progress = 29500/40159 = 0.7346
# 		time = 2024-01-29 17:59:45.052486
# 			progress = 30000/40159 = 0.7470
# 		time = 2024-01-29 18:00:18.668491
# 			progress = 30500/40159 = 0.7595
# 		time = 2024-01-29 18:00:52.599428
# 			progress = 31000/40159 = 0.7719
# 		time = 2024-01-29 18:01:26.557510
# 			progress = 31500/40159 = 0.7844
# /root/data/processed/drive_and_act/a_column_driver/images/train/20069.jpg has mask with 0.4945606589317322
# 		time = 2024-01-29 18:02:01.096364
# 			progress = 32000/40159 = 0.7968
# /root/data/processed/drive_and_act/a_column_driver/images/train/9433.jpg has mask with 0.4750511348247528
# 		time = 2024-01-29 18:02:35.756585
# 			progress = 32500/40159 = 0.8093
# 		time = 2024-01-29 18:03:10.489101
# 			progress = 33000/40159 = 0.8217
# 		time = 2024-01-29 18:03:45.156978
# 			progress = 33500/40159 = 0.8342
# 		time = 2024-01-29 18:04:19.909465
# 			progress = 34000/40159 = 0.8466
# 		time = 2024-01-29 18:04:54.513185
# 			progress = 34500/40159 = 0.8591
# /root/data/processed/drive_and_act/a_column_driver/images/train/3299.jpg has mask with 0.32495030760765076
# /root/data/processed/drive_and_act/a_column_driver/images/train/8726.jpg has mask with 0.453102171421051
# 		time = 2024-01-29 18:05:30.013210
# 			progress = 35000/40159 = 0.8715
# 		time = 2024-01-29 18:06:04.281330
# 			progress = 35500/40159 = 0.8840
# /root/data/processed/drive_and_act/a_column_driver/images/train/35579.jpg has mask with 0.3659268617630005
# 		time = 2024-01-29 18:06:38.727457
# 			progress = 36000/40159 = 0.8964
# /root/data/processed/drive_and_act/a_column_driver/images/train/11137.jpg has mask with 0.4970804750919342
# 		time = 2024-01-29 18:07:13.269752
# 			progress = 36500/40159 = 0.9089
# 		time = 2024-01-29 18:07:47.957824
# 			progress = 37000/40159 = 0.9213
# 		time = 2024-01-29 18:08:22.243806
# 			progress = 37500/40159 = 0.9338
# /root/data/processed/drive_and_act/a_column_driver/images/train/4957.jpg has mask with 0.4288880527019501
# 		time = 2024-01-29 18:08:56.584639
# 			progress = 38000/40159 = 0.9462
# /root/data/processed/drive_and_act/a_column_driver/images/train/26514.jpg has mask with 0.4983880817890167
# 		time = 2024-01-29 18:09:30.989022
# 			progress = 38500/40159 = 0.9587
# 		time = 2024-01-29 18:10:05.532242
# 			progress = 39000/40159 = 0.9711
# 		time = 2024-01-29 18:10:40.403845
# 			progress = 39500/40159 = 0.9836
# 		time = 2024-01-29 18:11:14.708376
# 			progress = 40000/40159 = 0.9960
# 		image_set = train, finish at = 2024-01-29 18:11:25.605671
# 		time spend = 45.57 mins (2734.47 secs), fps = 14.6858 fps
# created a folder at /root/data/processed/drive_and_act/a_column_driver/person_detection_results.
# 	image_set = val, start at = 2024-01-29 18:11:25.883343
# 		image_set = val, finish at = 2024-01-29 18:11:25.883698
# 		time spend = 0.00 mins (0.00 secs), fps = 2840.9091 fps
# 	image_set = test, start at = 2024-01-29 18:11:25.883963
# 		image_set = test, finish at = 2024-01-29 18:11:25.884052
# 		time spend = 0.00 mins (0.00 secs), fps = 11494.2529 fps
