# %%
from modules.human_detector.main import detect_person

detect_person(
    config_path='./modules/human_detector/config/faster_rcnn.py',
    # pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
    #     "faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth",
    pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
        "faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth",
    checkpoint_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
        "faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth",
    dataset_root_path='/root/data/processed/drive_and_act/',
    device='cuda:0',
    working_directory='./mmengine_workdir/human_detector_drive_and_act',
    log_level='INFO'
)
# Out:
# 01/09 20:28:34 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 384863292
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 384863292
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 01/09 20:28:35 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[
#             103.53,
#             116.28,
#             123.675,
#         ],
#         std=[
#             1.0,
#             1.0,
#             1.0,
#         ],
#         bgr_to_rgb=False,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[
#                 8,
#             ],
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=1,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)),
#     _scope_='mmdet')
# dataset_type = 'CocoDataset'
# data_root = '/root/data/processed/drive_and_act'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='RandomChoiceResize',
#         scales=[
#             (
#                 1333,
#                 640,
#             ),
#             (
#                 1333,
#                 672,
#             ),
#             (
#                 1333,
#                 704,
#             ),
#             (
#                 1333,
#                 736,
#             ),
#             (
#                 1333,
#                 768,
#             ),
#             (
#                 1333,
#                 800,
#             ),
#         ],
#         keep_ratio=True,
#         _scope_='mmdet'),
#     dict(type='RandomFlip', prob=0.5, _scope_='mmdet'),
#     dict(type='PackDetInputs', _scope_='mmdet'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='PackDetInputs',
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         _scope_='mmdet'),
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmdet'),
#     batch_sampler=dict(type='AspectRatioBatchSampler', _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/drive_and_act',
#         ann_file='annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='RandomChoiceResize',
#                 scales=[
#                     (
#                         1333,
#                         640,
#                     ),
#                     (
#                         1333,
#                         672,
#                     ),
#                     (
#                         1333,
#                         704,
#                     ),
#                     (
#                         1333,
#                         736,
#                     ),
#                     (
#                         1333,
#                         768,
#                     ),
#                     (
#                         1333,
#                         800,
#                     ),
#                 ],
#                 keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs'),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/drive_and_act',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/drive_and_act',
#         ann_file='annotations/person_keypoints_test.json',
#         data_prefix=dict(img='images/test/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/drive_and_act/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/drive_and_act/annotations/person_keypoints_test.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# train_cfg = dict(
#     type='EpochBasedTrainLoop', max_epochs=1, val_interval=1, _scope_='mmdet')
# val_cfg = dict(type='ValLoop', _scope_='mmdet')
# test_cfg = dict(type='TestLoop', _scope_='mmdet')
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.001,
#         by_epoch=False,
#         begin=0,
#         end=500,
#         _scope_='mmdet'),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[
#             8,
#             11,
#         ],
#         gamma=0.1,
#         _scope_='mmdet'),
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     _scope_='mmdet')
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmdet'),
#     logger=dict(type='LoggerHook', interval=500, _scope_='mmdet'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmdet'),
#     checkpoint=dict(type='CheckpointHook', interval=1, _scope_='mmdet'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmdet'),
#     visualization=dict(type='DetVisualizationHook', _scope_='mmdet'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmdet'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmdet')
# log_processor = dict(
#     type='LogProcessor', window_size=50, by_epoch=True, _scope_='mmdet')
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth'
# resume = False
# metainfo = dict(
#     classes=('person', ), palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#     ])
# work_dir = './mmengine_workdir/human_detector_drive_and_act'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/workspace/mmengine_workdir/human_detector_drive_and_act/20240109_202834/vis_data/wandb/run-20240109_202922-x57zobgd</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/x57zobgd' target="_blank">leafy-hill-109</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/x57zobgd' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/x57zobgd</a>
# 01/09 20:29:30 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 01/09 20:29:30 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# Downloading: "https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth" to /root/.cache/torch/hub/checkpoints/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 01/09 20:29:42 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 	image_set = train, start at = 2024-01-09 20:29:42.691325
# /root/data/processed/drive_and_act/images/train/16794.jpg has mask with 0.3602716028690338
# /root/data/processed/drive_and_act/images/train/34770.jpg has mask with 0.4764999747276306
# /root/data/processed/drive_and_act/images/train/4449.jpg has mask with 0.28895023465156555
# 		time = 2024-01-09 20:30:17.195965
# 			progress = 500/40153 = 0.0125
# /root/data/processed/drive_and_act/images/train/31612.jpg has mask with 0.48930999636650085
# /root/data/processed/drive_and_act/images/train/21056.jpg has mask with 0.289980411529541
# problematic images = /root/data/processed/drive_and_act/images/train/17259.jpg
# 		time = 2024-01-09 20:30:50.295044
# 			progress = 1000/40153 = 0.0249
# /root/data/processed/drive_and_act/images/train/5591.jpg has mask with 0.3080006241798401
# /root/data/processed/drive_and_act/images/train/5618.jpg has mask with 0.38000065088272095
# 		time = 2024-01-09 20:31:25.493169
# 			progress = 1500/40153 = 0.0374
# /root/data/processed/drive_and_act/images/train/5627.jpg has mask with 0.38548558950424194
# 		time = 2024-01-09 20:32:01.218801
# 			progress = 2000/40153 = 0.0498
# /root/data/processed/drive_and_act/images/train/8106.jpg has mask with 0.3856286406517029
# /root/data/processed/drive_and_act/images/train/5878.jpg has mask with 0.30868619680404663
# 		time = 2024-01-09 20:32:36.274969
# 			progress = 2500/40153 = 0.0623
# /root/data/processed/drive_and_act/images/train/5593.jpg has mask with 0.4034499228000641
# 		time = 2024-01-09 20:33:10.322954
# 			progress = 3000/40153 = 0.0747
# /root/data/processed/drive_and_act/images/train/5629.jpg has mask with 0.30335378646850586
# /root/data/processed/drive_and_act/images/train/33525.jpg has mask with 0.22854715585708618
# /root/data/processed/drive_and_act/images/train/3866.jpg has mask with 0.4957968294620514
# /root/data/processed/drive_and_act/images/train/5920.jpg has mask with 0.41853415966033936
# 		time = 2024-01-09 20:33:44.780061
# 			progress = 3500/40153 = 0.0872
# /root/data/processed/drive_and_act/images/train/5869.jpg has mask with 0.31521424651145935
# problematic images = /root/data/processed/drive_and_act/images/train/33527.jpg
# 		time = 2024-01-09 20:34:20.358389
# 			progress = 4000/40153 = 0.0996
# /root/data/processed/drive_and_act/images/train/5600.jpg has mask with 0.30651506781578064
# 		time = 2024-01-09 20:34:57.309341
# 			progress = 4500/40153 = 0.1121
# 		time = 2024-01-09 20:35:34.890379
# 			progress = 5000/40153 = 0.1245
# /root/data/processed/drive_and_act/images/train/8254.jpg has mask with 0.3793131709098816
# 		time = 2024-01-09 20:36:11.773727
# 			progress = 5500/40153 = 0.1370
# /root/data/processed/drive_and_act/images/train/5766.jpg has mask with 0.3844313323497772
# /root/data/processed/drive_and_act/images/train/31726.jpg has mask with 0.43780606985092163
# /root/data/processed/drive_and_act/images/train/5596.jpg has mask with 0.441266804933548
# 		time = 2024-01-09 20:36:48.759163
# 			progress = 6000/40153 = 0.1494
# /root/data/processed/drive_and_act/images/train/15794.jpg has mask with 0.11394653469324112
# /root/data/processed/drive_and_act/images/train/12057.jpg has mask with 0.36584925651550293
# 		time = 2024-01-09 20:37:26.067459
# 			progress = 6500/40153 = 0.1619
# /root/data/processed/drive_and_act/images/train/31687.jpg has mask with 0.378833144903183
# /root/data/processed/drive_and_act/images/train/5619.jpg has mask with 0.3822842836380005
# /root/data/processed/drive_and_act/images/train/12109.jpg has mask with 0.4242633581161499
# /root/data/processed/drive_and_act/images/train/14446.jpg has mask with 0.18138249218463898
# /root/data/processed/drive_and_act/images/train/5594.jpg has mask with 0.36853283643722534
# /root/data/processed/drive_and_act/images/train/5341.jpg has mask with 0.46047070622444153
# /root/data/processed/drive_and_act/images/train/7895.jpg has mask with 0.08874818682670593
# 		time = 2024-01-09 20:38:01.227282
# 			progress = 7000/40153 = 0.1743
# /root/data/processed/drive_and_act/images/train/31614.jpg has mask with 0.36354756355285645
# /root/data/processed/drive_and_act/images/train/5632.jpg has mask with 0.49006620049476624
# /root/data/processed/drive_and_act/images/train/33870.jpg has mask with 0.4038737416267395
# 		time = 2024-01-09 20:38:37.042021
# 			progress = 7500/40153 = 0.1868
# /root/data/processed/drive_and_act/images/train/9293.jpg has mask with 0.1276681274175644
# /root/data/processed/drive_and_act/images/train/5595.jpg has mask with 0.3965916633605957
# /root/data/processed/drive_and_act/images/train/11572.jpg has mask with 0.12773916125297546
# /root/data/processed/drive_and_act/images/train/5864.jpg has mask with 0.2728041410446167
# /root/data/processed/drive_and_act/images/train/31920.jpg has mask with 0.47212669253349304
# /root/data/processed/drive_and_act/images/train/4113.jpg has mask with 0.35886895656585693
# /root/data/processed/drive_and_act/images/train/5867.jpg has mask with 0.47688621282577515
# /root/data/processed/drive_and_act/images/train/12104.jpg has mask with 0.33628642559051514
# 		time = 2024-01-09 20:39:13.999605
# 			progress = 8000/40153 = 0.1992
# /root/data/processed/drive_and_act/images/train/3865.jpg has mask with 0.4986012578010559
# /root/data/processed/drive_and_act/images/train/2497.jpg has mask with 0.4398873448371887
# /root/data/processed/drive_and_act/images/train/9516.jpg has mask with 0.3975454270839691
# /root/data/processed/drive_and_act/images/train/5622.jpg has mask with 0.48438143730163574
# /root/data/processed/drive_and_act/images/train/899.jpg has mask with 0.3734976053237915
# 		time = 2024-01-09 20:39:49.552721
# 			progress = 8500/40153 = 0.2117
# /root/data/processed/drive_and_act/images/train/5621.jpg has mask with 0.4415089190006256
# /root/data/processed/drive_and_act/images/train/34773.jpg has mask with 0.06611941009759903
# 		time = 2024-01-09 20:40:23.978063
# 			progress = 9000/40153 = 0.2241
# /root/data/processed/drive_and_act/images/train/16420.jpg has mask with 0.43820348381996155
# /root/data/processed/drive_and_act/images/train/30990.jpg has mask with 0.4905075132846832
# /root/data/processed/drive_and_act/images/train/5581.jpg has mask with 0.4016977846622467
# 		time = 2024-01-09 20:40:59.412801
# 			progress = 9500/40153 = 0.2366
# /root/data/processed/drive_and_act/images/train/5641.jpg has mask with 0.4392876625061035
# 		time = 2024-01-09 20:41:35.646017
# 			progress = 10000/40153 = 0.2490
# /root/data/processed/drive_and_act/images/train/5639.jpg has mask with 0.22323556244373322
# /root/data/processed/drive_and_act/images/train/5605.jpg has mask with 0.40493208169937134
# /root/data/processed/drive_and_act/images/train/6285.jpg has mask with 0.46497905254364014
# 		time = 2024-01-09 20:42:10.280740
# 			progress = 10500/40153 = 0.2615
# /root/data/processed/drive_and_act/images/train/5631.jpg has mask with 0.39401775598526
# /root/data/processed/drive_and_act/images/train/16436.jpg has mask with 0.37610799074172974
# /root/data/processed/drive_and_act/images/train/31561.jpg has mask with 0.3812403678894043
# /root/data/processed/drive_and_act/images/train/5592.jpg has mask with 0.4690916836261749
# 		time = 2024-01-09 20:42:45.082534
# 			progress = 11000/40153 = 0.2740
# /root/data/processed/drive_and_act/images/train/5597.jpg has mask with 0.39726224541664124
# 		time = 2024-01-09 20:43:20.113064
# 			progress = 11500/40153 = 0.2864
# /root/data/processed/drive_and_act/images/train/32200.jpg has mask with 0.48932763934135437
# /root/data/processed/drive_and_act/images/train/7911.jpg has mask with 0.3107594847679138
# /root/data/processed/drive_and_act/images/train/5137.jpg has mask with 0.49995020031929016
# /root/data/processed/drive_and_act/images/train/12038.jpg has mask with 0.45711326599121094
# /root/data/processed/drive_and_act/images/train/12058.jpg has mask with 0.49960458278656006
# 		time = 2024-01-09 20:43:54.764829
# 			progress = 12000/40153 = 0.2989
# /root/data/processed/drive_and_act/images/train/5671.jpg has mask with 0.4584687650203705
# 		time = 2024-01-09 20:44:29.622949
# 			progress = 12500/40153 = 0.3113
# /root/data/processed/drive_and_act/images/train/25334.jpg has mask with 0.09599097818136215
# /root/data/processed/drive_and_act/images/train/11570.jpg has mask with 0.3810022175312042
# 		time = 2024-01-09 20:45:04.361923
# 			progress = 13000/40153 = 0.3238
# /root/data/processed/drive_and_act/images/train/21269.jpg has mask with 0.4911636710166931
# /root/data/processed/drive_and_act/images/train/23945.jpg has mask with 0.41600269079208374
# 		time = 2024-01-09 20:45:39.736395
# 			progress = 13500/40153 = 0.3362
# /root/data/processed/drive_and_act/images/train/21057.jpg has mask with 0.29856032133102417
# /root/data/processed/drive_and_act/images/train/27461.jpg has mask with 0.48307231068611145
# /root/data/processed/drive_and_act/images/train/5653.jpg has mask with 0.49100571870803833
# /root/data/processed/drive_and_act/images/train/30628.jpg has mask with 0.49506184458732605
# /root/data/processed/drive_and_act/images/train/30959.jpg has mask with 0.37438639998435974
# 		time = 2024-01-09 20:46:14.261256
# 			progress = 14000/40153 = 0.3487
# 		time = 2024-01-09 20:46:49.070981
# 			progress = 14500/40153 = 0.3611
# /root/data/processed/drive_and_act/images/train/5324.jpg has mask with 0.471593976020813
# /root/data/processed/drive_and_act/images/train/39388.jpg has mask with 0.474091112613678
# /root/data/processed/drive_and_act/images/train/12039.jpg has mask with 0.49273329973220825
# 		time = 2024-01-09 20:47:23.759008
# 			progress = 15000/40153 = 0.3736
# /root/data/processed/drive_and_act/images/train/31609.jpg has mask with 0.4391474723815918
# 		time = 2024-01-09 20:47:58.727752
# 			progress = 15500/40153 = 0.3860
# /root/data/processed/drive_and_act/images/train/5611.jpg has mask with 0.3115842640399933
# /root/data/processed/drive_and_act/images/train/9297.jpg has mask with 0.45611539483070374
# /root/data/processed/drive_and_act/images/train/16165.jpg has mask with 0.37740710377693176
# 		time = 2024-01-09 20:48:33.881125
# 			progress = 16000/40153 = 0.3985
# /root/data/processed/drive_and_act/images/train/15791.jpg has mask with 0.3015156686306
# /root/data/processed/drive_and_act/images/train/31610.jpg has mask with 0.3504568934440613
# 		time = 2024-01-09 20:49:08.558402
# 			progress = 16500/40153 = 0.4109
# /root/data/processed/drive_and_act/images/train/5819.jpg has mask with 0.46469950675964355
# /root/data/processed/drive_and_act/images/train/5640.jpg has mask with 0.4159100651741028
# 		time = 2024-01-09 20:49:41.870370
# 			progress = 17000/40153 = 0.4234
# /root/data/processed/drive_and_act/images/train/16250.jpg has mask with 0.34695571660995483
# /root/data/processed/drive_and_act/images/train/12086.jpg has mask with 0.3848165273666382
# 		time = 2024-01-09 20:50:14.370872
# 			progress = 17500/40153 = 0.4358
# /root/data/processed/drive_and_act/images/train/15784.jpg has mask with 0.055413320660591125
# /root/data/processed/drive_and_act/images/train/31608.jpg has mask with 0.4493049681186676
# /root/data/processed/drive_and_act/images/train/6281.jpg has mask with 0.4118107259273529
# /root/data/processed/drive_and_act/images/train/5630.jpg has mask with 0.37125083804130554
# problematic images = /root/data/processed/drive_and_act/images/train/15783.jpg
# /root/data/processed/drive_and_act/images/train/30979.jpg has mask with 0.40520086884498596
# 		time = 2024-01-09 20:50:46.872016
# 			progress = 18000/40153 = 0.4483
# /root/data/processed/drive_and_act/images/train/5598.jpg has mask with 0.3452965021133423
# problematic images = /root/data/processed/drive_and_act/images/train/21276.jpg
# /root/data/processed/drive_and_act/images/train/36178.jpg has mask with 0.19890546798706055
# /root/data/processed/drive_and_act/images/train/15795.jpg has mask with 0.11228787153959274
# 		time = 2024-01-09 20:51:21.229818
# 			progress = 18500/40153 = 0.4607
# /root/data/processed/drive_and_act/images/train/5635.jpg has mask with 0.4823305010795593
# /root/data/processed/drive_and_act/images/train/10604.jpg has mask with 0.21859332919120789
# /root/data/processed/drive_and_act/images/train/5626.jpg has mask with 0.3547762632369995
# /root/data/processed/drive_and_act/images/train/5603.jpg has mask with 0.2928764820098877
# 		time = 2024-01-09 20:51:55.940226
# 			progress = 19000/40153 = 0.4732
# /root/data/processed/drive_and_act/images/train/5879.jpg has mask with 0.29638493061065674
# problematic images = /root/data/processed/drive_and_act/images/train/21274.jpg
# 		time = 2024-01-09 20:52:30.416708
# 			progress = 19500/40153 = 0.4856
# /root/data/processed/drive_and_act/images/train/3864.jpg has mask with 0.4844502806663513
# /root/data/processed/drive_and_act/images/train/16141.jpg has mask with 0.22872456908226013
# /root/data/processed/drive_and_act/images/train/5606.jpg has mask with 0.3716432452201843
# /root/data/processed/drive_and_act/images/train/16792.jpg has mask with 0.24419283866882324
# /root/data/processed/drive_and_act/images/train/5608.jpg has mask with 0.34954553842544556
# 		time = 2024-01-09 20:53:04.738497
# 			progress = 20000/40153 = 0.4981
# /root/data/processed/drive_and_act/images/train/16171.jpg has mask with 0.33002007007598877
# /root/data/processed/drive_and_act/images/train/17119.jpg has mask with 0.48722630739212036
# /root/data/processed/drive_and_act/images/train/31611.jpg has mask with 0.34205570816993713
# 		time = 2024-01-09 20:53:38.880231
# 			progress = 20500/40153 = 0.5105
# /root/data/processed/drive_and_act/images/train/2498.jpg has mask with 0.10514847189188004
# problematic images = /root/data/processed/drive_and_act/images/train/21271.jpg
# /root/data/processed/drive_and_act/images/train/16791.jpg has mask with 0.46828341484069824
# 		time = 2024-01-09 20:54:12.891430
# 			progress = 21000/40153 = 0.5230
# /root/data/processed/drive_and_act/images/train/5650.jpg has mask with 0.45045337080955505
# /root/data/processed/drive_and_act/images/train/25335.jpg has mask with 0.08898875117301941
# 		time = 2024-01-09 20:54:46.852068
# 			progress = 21500/40153 = 0.5355
# /root/data/processed/drive_and_act/images/train/16783.jpg has mask with 0.4207543432712555
# /root/data/processed/drive_and_act/images/train/5880.jpg has mask with 0.33887434005737305
# problematic images = /root/data/processed/drive_and_act/images/train/17258.jpg
# 		time = 2024-01-09 20:55:22.598827
# 			progress = 22000/40153 = 0.5479
# /root/data/processed/drive_and_act/images/train/21059.jpg has mask with 0.4843144416809082
# /root/data/processed/drive_and_act/images/train/6292.jpg has mask with 0.4506300091743469
# /root/data/processed/drive_and_act/images/train/6262.jpg has mask with 0.3180319368839264
# 		time = 2024-01-09 20:55:58.220592
# 			progress = 22500/40153 = 0.5604
# /root/data/processed/drive_and_act/images/train/16438.jpg has mask with 0.4854236841201782
# problematic images = /root/data/processed/drive_and_act/images/train/21273.jpg
# 		time = 2024-01-09 20:56:33.194016
# 			progress = 23000/40153 = 0.5728
# /root/data/processed/drive_and_act/images/train/5634.jpg has mask with 0.41127288341522217
# /root/data/processed/drive_and_act/images/train/31711.jpg has mask with 0.3470973074436188
# /root/data/processed/drive_and_act/images/train/5609.jpg has mask with 0.34941932559013367
# 		time = 2024-01-09 20:57:09.021744
# 			progress = 23500/40153 = 0.5853
# /root/data/processed/drive_and_act/images/train/10605.jpg has mask with 0.17681308090686798
# /root/data/processed/drive_and_act/images/train/5863.jpg has mask with 0.28078311681747437
# 		time = 2024-01-09 20:57:43.683902
# 			progress = 24000/40153 = 0.5977
# /root/data/processed/drive_and_act/images/train/31606.jpg has mask with 0.43091246485710144
# /root/data/processed/drive_and_act/images/train/16114.jpg has mask with 0.4611770808696747
# /root/data/processed/drive_and_act/images/train/29779.jpg has mask with 0.17763200402259827
# /root/data/processed/drive_and_act/images/train/32201.jpg has mask with 0.49763867259025574
# 		time = 2024-01-09 20:58:19.008717
# 			progress = 24500/40153 = 0.6102
# /root/data/processed/drive_and_act/images/train/5638.jpg has mask with 0.32611995935440063
# /root/data/processed/drive_and_act/images/train/12054.jpg has mask with 0.4672594368457794
# /root/data/processed/drive_and_act/images/train/31723.jpg has mask with 0.4680260717868805
# /root/data/processed/drive_and_act/images/train/5607.jpg has mask with 0.32879936695098877
# /root/data/processed/drive_and_act/images/train/34771.jpg has mask with 0.17277751863002777
# 		time = 2024-01-09 20:58:54.765681
# 			progress = 25000/40153 = 0.6226
# /root/data/processed/drive_and_act/images/train/7907.jpg has mask with 0.4823077619075775
# /root/data/processed/drive_and_act/images/train/31073.jpg has mask with 0.441547155380249
# 		time = 2024-01-09 20:59:30.713571
# 			progress = 25500/40153 = 0.6351
# /root/data/processed/drive_and_act/images/train/4908.jpg has mask with 0.4847269356250763
# /root/data/processed/drive_and_act/images/train/6283.jpg has mask with 0.34038904309272766
# /root/data/processed/drive_and_act/images/train/9536.jpg has mask with 0.26657000184059143
# /root/data/processed/drive_and_act/images/train/5881.jpg has mask with 0.2010394036769867
# /root/data/processed/drive_and_act/images/train/31258.jpg has mask with 0.45836055278778076
# 		time = 2024-01-09 21:00:06.689135
# 			progress = 26000/40153 = 0.6475
# /root/data/processed/drive_and_act/images/train/5328.jpg has mask with 0.47316300868988037
# /root/data/processed/drive_and_act/images/train/5615.jpg has mask with 0.4237802028656006
# /root/data/processed/drive_and_act/images/train/5602.jpg has mask with 0.3291037380695343
# problematic images = /root/data/processed/drive_and_act/images/train/21275.jpg
# 		time = 2024-01-09 21:00:42.666244
# 			progress = 26500/40153 = 0.6600
# /root/data/processed/drive_and_act/images/train/6264.jpg has mask with 0.42540884017944336
# /root/data/processed/drive_and_act/images/train/5877.jpg has mask with 0.18690162897109985
# /root/data/processed/drive_and_act/images/train/31990.jpg has mask with 0.3980870246887207
# 		time = 2024-01-09 21:01:17.293343
# 			progress = 27000/40153 = 0.6724
# /root/data/processed/drive_and_act/images/train/8108.jpg has mask with 0.44446370005607605
# /root/data/processed/drive_and_act/images/train/5617.jpg has mask with 0.3156772255897522
# /root/data/processed/drive_and_act/images/train/23374.jpg has mask with 0.4794919192790985
# /root/data/processed/drive_and_act/images/train/5691.jpg has mask with 0.4615834355354309
# 		time = 2024-01-09 21:01:51.379390
# 			progress = 27500/40153 = 0.6849
# /root/data/processed/drive_and_act/images/train/31652.jpg has mask with 0.44843819737434387
# /root/data/processed/drive_and_act/images/train/5612.jpg has mask with 0.3806171119213104
# /root/data/processed/drive_and_act/images/train/5875.jpg has mask with 0.28854697942733765
# /root/data/processed/drive_and_act/images/train/33526.jpg has mask with 0.07051058113574982
# /root/data/processed/drive_and_act/images/train/12347.jpg has mask with 0.4571778476238251
# /root/data/processed/drive_and_act/images/train/21022.jpg has mask with 0.424039363861084
# /root/data/processed/drive_and_act/images/train/15793.jpg has mask with 0.4850098490715027
# 		time = 2024-01-09 21:02:25.591225
# 			progress = 28000/40153 = 0.6973
# /root/data/processed/drive_and_act/images/train/5601.jpg has mask with 0.34208014607429504
# /root/data/processed/drive_and_act/images/train/16419.jpg has mask with 0.4610083997249603
# /root/data/processed/drive_and_act/images/train/2520.jpg has mask with 0.48061805963516235
# /root/data/processed/drive_and_act/images/train/5874.jpg has mask with 0.24766486883163452
# 		time = 2024-01-09 21:03:00.159887
# 			progress = 28500/40153 = 0.7098
# /root/data/processed/drive_and_act/images/train/5624.jpg has mask with 0.4676460027694702
# /root/data/processed/drive_and_act/images/train/5623.jpg has mask with 0.4863758981227875
# /root/data/processed/drive_and_act/images/train/30627.jpg has mask with 0.48739391565322876
# /root/data/processed/drive_and_act/images/train/16372.jpg has mask with 0.49957939982414246
# /root/data/processed/drive_and_act/images/train/9593.jpg has mask with 0.3469473719596863
# /root/data/processed/drive_and_act/images/train/5876.jpg has mask with 0.21319706737995148
# /root/data/processed/drive_and_act/images/train/5870.jpg has mask with 0.36834222078323364
# 		time = 2024-01-09 21:03:35.084601
# 			progress = 29000/40153 = 0.7222
# problematic images = /root/data/processed/drive_and_act/images/train/21272.jpg
# /root/data/processed/drive_and_act/images/train/8104.jpg has mask with 0.43832799792289734
# 		time = 2024-01-09 21:04:09.120991
# 			progress = 29500/40153 = 0.7347
# /root/data/processed/drive_and_act/images/train/6332.jpg has mask with 0.4445876181125641
# 		time = 2024-01-09 21:04:44.206569
# 			progress = 30000/40153 = 0.7471
# /root/data/processed/drive_and_act/images/train/16390.jpg has mask with 0.4886496961116791
# /root/data/processed/drive_and_act/images/train/4200.jpg has mask with 0.44686684012413025
# /root/data/processed/drive_and_act/images/train/22587.jpg has mask with 0.4847829341888428
# 		time = 2024-01-09 21:05:18.078873
# 			progress = 30500/40153 = 0.7596
# /root/data/processed/drive_and_act/images/train/39274.jpg has mask with 0.4333917200565338
# /root/data/processed/drive_and_act/images/train/5636.jpg has mask with 0.42361244559288025
# /root/data/processed/drive_and_act/images/train/5613.jpg has mask with 0.36315587162971497
# /root/data/processed/drive_and_act/images/train/32233.jpg has mask with 0.4382418990135193
# /root/data/processed/drive_and_act/images/train/5873.jpg has mask with 0.1835392713546753
# 		time = 2024-01-09 21:05:52.166384
# 			progress = 31000/40153 = 0.7720
# 		time = 2024-01-09 21:06:26.145151
# 			progress = 31500/40153 = 0.7845
# /root/data/processed/drive_and_act/images/train/5599.jpg has mask with 0.340055376291275
# /root/data/processed/drive_and_act/images/train/5651.jpg has mask with 0.37826797366142273
# /root/data/processed/drive_and_act/images/train/7922.jpg has mask with 0.4251522719860077
# 		time = 2024-01-09 21:07:00.518728
# 			progress = 32000/40153 = 0.7970
# /root/data/processed/drive_and_act/images/train/5883.jpg has mask with 0.2801489531993866
# 		time = 2024-01-09 21:07:36.093432
# 			progress = 32500/40153 = 0.8094
# /root/data/processed/drive_and_act/images/train/3790.jpg has mask with 0.47273337841033936
# /root/data/processed/drive_and_act/images/train/2753.jpg has mask with 0.31488919258117676
# /root/data/processed/drive_and_act/images/train/23946.jpg has mask with 0.4996473789215088
# 		time = 2024-01-09 21:08:10.320480
# 			progress = 33000/40153 = 0.8219
# /root/data/processed/drive_and_act/images/train/5345.jpg has mask with 0.4624413847923279
# /root/data/processed/drive_and_act/images/train/16253.jpg has mask with 0.20226195454597473
# /root/data/processed/drive_and_act/images/train/5625.jpg has mask with 0.4541286528110504
# /root/data/processed/drive_and_act/images/train/5327.jpg has mask with 0.48498815298080444
# /root/data/processed/drive_and_act/images/train/26232.jpg has mask with 0.49207809567451477
# 		time = 2024-01-09 21:08:44.727041
# 			progress = 33500/40153 = 0.8343
# /root/data/processed/drive_and_act/images/train/5834.jpg has mask with 0.3516618311405182
# /root/data/processed/drive_and_act/images/train/16784.jpg has mask with 0.4787932336330414
# /root/data/processed/drive_and_act/images/train/5652.jpg has mask with 0.48704850673675537
# /root/data/processed/drive_and_act/images/train/5866.jpg has mask with 0.2899199426174164
# /root/data/processed/drive_and_act/images/train/5649.jpg has mask with 0.4023870825767517
# 		time = 2024-01-09 21:09:19.299176
# 			progress = 34000/40153 = 0.8468
# 		time = 2024-01-09 21:09:54.448685
# 			progress = 34500/40153 = 0.8592
# /root/data/processed/drive_and_act/images/train/10423.jpg has mask with 0.4967406690120697
# /root/data/processed/drive_and_act/images/train/23947.jpg has mask with 0.07870015501976013
# 		time = 2024-01-09 21:10:29.115015
# 			progress = 35000/40153 = 0.8717
# /root/data/processed/drive_and_act/images/train/5865.jpg has mask with 0.3647626042366028
# /root/data/processed/drive_and_act/images/train/5614.jpg has mask with 0.3543749153614044
# /root/data/processed/drive_and_act/images/train/5604.jpg has mask with 0.482077032327652
# /root/data/processed/drive_and_act/images/train/16437.jpg has mask with 0.41654178500175476
# /root/data/processed/drive_and_act/images/train/16166.jpg has mask with 0.49417805671691895
# 		time = 2024-01-09 21:11:04.327652
# 			progress = 35500/40153 = 0.8841
# /root/data/processed/drive_and_act/images/train/5838.jpg has mask with 0.4794580042362213
# /root/data/processed/drive_and_act/images/train/1273.jpg has mask with 0.4669705629348755
# 		time = 2024-01-09 21:11:40.527506
# 			progress = 36000/40153 = 0.8966
# /root/data/processed/drive_and_act/images/train/32261.jpg has mask with 0.1643550992012024
# /root/data/processed/drive_and_act/images/train/6507.jpg has mask with 0.3967525362968445
# /root/data/processed/drive_and_act/images/train/31071.jpg has mask with 0.4956647455692291
# /root/data/processed/drive_and_act/images/train/34772.jpg has mask with 0.05944149196147919
# /root/data/processed/drive_and_act/images/train/12052.jpg has mask with 0.46949511766433716
# /root/data/processed/drive_and_act/images/train/12056.jpg has mask with 0.3597106635570526
# /root/data/processed/drive_and_act/images/train/7923.jpg has mask with 0.24055148661136627
# /root/data/processed/drive_and_act/images/train/5688.jpg has mask with 0.4514135718345642
# 		time = 2024-01-09 21:12:16.808726
# 			progress = 36500/40153 = 0.9090
# 		time = 2024-01-09 21:12:51.553936
# 			progress = 37000/40153 = 0.9215
# /root/data/processed/drive_and_act/images/train/5882.jpg has mask with 0.30626964569091797
# /root/data/processed/drive_and_act/images/train/6338.jpg has mask with 0.4227215349674225
# /root/data/processed/drive_and_act/images/train/5610.jpg has mask with 0.3530373275279999
# /root/data/processed/drive_and_act/images/train/22470.jpg has mask with 0.48461511731147766
# 		time = 2024-01-09 21:13:25.601316
# 			progress = 37500/40153 = 0.9339
# /root/data/processed/drive_and_act/images/train/5868.jpg has mask with 0.38249480724334717
# 		time = 2024-01-09 21:14:00.020298
# 			progress = 38000/40153 = 0.9464
# /root/data/processed/drive_and_act/images/train/31600.jpg has mask with 0.4773190915584564
# /root/data/processed/drive_and_act/images/train/5872.jpg has mask with 0.4358491003513336
# /root/data/processed/drive_and_act/images/train/34715.jpg has mask with 0.2433718591928482
# 		time = 2024-01-09 21:14:35.743363
# 			progress = 38500/40153 = 0.9588
# /root/data/processed/drive_and_act/images/train/5628.jpg has mask with 0.2875479757785797
# /root/data/processed/drive_and_act/images/train/5637.jpg has mask with 0.4102970063686371
# /root/data/processed/drive_and_act/images/train/27890.jpg has mask with 0.33946532011032104
# /root/data/processed/drive_and_act/images/train/7921.jpg has mask with 0.41128575801849365
# 		time = 2024-01-09 21:15:11.607497
# 			progress = 39000/40153 = 0.9713
# /root/data/processed/drive_and_act/images/train/4516.jpg has mask with 0.42823994159698486
# /root/data/processed/drive_and_act/images/train/8105.jpg has mask with 0.4068545401096344
# /root/data/processed/drive_and_act/images/train/31072.jpg has mask with 0.38686472177505493
# /root/data/processed/drive_and_act/images/train/9294.jpg has mask with 0.09710916876792908
# 		time = 2024-01-09 21:15:47.444259
# 			progress = 39500/40153 = 0.9837
# /root/data/processed/drive_and_act/images/train/2754.jpg has mask with 0.3832334280014038
# /root/data/processed/drive_and_act/images/train/5297.jpg has mask with 0.47417208552360535
# 		time = 2024-01-09 21:16:23.608189
# 			progress = 40000/40153 = 0.9962
# 		image_set = train, finish at = 2024-01-09 21:16:34.237516
# 		time spend = 46.86 mins (2811.55 secs), fps = 14.2783 fps
# created a folder at /root/data/processed/drive_and_act/person_detection_results.
# 	image_set = val, start at = 2024-01-09 21:16:34.496869
# 		image_set = val, finish at = 2024-01-09 21:16:34.497208
# 		time spend = 0.00 mins (0.00 secs), fps = 2967.3591 fps
# 	image_set = test, start at = 2024-01-09 21:16:34.497460
# 		image_set = test, finish at = 2024-01-09 21:16:34.497526
# 		time spend = 0.00 mins (0.00 secs), fps = 15625.0000 fps
