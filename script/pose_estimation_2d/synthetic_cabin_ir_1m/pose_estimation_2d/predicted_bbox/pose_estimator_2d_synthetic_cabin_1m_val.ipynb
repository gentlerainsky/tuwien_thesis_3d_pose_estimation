# %%
from src.modules.pose_estimator_2d.pose_estimator_2d import PoseEstimator2D

pose_estimator_2d = PoseEstimator2D(
    config_path='src/modules/pose_estimator_2d/config/hrnet.py',
    pretrained_path='https://download.openmmlab.com/mmpose/v1/'\
        'body_2d_keypoint/topdown_heatmap/coco/'\
            'td-hm_hrnet-w48_udp-8xb32-210e_coco-384x288-70d7ab01_20220913.pth',
    checkpoint_path="./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth",
    data_root_path='/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
    device='cuda:0',
    working_directory='./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m',
    log_level='INFO'
)

pose_estimator_2d.load_pretrained()
pose_estimator_2d.runner.val()
# Out:
# 11/18 18:33:40 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 298498084
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 298498084
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/18 18:33:43 - mmengine - INFO - Config:
# default_scope = 'mmpose'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmpose'),
#     logger=dict(type='LoggerHook', interval=50, _scope_='mmpose'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmpose'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         interval=10,
#         save_best='coco/AP',
#         rule='greater',
#         _scope_='mmpose'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmpose'),
#     visualization=dict(
#         type='PoseVisualizationHook', enable=False, _scope_='mmpose'))
# custom_hooks = [
#     dict(type='SyncBuffersHook', _scope_='mmpose'),
# ]
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmpose'),
# ]
# visualizer = dict(
#     type='PoseLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmpose')
# log_processor = dict(
#     type='LogProcessor',
#     window_size=50,
#     by_epoch=True,
#     num_digits=6,
#     _scope_='mmpose')
# log_level = 'INFO'
# load_from = './mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth'
# resume = False
# backend_args = dict(backend='local')
# train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# optim_wrapper = dict(optimizer=dict(type='Adam', lr=0.0005, _scope_='mmpose'))
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         begin=0,
#         end=500,
#         start_factor=0.001,
#         by_epoch=False,
#         _scope_='mmpose'),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=210,
#         milestones=[
#             170,
#             200,
#         ],
#         gamma=0.1,
#         by_epoch=True,
#         _scope_='mmpose'),
# ]
# auto_scale_lr = dict(base_batch_size=512)
# codec = dict(
#     type='UDPHeatmap',
#     input_size=(
#         288,
#         384,
#     ),
#     heatmap_size=(
#         72,
#         96,
#     ),
#     sigma=3,
#     _scope_='mmpose')
# model = dict(
#     type='TopdownPoseEstimator',
#     data_preprocessor=dict(
#         type='PoseDataPreprocessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True),
#     backbone=dict(
#         type='HRNet',
#         in_channels=3,
#         extra=dict(
#             stage1=dict(
#                 num_modules=1,
#                 num_branches=1,
#                 block='BOTTLENECK',
#                 num_blocks=(4, ),
#                 num_channels=(64, )),
#             stage2=dict(
#                 num_modules=1,
#                 num_branches=2,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                 )),
#             stage3=dict(
#                 num_modules=4,
#                 num_branches=3,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                     192,
#                 )),
#             stage4=dict(
#                 num_modules=3,
#                 num_branches=4,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                     192,
#                     384,
#                 ))),
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmpose/pretrain_models/hrnet_w48-8ef0771d.pth'
#         )),
#     head=dict(
#         type='HeatmapHead',
#         in_channels=48,
#         out_channels=17,
#         deconv_out_channels=None,
#         loss=dict(type='KeypointMSELoss', use_target_weight=True),
#         decoder=dict(
#             type='UDPHeatmap',
#             input_size=(
#                 288,
#                 384,
#             ),
#             heatmap_size=(
#                 72,
#                 96,
#             ),
#             sigma=3)),
#     test_cfg=dict(flip_test=True, flip_mode='heatmap', shift_heatmap=False),
#     _scope_='mmpose')
# dataset_type = 'CocoDataset'
# data_mode = 'topdown'
# data_root = '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/'
# train_pipeline = [
#     dict(type='LoadImage', _scope_='mmpose'),
#     dict(type='GetBBoxCenterScale', _scope_='mmpose'),
#     dict(type='RandomFlip', direction='horizontal', _scope_='mmpose'),
#     dict(type='RandomHalfBody', _scope_='mmpose'),
#     dict(type='RandomBBoxTransform', _scope_='mmpose'),
#     dict(
#         type='TopdownAffine',
#         input_size=(
#             288,
#             384,
#         ),
#         use_udp=True,
#         _scope_='mmpose'),
#     dict(
#         type='GenerateTarget',
#         encoder=dict(
#             type='UDPHeatmap',
#             input_size=(
#                 288,
#                 384,
#             ),
#             heatmap_size=(
#                 72,
#                 96,
#             ),
#             sigma=3),
#         _scope_='mmpose'),
#     dict(type='PackPoseInputs', _scope_='mmpose'),
# ]
# val_pipeline = [
#     dict(type='LoadImage', _scope_='mmpose'),
#     dict(type='GetBBoxCenterScale', _scope_='mmpose'),
#     dict(
#         type='TopdownAffine',
#         input_size=(
#             288,
#             384,
#         ),
#         use_udp=True,
#         _scope_='mmpose'),
#     dict(type='PackPoseInputs', _scope_='mmpose'),
# ]
# train_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
#         data_mode='topdown',
#         ann_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train'),
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='RandomFlip', direction='horizontal'),
#             dict(type='RandomHalfBody'),
#             dict(type='RandomBBoxTransform'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(
#                 type='GenerateTarget',
#                 encoder=dict(
#                     type='UDPHeatmap',
#                     input_size=(
#                         288,
#                         384,
#                     ),
#                     heatmap_size=(
#                         72,
#                         96,
#                     ),
#                     sigma=3)),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# val_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(
#         type='DefaultSampler', shuffle=False, round_up=False,
#         _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
#         data_mode='topdown',
#         ann_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#         bbox_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/person_detection_results/human_detection_val.json',
#         data_prefix=dict(img='images/val'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# test_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(
#         type='DefaultSampler', shuffle=False, round_up=False,
#         _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
#         data_mode='topdown',
#         ann_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_test.json',
#         bbox_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/person_detection_results/human_detection_test.json',
#         data_prefix=dict(img='images/test'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     _scope_='mmpose')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_test.json',
#     _scope_='mmpose')
# work_dir = './mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m'
# wandb: Currently logged in as: gentlerainsky. Use `wandb login --relogin` to force relogin
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/workspace/mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/20231118_183340/vis_data/wandb/run-20231118_183348-kogmw2wg</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/kogmw2wg' target="_blank">balmy-frog-76</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/kogmw2wg' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/kogmw2wg</a>
# 11/18 18:34:00 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/18 18:34:00 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by local backend from path: ./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth
# 11/18 18:34:04 - mmengine - INFO - Load checkpoint from ./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth
# loading annotations into memory...
# /opt/conda/lib/python3.10/site-packages/mmpose/datasets/datasets/utils.py:102: UserWarning: The metainfo config file "configs/_base_/datasets/coco.py" does not exist. A matched config file "/opt/conda/lib/python3.10/site-packages/mmpose/.mim/configs/_base_/datasets/coco.py" will be used instead.
#   warnings.warn(
# Done (t=0.87s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.74s)
# creating index...
# index created!
# 11/18 18:35:05 - mmengine - INFO - Epoch(val)[0][  50/2344]    eta: 0:42:37  time: 1.115012  data_time: 0.028740  memory: 655
# 11/18 18:35:58 - mmengine - INFO - Epoch(val)[0][ 100/2344]    eta: 0:40:33  time: 1.054042  data_time: 0.010543  memory: 655
# 11/18 18:36:51 - mmengine - INFO - Epoch(val)[0][ 150/2344]    eta: 0:39:19  time: 1.057500  data_time: 0.009741  memory: 655
# 11/18 18:37:45 - mmengine - INFO - Epoch(val)[0][ 200/2344]    eta: 0:38:24  time: 1.073799  data_time: 0.009740  memory: 655
# 11/18 18:38:38 - mmengine - INFO - Epoch(val)[0][ 250/2344]    eta: 0:37:25  time: 1.060818  data_time: 0.010034  memory: 655
# 11/18 18:39:32 - mmengine - INFO - Epoch(val)[0][ 300/2344]    eta: 0:36:39  time: 1.095654  data_time: 0.009850  memory: 655
# 11/18 18:40:27 - mmengine - INFO - Epoch(val)[0][ 350/2344]    eta: 0:35:49  time: 1.090275  data_time: 0.011059  memory: 655
# 11/18 18:41:22 - mmengine - INFO - Epoch(val)[0][ 400/2344]    eta: 0:34:59  time: 1.092707  data_time: 0.010685  memory: 655
# 11/18 18:42:15 - mmengine - INFO - Epoch(val)[0][ 450/2344]    eta: 0:34:04  time: 1.077442  data_time: 0.009658  memory: 655
# 11/18 18:43:07 - mmengine - INFO - Epoch(val)[0][ 500/2344]    eta: 0:33:01  time: 1.026807  data_time: 0.009531  memory: 655
# 11/18 18:43:58 - mmengine - INFO - Epoch(val)[0][ 550/2344]    eta: 0:32:00  time: 1.030658  data_time: 0.009540  memory: 655
# 11/18 18:44:50 - mmengine - INFO - Epoch(val)[0][ 600/2344]    eta: 0:31:01  time: 1.031314  data_time: 0.009717  memory: 655
# 11/18 18:45:42 - mmengine - INFO - Epoch(val)[0][ 650/2344]    eta: 0:30:03  time: 1.034964  data_time: 0.009799  memory: 655
# 11/18 18:46:33 - mmengine - INFO - Epoch(val)[0][ 700/2344]    eta: 0:29:06  time: 1.033524  data_time: 0.009943  memory: 655
# 11/18 18:47:25 - mmengine - INFO - Epoch(val)[0][ 750/2344]    eta: 0:28:10  time: 1.030225  data_time: 0.010059  memory: 655
# 11/18 18:48:17 - mmengine - INFO - Epoch(val)[0][ 800/2344]    eta: 0:27:15  time: 1.042165  data_time: 0.009554  memory: 655
# 11/18 18:49:09 - mmengine - INFO - Epoch(val)[0][ 850/2344]    eta: 0:26:20  time: 1.040151  data_time: 0.009793  memory: 655
# 11/18 18:50:01 - mmengine - INFO - Epoch(val)[0][ 900/2344]    eta: 0:25:26  time: 1.041639  data_time: 0.009906  memory: 655
# 11/18 18:50:53 - mmengine - INFO - Epoch(val)[0][ 950/2344]    eta: 0:24:32  time: 1.045083  data_time: 0.010126  memory: 655
# 11/18 18:51:45 - mmengine - INFO - Epoch(val)[0][1000/2344]    eta: 0:23:38  time: 1.036120  data_time: 0.010057  memory: 655
# 11/18 18:52:37 - mmengine - INFO - Epoch(val)[0][1050/2344]    eta: 0:22:44  time: 1.039434  data_time: 0.010854  memory: 655
# 11/18 18:53:29 - mmengine - INFO - Epoch(val)[0][1100/2344]    eta: 0:21:51  time: 1.042828  data_time: 0.009793  memory: 655
# 11/18 18:54:21 - mmengine - INFO - Epoch(val)[0][1150/2344]    eta: 0:20:58  time: 1.043963  data_time: 0.009786  memory: 655
# 11/18 18:55:14 - mmengine - INFO - Epoch(val)[0][1200/2344]    eta: 0:20:05  time: 1.045262  data_time: 0.009933  memory: 655
# 11/18 18:56:06 - mmengine - INFO - Epoch(val)[0][1250/2344]    eta: 0:19:12  time: 1.045055  data_time: 0.010335  memory: 655
# 11/18 18:56:57 - mmengine - INFO - Epoch(val)[0][1300/2344]    eta: 0:18:18  time: 1.018961  data_time: 0.010474  memory: 655
# 11/18 18:57:27 - mmengine - INFO - Epoch(val)[0][1350/2344]    eta: 0:17:08  time: 0.595101  data_time: 0.009530  memory: 655
# 11/18 18:57:57 - mmengine - INFO - Epoch(val)[0][1400/2344]    eta: 0:16:02  time: 0.606760  data_time: 0.009322  memory: 655
# 11/18 18:58:26 - mmengine - INFO - Epoch(val)[0][1450/2344]    eta: 0:14:57  time: 0.581355  data_time: 0.009613  memory: 655
# 11/18 18:58:55 - mmengine - INFO - Epoch(val)[0][1500/2344]    eta: 0:13:55  time: 0.581771  data_time: 0.009396  memory: 655
# 11/18 18:59:24 - mmengine - INFO - Epoch(val)[0][1550/2344]    eta: 0:12:55  time: 0.586749  data_time: 0.009482  memory: 655
# 11/18 18:59:54 - mmengine - INFO - Epoch(val)[0][1600/2344]    eta: 0:11:58  time: 0.590759  data_time: 0.010063  memory: 655
# 11/18 19:00:23 - mmengine - INFO - Epoch(val)[0][1650/2344]    eta: 0:11:01  time: 0.575902  data_time: 0.009350  memory: 655
# 11/18 19:00:52 - mmengine - INFO - Epoch(val)[0][1700/2344]    eta: 0:10:06  time: 0.578631  data_time: 0.009569  memory: 655
# 11/18 19:01:22 - mmengine - INFO - Epoch(val)[0][1750/2344]    eta: 0:09:13  time: 0.595665  data_time: 0.009737  memory: 655
# 11/18 19:01:50 - mmengine - INFO - Epoch(val)[0][1800/2344]    eta: 0:08:21  time: 0.564542  data_time: 0.009391  memory: 655
# 11/18 19:02:19 - mmengine - INFO - Epoch(val)[0][1850/2344]    eta: 0:07:30  time: 0.576271  data_time: 0.009600  memory: 655
# 11/18 19:02:49 - mmengine - INFO - Epoch(val)[0][1900/2344]    eta: 0:06:41  time: 0.601090  data_time: 0.009980  memory: 655
# 11/18 19:03:18 - mmengine - INFO - Epoch(val)[0][1950/2344]    eta: 0:05:53  time: 0.587808  data_time: 0.009650  memory: 655
# 11/18 19:03:47 - mmengine - INFO - Epoch(val)[0][2000/2344]    eta: 0:05:05  time: 0.585533  data_time: 0.009434  memory: 655
# 11/18 19:04:17 - mmengine - INFO - Epoch(val)[0][2050/2344]    eta: 0:04:19  time: 0.589547  data_time: 0.009963  memory: 655
# 11/18 19:04:46 - mmengine - INFO - Epoch(val)[0][2100/2344]    eta: 0:03:33  time: 0.583737  data_time: 0.009431  memory: 655
# 11/18 19:05:15 - mmengine - INFO - Epoch(val)[0][2150/2344]    eta: 0:02:48  time: 0.581532  data_time: 0.009672  memory: 655
# 11/18 19:05:45 - mmengine - INFO - Epoch(val)[0][2200/2344]    eta: 0:02:04  time: 0.609136  data_time: 0.009254  memory: 655
# 11/18 19:06:15 - mmengine - INFO - Epoch(val)[0][2250/2344]    eta: 0:01:20  time: 0.595348  data_time: 0.009683  memory: 655
# 11/18 19:06:44 - mmengine - INFO - Epoch(val)[0][2300/2344]    eta: 0:00:37  time: 0.573175  data_time: 0.009566  memory: 655
# 11/18 19:07:14 - mmengine - INFO - Evaluating CocoMetric...
# Loading and preparing results...
# DONE (t=1.36s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=6.41s).
# Accumulating evaluation results...
# DONE (t=0.76s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.737
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  0.929
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.789
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.759
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  0.939
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.759
# 11/18 19:07:23 - mmengine - INFO - Epoch(val) [0][2344/2344]    coco/AP: 0.736583  coco/AP .5: 0.929483  coco/AP .75: 0.789377  coco/AP (M): -1.000000  coco/AP (L): 0.736583  coco/AR: 0.758771  coco/AR .5: 0.939067  coco/AR .75: 0.804160  coco/AR (M): -1.000000  coco/AR (L): 0.758771  data_time: 0.010224  time: 0.844939
# loading annotations into memory...
# /opt/conda/lib/python3.10/site-packages/mmpose/datasets/datasets/utils.py:102: UserWarning: The metainfo config file "configs/_base_/datasets/coco.py" does not exist. A matched config file "/opt/conda/lib/python3.10/site-packages/mmpose/.mim/configs/_base_/datasets/coco.py" will be used instead.
#   warnings.warn(
# Done (t=1.00s)
# creating index...
# index created!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> pose_estimator_2d = PoseEstimator2D(
#       <a href='vscode-notebook-cell:/home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a>     config_path='src/modules/pose_estimator_2d/config/hrnet.py',
#       <a href='vscode-notebook-cell:/home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>     pretrained_path='https://download.openmmlab.com/mmpose/v1/'\
#    (...)
#      <a href='vscode-notebook-cell:/home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>     log_level='INFO'
#      <a href='vscode-notebook-cell:/home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> )
#      <a href='vscode-notebook-cell:/home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> pose_estimator_2d.load_pretrained()
# ---> <a href='vscode-notebook-cell:/home/tk/Documents/Projects/pose_estimation_3d/script/pose_estimation_2d/synthetic_cabin_1m/pose_estimator_2d_synthetic_cabin_1m_val.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> pose_estimator_2d.runner.val()
#
# File /opt/conda/lib/python3.10/site-packages/mmengine/runner/runner.py:1758, in Runner.val(self)
#    1755 # make sure checkpoint-related hooks are triggered after `before_run`
#    1756 self.load_or_resume()
# -> 1758 metrics = self.val_loop.run()  # type: ignore
#    1759 self.call_hook('after_run')
#    1760 return metrics
#
# File /opt/conda/lib/python3.10/site-packages/mmengine/runner/loops.py:367, in ValLoop.run(self)
#     365 # compute metrics
#     366 metrics = self.evaluator.evaluate(len(self.dataloader.dataset))
# --> 367 self.runner.call_hook('after_val_epoch', metrics=metrics)
#     368 self.runner.call_hook('after_val')
#     369 return metrics
#
# File /opt/conda/lib/python3.10/site-packages/mmengine/runner/runner.py:1797, in Runner.call_hook(self, fn_name, **kwargs)
#    1795 if hasattr(hook, fn_name):
#    1796     try:
# -> 1797         getattr(hook, fn_name)(self, **kwargs)
#    1798     except TypeError as e:
#    1799         raise TypeError(f'{e} in {hook}') from None
#
# File /opt/conda/lib/python3.10/site-packages/mmengine/hooks/checkpoint_hook.py:351, in CheckpointHook.after_val_epoch(self, runner, metrics)
#     346     runner.logger.warning(
#     347         'Since `metrics` is an empty dict, the behavior to save '
#     348         'the best checkpoint will be skipped in this evaluation.')
#     349     return
# --> 351 self._save_best_checkpoint(runner, metrics)
#
# File /opt/conda/lib/python3.10/site-packages/mmengine/hooks/checkpoint_hook.py:539, in CheckpointHook._save_best_checkpoint(self, runner, metrics)
#     537 best_ckpt_name = best_ckpt_name.replace('/', '_')
#     538 if len(self.key_indicators) == 1:
# --> 539     self.best_ckpt_path = self.file_backend.join_path(  # type: ignore # noqa: E501
#     540         self.out_dir, best_ckpt_name)
#     541     runner.message_hub.update_info(runtime_best_ckpt_key,
#     542                                    self.best_ckpt_path)
#     543 else:
#
# AttributeError: 'CheckpointHook' object has no attribute 'file_backend'
