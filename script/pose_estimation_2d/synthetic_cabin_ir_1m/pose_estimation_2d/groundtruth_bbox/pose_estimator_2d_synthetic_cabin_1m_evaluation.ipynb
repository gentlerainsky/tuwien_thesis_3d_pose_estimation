# %%
from src.modules.pose_estimator_2d.pose_estimator_2d import PoseEstimator2D

pose_estimator_2d = PoseEstimator2D(
    config_path='src/modules/pose_estimator_2d/config/hrnet.py',
    pretrained_path='https://download.openmmlab.com/mmpose/v1/'\
        'body_2d_keypoint/topdown_heatmap/coco/'\
            'td-hm_hrnet-w48_udp-8xb32-210e_coco-384x288-70d7ab01_20220913.pth',
    checkpoint_path="./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth",
    data_root_path='/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
    device='cuda:0',
    working_directory='./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m',
    log_level='INFO'
)

pose_estimator_2d.load_pretrained()
pose_estimator_2d.test()
# Out:
# 11/19 14:28:20 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1150038243
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1150038243
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/19 14:28:22 - mmengine - INFO - Config:
# default_scope = 'mmpose'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmpose'),
#     logger=dict(type='LoggerHook', interval=50, _scope_='mmpose'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmpose'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         interval=10,
#         save_best='coco/AP',
#         rule='greater',
#         _scope_='mmpose'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmpose'),
#     visualization=dict(
#         type='PoseVisualizationHook', enable=False, _scope_='mmpose'))
# custom_hooks = [
#     dict(type='SyncBuffersHook', _scope_='mmpose'),
# ]
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmpose'),
# ]
# visualizer = dict(
#     type='PoseLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmpose')
# log_processor = dict(
#     type='LogProcessor',
#     window_size=50,
#     by_epoch=True,
#     num_digits=6,
#     _scope_='mmpose')
# log_level = 'INFO'
# load_from = './mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth'
# resume = False
# backend_args = dict(backend='local')
# train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# optim_wrapper = dict(optimizer=dict(type='Adam', lr=0.0005, _scope_='mmpose'))
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         begin=0,
#         end=500,
#         start_factor=0.001,
#         by_epoch=False,
#         _scope_='mmpose'),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=210,
#         milestones=[
#             170,
#             200,
#         ],
#         gamma=0.1,
#         by_epoch=True,
#         _scope_='mmpose'),
# ]
# auto_scale_lr = dict(base_batch_size=512)
# codec = dict(
#     type='UDPHeatmap',
#     input_size=(
#         288,
#         384,
#     ),
#     heatmap_size=(
#         72,
#         96,
#     ),
#     sigma=3,
#     _scope_='mmpose')
# model = dict(
#     type='TopdownPoseEstimator',
#     data_preprocessor=dict(
#         type='PoseDataPreprocessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True),
#     backbone=dict(
#         type='HRNet',
#         in_channels=3,
#         extra=dict(
#             stage1=dict(
#                 num_modules=1,
#                 num_branches=1,
#                 block='BOTTLENECK',
#                 num_blocks=(4, ),
#                 num_channels=(64, )),
#             stage2=dict(
#                 num_modules=1,
#                 num_branches=2,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                 )),
#             stage3=dict(
#                 num_modules=4,
#                 num_branches=3,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                     192,
#                 )),
#             stage4=dict(
#                 num_modules=3,
#                 num_branches=4,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                     192,
#                     384,
#                 ))),
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmpose/pretrain_models/hrnet_w48-8ef0771d.pth'
#         )),
#     head=dict(
#         type='HeatmapHead',
#         in_channels=48,
#         out_channels=17,
#         deconv_out_channels=None,
#         loss=dict(type='KeypointMSELoss', use_target_weight=True),
#         decoder=dict(
#             type='UDPHeatmap',
#             input_size=(
#                 288,
#                 384,
#             ),
#             heatmap_size=(
#                 72,
#                 96,
#             ),
#             sigma=3)),
#     test_cfg=dict(flip_test=True, flip_mode='heatmap', shift_heatmap=False),
#     _scope_='mmpose')
# dataset_type = 'CocoDataset'
# data_mode = 'topdown'
# data_root = '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/'
# train_pipeline = [
#     dict(type='LoadImage', _scope_='mmpose'),
#     dict(type='GetBBoxCenterScale', _scope_='mmpose'),
#     dict(type='RandomFlip', direction='horizontal', _scope_='mmpose'),
#     dict(type='RandomHalfBody', _scope_='mmpose'),
#     dict(type='RandomBBoxTransform', _scope_='mmpose'),
#     dict(
#         type='TopdownAffine',
#         input_size=(
#             288,
#             384,
#         ),
#         use_udp=True,
#         _scope_='mmpose'),
#     dict(
#         type='GenerateTarget',
#         encoder=dict(
#             type='UDPHeatmap',
#             input_size=(
#                 288,
#                 384,
#             ),
#             heatmap_size=(
#                 72,
#                 96,
#             ),
#             sigma=3),
#         _scope_='mmpose'),
#     dict(type='PackPoseInputs', _scope_='mmpose'),
# ]
# val_pipeline = [
#     dict(type='LoadImage', _scope_='mmpose'),
#     dict(type='GetBBoxCenterScale', _scope_='mmpose'),
#     dict(
#         type='TopdownAffine',
#         input_size=(
#             288,
#             384,
#         ),
#         use_udp=True,
#         _scope_='mmpose'),
#     dict(type='PackPoseInputs', _scope_='mmpose'),
# ]
# train_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
#         data_mode='topdown',
#         ann_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train'),
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='RandomFlip', direction='horizontal'),
#             dict(type='RandomHalfBody'),
#             dict(type='RandomBBoxTransform'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(
#                 type='GenerateTarget',
#                 encoder=dict(
#                     type='UDPHeatmap',
#                     input_size=(
#                         288,
#                         384,
#                     ),
#                     heatmap_size=(
#                         72,
#                         96,
#                     ),
#                     sigma=3)),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# val_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(
#         type='DefaultSampler', shuffle=False, round_up=False,
#         _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
#         data_mode='topdown',
#         ann_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#         bbox_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/person_detection_results/human_detection_val.json',
#         data_prefix=dict(img='images/val'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# test_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(
#         type='DefaultSampler', shuffle=False, round_up=False,
#         _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/',
#         data_mode='topdown',
#         ann_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_test.json',
#         bbox_file=
#         '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/person_detection_results/ground_truth_human_detection_test.json',
#         data_prefix=dict(img='images/test'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     _scope_='mmpose')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/synthetic_cabin_1m/syntheticcabin_1mil/processed_syntheticCabin_1m/A_Pillar_Codriver/annotations/person_keypoints_test.json',
#     _scope_='mmpose')
# work_dir = './mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m'
# wandb: Currently logged in as: gentlerainsky. Use `wandb login --relogin` to force relogin
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/workspace/mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/20231119_142819/vis_data/wandb/run-20231119_142826-prlqztjj</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/prlqztjj' target="_blank">legendary-shape-77</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/prlqztjj' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/prlqztjj</a>
# 11/19 14:28:33 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/19 14:28:33 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by local backend from path: ./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth
# 11/19 14:28:35 - mmengine - INFO - Load checkpoint from ./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/best_coco_AP_epoch_8.pth
# loading annotations into memory...
# /opt/conda/lib/python3.10/site-packages/mmpose/datasets/datasets/utils.py:102: UserWarning: The metainfo config file "configs/_base_/datasets/coco.py" does not exist. A matched config file "/opt/conda/lib/python3.10/site-packages/mmpose/.mim/configs/_base_/datasets/coco.py" will be used instead.
#   warnings.warn(
# Done (t=0.49s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.34s)
# creating index...
# index created!
# 11/19 14:28:59 - mmengine - INFO - Epoch(test) [  50/1897]    eta: 0:11:54  time: 0.386932  data_time: 0.018448  memory: 655
# 11/19 14:29:17 - mmengine - INFO - Epoch(test) [ 100/1897]    eta: 0:11:25  time: 0.375737  data_time: 0.006345  memory: 655
# 11/19 14:29:36 - mmengine - INFO - Epoch(test) [ 150/1897]    eta: 0:11:04  time: 0.378070  data_time: 0.006737  memory: 655
# 11/19 14:29:54 - mmengine - INFO - Epoch(test) [ 200/1897]    eta: 0:10:36  time: 0.359647  data_time: 0.007820  memory: 655
# 11/19 14:30:12 - mmengine - INFO - Epoch(test) [ 250/1897]    eta: 0:10:12  time: 0.358475  data_time: 0.007895  memory: 655
# 11/19 14:30:31 - mmengine - INFO - Epoch(test) [ 300/1897]    eta: 0:09:55  time: 0.377904  data_time: 0.008126  memory: 655
# 11/19 14:30:50 - mmengine - INFO - Epoch(test) [ 350/1897]    eta: 0:09:36  time: 0.373559  data_time: 0.007434  memory: 655
# 11/19 14:31:08 - mmengine - INFO - Epoch(test) [ 400/1897]    eta: 0:09:16  time: 0.362837  data_time: 0.007744  memory: 655
# 11/19 14:31:26 - mmengine - INFO - Epoch(test) [ 450/1897]    eta: 0:08:56  time: 0.365958  data_time: 0.008275  memory: 655
# 11/19 14:31:45 - mmengine - INFO - Epoch(test) [ 500/1897]    eta: 0:08:37  time: 0.367930  data_time: 0.008415  memory: 655
# 11/19 14:32:04 - mmengine - INFO - Epoch(test) [ 550/1897]    eta: 0:08:21  time: 0.390009  data_time: 0.007360  memory: 655
# 11/19 14:32:23 - mmengine - INFO - Epoch(test) [ 600/1897]    eta: 0:08:03  time: 0.379379  data_time: 0.006247  memory: 655
# 11/19 14:32:42 - mmengine - INFO - Epoch(test) [ 650/1897]    eta: 0:07:44  time: 0.371078  data_time: 0.006275  memory: 655
# 11/19 14:33:00 - mmengine - INFO - Epoch(test) [ 700/1897]    eta: 0:07:25  time: 0.364160  data_time: 0.006102  memory: 655
# 11/19 14:33:19 - mmengine - INFO - Epoch(test) [ 750/1897]    eta: 0:07:07  time: 0.381358  data_time: 0.006448  memory: 655
# 11/19 14:33:38 - mmengine - INFO - Epoch(test) [ 800/1897]    eta: 0:06:49  time: 0.376075  data_time: 0.006414  memory: 655
# 11/19 14:33:57 - mmengine - INFO - Epoch(test) [ 850/1897]    eta: 0:06:31  time: 0.379945  data_time: 0.006311  memory: 655
# 11/19 14:34:16 - mmengine - INFO - Epoch(test) [ 900/1897]    eta: 0:06:13  time: 0.385453  data_time: 0.007394  memory: 655
# 11/19 14:34:35 - mmengine - INFO - Epoch(test) [ 950/1897]    eta: 0:05:55  time: 0.389467  data_time: 0.007129  memory: 655
# 11/19 14:34:56 - mmengine - INFO - Epoch(test) [1000/1897]    eta: 0:05:37  time: 0.401893  data_time: 0.007686  memory: 655
# 11/19 14:35:14 - mmengine - INFO - Epoch(test) [1050/1897]    eta: 0:05:18  time: 0.375571  data_time: 0.007783  memory: 655
# 11/19 14:35:33 - mmengine - INFO - Epoch(test) [1100/1897]    eta: 0:05:00  time: 0.382785  data_time: 0.008192  memory: 655
# 11/19 14:35:53 - mmengine - INFO - Epoch(test) [1150/1897]    eta: 0:04:41  time: 0.383384  data_time: 0.006843  memory: 655
# 11/19 14:36:11 - mmengine - INFO - Epoch(test) [1200/1897]    eta: 0:04:22  time: 0.369401  data_time: 0.006786  memory: 655
# 11/19 14:36:30 - mmengine - INFO - Epoch(test) [1250/1897]    eta: 0:04:03  time: 0.378471  data_time: 0.007929  memory: 655
# 11/19 14:36:49 - mmengine - INFO - Epoch(test) [1300/1897]    eta: 0:03:44  time: 0.381150  data_time: 0.008181  memory: 655
# 11/19 14:37:08 - mmengine - INFO - Epoch(test) [1350/1897]    eta: 0:03:26  time: 0.378957  data_time: 0.007275  memory: 655
# 11/19 14:37:27 - mmengine - INFO - Epoch(test) [1400/1897]    eta: 0:03:07  time: 0.389579  data_time: 0.007929  memory: 655
# 11/19 14:37:48 - mmengine - INFO - Epoch(test) [1450/1897]    eta: 0:02:49  time: 0.401166  data_time: 0.007571  memory: 655
# 11/19 14:38:08 - mmengine - INFO - Epoch(test) [1500/1897]    eta: 0:02:30  time: 0.404930  data_time: 0.008485  memory: 655
# 11/19 14:38:28 - mmengine - INFO - Epoch(test) [1550/1897]    eta: 0:02:11  time: 0.401867  data_time: 0.007955  memory: 655
# 11/19 14:38:47 - mmengine - INFO - Epoch(test) [1600/1897]    eta: 0:01:52  time: 0.384596  data_time: 0.007427  memory: 655
# 11/19 14:39:07 - mmengine - INFO - Epoch(test) [1650/1897]    eta: 0:01:33  time: 0.390746  data_time: 0.007661  memory: 655
# 11/19 14:39:26 - mmengine - INFO - Epoch(test) [1700/1897]    eta: 0:01:14  time: 0.391533  data_time: 0.007805  memory: 655
# 11/19 14:39:46 - mmengine - INFO - Epoch(test) [1750/1897]    eta: 0:00:55  time: 0.389262  data_time: 0.007657  memory: 655
# 11/19 14:40:05 - mmengine - INFO - Epoch(test) [1800/1897]    eta: 0:00:36  time: 0.392787  data_time: 0.007374  memory: 655
# 11/19 14:40:25 - mmengine - INFO - Epoch(test) [1850/1897]    eta: 0:00:17  time: 0.393419  data_time: 0.007682  memory: 655
# 11/19 14:40:45 - mmengine - INFO - Evaluating CocoMetric...
# Loading and preparing results...
# DONE (t=0.83s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=5.14s).
# Accumulating evaluation results...
# DONE (t=0.25s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.964
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  0.990
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.989
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.964
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.975
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.993
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.975
# 11/19 14:40:52 - mmengine - INFO - Epoch(test) [1897/1897]    coco/AP: 0.964388  coco/AP .5: 0.990098  coco/AP .75: 0.989443  coco/AP (M): -1.000000  coco/AP (L): 0.964388  coco/AR: 0.974955  coco/AR .5: 0.999835  coco/AR .75: 0.993179  coco/AR (M): -1.000000  coco/AR (L): 0.974955  data_time: 0.007693  time: 0.381302
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'artifact' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
#  View run <strong style="color:#cdcd00">legendary-shape-77</strong> at: <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/prlqztjj' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/prlqztjj</a><br/>Synced 6 W&B file(s), 0 media file(s), 60 artifact file(s) and 0 other file(s)
# Find logs at: <code>./mmengine_workdir/pose_estimator_2d_synthetic_cabin_1m/20231119_142819/vis_data/wandb/run-20231119_142826-prlqztjj/logs</code>
