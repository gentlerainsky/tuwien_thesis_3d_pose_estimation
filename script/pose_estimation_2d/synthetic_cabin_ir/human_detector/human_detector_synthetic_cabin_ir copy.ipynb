# %%
from modules.human_detector.human_detector import HumanDetector
from modules.human_detector.main import detect_person
import pathlib

# %%
# view_point = 'A_Pillar_Codriver'
# view_point = 'A_Pillar_Driver'
view_point = 'Rear_Mirror'
detector = HumanDetector(
    config_path='./modules/human_detector/config/faster_rcnn.py',
    # pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
    #     "faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth",
    pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
        "faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth",
    checkpoint_path="./mmengine_workdir/human_detector_synthetic_cabin_ir/epoch_1.pth",
    data_root_path=f'/root/data/processed/synthetic_cabin_ir/{view_point}/',
    device='cuda:0',
    working_directory=f'./mmengine_workdir/human_detector_synthetic_cabin_ir/{view_point}',
    log_level='INFO'
)
# https://github.com/open-mmlab/mmdetection/blob/main/configs/faster_rcnn/
detector.finetune()
# Out:
# 02/21 17:38:57 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1458593434
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1458593434
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/21 17:38:58 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[
#             103.53,
#             116.28,
#             123.675,
#         ],
#         std=[
#             1.0,
#             1.0,
#             1.0,
#         ],
#         bgr_to_rgb=False,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[
#                 8,
#             ],
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=1,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)),
#     _scope_='mmdet')
# dataset_type = 'CocoDataset'
# data_root = '/root/data/processed/synthetic_cabin_ir/Rear_Mirror'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='RandomChoiceResize',
#         scales=[
#             (
#                 1333,
#                 640,
#             ),
#             (
#                 1333,
#                 672,
#             ),
#             (
#                 1333,
#                 704,
#             ),
#             (
#                 1333,
#                 736,
#             ),
#             (
#                 1333,
#                 768,
#             ),
#             (
#                 1333,
#                 800,
#             ),
#         ],
#         keep_ratio=True,
#         _scope_='mmdet'),
#     dict(type='RandomFlip', prob=0.5, _scope_='mmdet'),
#     dict(type='PackDetInputs', _scope_='mmdet'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='PackDetInputs',
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         _scope_='mmdet'),
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmdet'),
#     batch_sampler=dict(type='AspectRatioBatchSampler', _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/Rear_Mirror',
#         ann_file='annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='RandomChoiceResize',
#                 scales=[
#                     (
#                         1333,
#                         640,
#                     ),
#                     (
#                         1333,
#                         672,
#                     ),
#                     (
#                         1333,
#                         704,
#                     ),
#                     (
#                         1333,
#                         736,
#                     ),
#                     (
#                         1333,
#                         768,
#                     ),
#                     (
#                         1333,
#                         800,
#                     ),
#                 ],
#                 keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs'),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/Rear_Mirror',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/Rear_Mirror',
#         ann_file='annotations/person_keypoints_test.json',
#         data_prefix=dict(img='images/test/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_ir/Rear_Mirror/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_ir/Rear_Mirror/annotations/person_keypoints_test.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# train_cfg = dict(
#     type='EpochBasedTrainLoop', max_epochs=1, val_interval=1, _scope_='mmdet')
# val_cfg = dict(type='ValLoop', _scope_='mmdet')
# test_cfg = dict(type='TestLoop', _scope_='mmdet')
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.001,
#         by_epoch=False,
#         begin=0,
#         end=500,
#         _scope_='mmdet'),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[
#             8,
#             11,
#         ],
#         gamma=0.1,
#         _scope_='mmdet'),
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     _scope_='mmdet')
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmdet'),
#     logger=dict(type='LoggerHook', interval=500, _scope_='mmdet'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmdet'),
#     checkpoint=dict(type='CheckpointHook', interval=1, _scope_='mmdet'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmdet'),
#     visualization=dict(type='DetVisualizationHook', _scope_='mmdet'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmdet'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmdet')
# log_processor = dict(
#     type='LogProcessor', window_size=50, by_epoch=True, _scope_='mmdet')
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth'
# resume = False
# metainfo = dict(
#     classes=('person', ), palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#     ])
# work_dir = './mmengine_workdir/human_detector_synthetic_cabin_ir/Rear_Mirror'
# wandb: Currently logged in as: gentlerainsky. Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112014477516318, max=1.0…
# wandb version 0.16.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.2
# Run data is saved locally in <code>/workspace/mmengine_workdir/human_detector_synthetic_cabin_ir/Rear_Mirror/20240221_173857/vis_data/wandb/run-20240221_173900-79d67aoo</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/79d67aoo' target="_blank">lambent-moon-120</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/79d67aoo' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/79d67aoo</a>
# 02/21 17:39:12 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/21 17:39:12 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=1.23s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# 02/21 17:39:15 - mmengine - INFO - load model from: open-mmlab://detectron2/resnet50_caffe
# 02/21 17:39:15 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://detectron2/resnet50_caffe
# 02/21 17:39:15 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: conv1.bias
#
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 02/21 17:39:15 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 02/21 17:39:15 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/21 17:39:15 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/21 17:39:15 - mmengine - INFO - Checkpoints will be saved to /workspace/mmengine_workdir/human_detector_synthetic_cabin_ir/Rear_Mirror.
# 02/21 17:43:44 - mmengine - INFO - Epoch(train) [1][  500/18750]  lr: 2.0000e-02  eta: 2:43:22  time: 0.5396  data_time: 0.0027  memory: 2815  loss: 0.0503  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0028  loss_cls: 0.0175  acc: 99.7070  loss_bbox: 0.0292
# 02/21 17:48:12 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 17:48:12 - mmengine - INFO - Epoch(train) [1][ 1000/18750]  lr: 2.0000e-02  eta: 2:38:35  time: 0.5203  data_time: 0.0029  memory: 2814  loss: 0.0429  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0028  loss_cls: 0.0139  acc: 99.0234  loss_bbox: 0.0257
# 02/21 17:52:41 - mmengine - INFO - Epoch(train) [1][ 1500/18750]  lr: 2.0000e-02  eta: 2:34:24  time: 0.5340  data_time: 0.0028  memory: 2814  loss: 0.0400  loss_rpn_cls: 0.0007  loss_rpn_bbox: 0.0022  loss_cls: 0.0130  acc: 99.8047  loss_bbox: 0.0241
# 02/21 17:57:06 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 17:57:06 - mmengine - INFO - Epoch(train) [1][ 2000/18750]  lr: 2.0000e-02  eta: 2:29:26  time: 0.5221  data_time: 0.0028  memory: 2814  loss: 0.0287  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0020  loss_cls: 0.0089  acc: 99.3164  loss_bbox: 0.0175
# 02/21 18:01:27 - mmengine - INFO - Epoch(train) [1][ 2500/18750]  lr: 2.0000e-02  eta: 2:24:12  time: 0.5220  data_time: 0.0028  memory: 2815  loss: 0.0305  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.
loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0015  loss_cls: 0.0065  acc: 99.6094  loss_bbox: 0.0121
# 02/21 19:25:15 - mmengine - INFO - Epoch(train) [1][12500/18750]  lr: 2.0000e-02  eta: 0:52:59  time: 0.4953  data_time: 0.0028  memory: 2814  loss: 0.0200  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0014  loss_cls: 0.0067  acc: 99.8047  loss_bbox: 0.0115
# 02/21 19:29:23 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 19:29:23 - mmengine - INFO - Epoch(train) [1][13000/18750]  lr: 2.0000e-02  eta: 0:48:42  time: 0.4977  data_time: 0.0028  memory: 2814  loss: 0.0230  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0015  loss_cls: 0.0073  acc: 99.9023  loss_bbox: 0.0139
# 02/21 19:33:32 - mmengine - INFO - Epoch(train) [1][13500/18750]  lr: 2.0000e-02  eta: 0:44:26  time: 0.4929  data_time: 0.0027  memory: 2814  loss: 0.0200  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0016  loss_cls: 0.0065  acc: 99.5117  loss_bbox: 0.0116
# 02/21 19:37:26 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 19:37:26 - mmengine - INFO - Epoch(train) [1][14000/18750]  lr: 2.0000e-02  eta: 0:40:05  time: 0.4643  data_time: 0.0028  memory: 2814  loss: 0.0247  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0017  loss_cls: 0.0075  acc: 100.0000  loss_bbox: 0.0152
# 02/21 19:41:14 - mmengine - INFO - Epoch(train) [1][14500/18750]  lr: 2.0000e-02  eta: 0:35:45  time: 0.4741  data_time: 0.0027  memory: 2814  loss: 0.0234  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0013  loss_cls: 0.0078  acc: 99.9023  loss_bbox: 0.0141
# 02/21 19:45:03 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 19:45:03 - mmengine - INFO - Epoch(train) [1][15000/18750]  lr: 2.0000e-02  eta: 0:31:26  time: 0.4620  data_time: 0.0027  memory: 2814  loss: 0.0246  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0015  loss_cls: 0.0084  acc: 99.7070  loss_bbox: 0.0143
# 02/21 19:48:45 - mmengine - INFO - Epoch(train) [1][15500/18750]  lr: 2.0000e-02  eta: 0:27:09  time: 0.4604  data_time: 0.0029  memory: 2814  loss: 0.0258  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0016  loss_cls: 0.0084  acc: 99.6094  loss_bbox: 0.0155
# 02/21 19:52:35 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 19:52:35 - mmengine - INFO - Epoch(train) [1][16000/18750]  lr: 2.0000e-02  eta: 0:22:54  time: 0.4585  data_time: 0.0027  memory: 2814  loss: 0.0226  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0017  loss_cls: 0.0071  acc: 99.6094  loss_bbox: 0.0133
# 02/21 19:56:24 - mmengine - INFO - Epoch(train) [1][16500/18750]  lr: 2.0000e-02  eta: 0:18:42  time: 0.4492  data_time: 0.0027  memory: 2814  loss: 0.0173  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0016  loss_cls: 0.0051  acc: 99.8047  loss_bbox: 0.0103
# 02/21 20:00:14 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 20:00:14 - mmengine - INFO - Epoch(train) [1][17000/18750]  lr: 2.0000e-02  eta: 0:14:30  time: 0.4528  data_time: 0.0027  memory: 2814  loss: 0.0171  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0011  loss_cls: 0.0051  acc: 99.7070  loss_bbox: 0.0107
# 02/21 20:02:55 - mmengine - INFO - Epoch(train) [1][17500/18750]  lr: 2.0000e-02  eta: 0:10:15  time: 0.2397  data_time: 0.0024  memory: 2814  loss: 0.0205  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0014  loss_cls: 0.0059  acc: 99.9023  loss_bbox: 0.0129
# 02/21 20:04:57 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 20:04:57 - mmengine - INFO - Epoch(train) [1][18000/18750]  lr: 2.0000e-02  eta: 0:06:04  time: 0.2413  data_time: 0.0024  memory: 2814  loss: 0.0173  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0012  loss_cls: 0.0055  acc: 99.7070  loss_bbox: 0.0105
# 02/21 20:06:58 - mmengine - INFO - Epoch(train) [1][18500/18750]  lr: 2.0000e-02  eta: 0:01:59  time: 0.2407  data_time: 0.0024  memory: 2814  loss: 0.0188  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0013  loss_cls: 0.0061  acc: 99.7070  loss_bbox: 0.0111
# 02/21 20:07:59 - mmengine - INFO - Exp name: faster_rcnn_20240221_173857
# 02/21 20:07:59 - mmengine - INFO - Saving checkpoint at 1 epochs
# 02/21 20:08:29 - mmengine - INFO - Epoch(val) [1][ 500/6250]    eta: 0:05:38  time: 0.0595  data_time: 0.0013  memory: 2814
# 02/21 20:08:58 - mmengine - INFO - Epoch(val) [1][1000/6250]    eta: 0:05:06  time: 0.0579  data_time: 0.0012  memory: 607
# 02/21 20:09:27 - mmengine - INFO - Epoch(val) [1][1500/6250]    eta: 0:04:37  time: 0.0578  data_time: 0.0012  memory: 607
# 02/21 20:09:56 - mmengine - INFO - Epoch(val) [1][2000/6250]    eta: 0:04:08  time: 0.0585  data_time: 0.0013  memory: 607
# 02/21 20:10:25 - mmengine - INFO - Epoch(val) [1][2500/6250]    eta: 0:03:38  time: 0.0585  data_time: 0.0013  memory: 607
# 02/21 20:10:55 - mmengine - INFO - Epoch(val) [1][3000/6250]    eta: 0:03:09  time: 0.0569  data_time: 0.0012  memory: 607
# 02/21 20:11:24 - mmengine - INFO - Epoch(val) [1][3500/6250]    eta: 0:02:40  time: 0.0582  data_time: 0.0013  memory: 607
# 02/21 20:11:53 - mmengine - INFO - Epoch(val) [1][4000/6250]    eta: 0:02:11  time: 0.0587  data_time: 0.0013  memory: 607
# 02/21 20:12:22 - mmengine - INFO - Epoch(val) [1][4500/6250]    eta: 0:01:42  time: 0.0588  data_time: 0.0012  memory: 607
# 02/21 20:12:51 - mmengine - INFO - Epoch(val) [1][5000/6250]    eta: 0:01:12  time: 0.0586  data_time: 0.0013  memory: 607
# 02/21 20:13:20 - mmengine - INFO - Epoch(val) [1][5500/6250]    eta: 0:00:43  time: 0.0577  data_time: 0.0013  memory: 607
# 02/21 20:13:50 - mmengine - INFO - Epoch(val) [1][6000/6250]    eta: 0:00:14  time: 0.0582  data_time: 0.0020  memory: 607
# 02/21 20:14:05 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.07s).
# Accumulating evaluation results...
# DONE (t=0.14s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.877
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.877
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.911
# 02/21 20:14:06 - mmengine - INFO - bbox_mAP_copypaste: 0.877 1.000 0.990 -1.000 -1.000 0.877
# 02/21 20:14:06 - mmengine - INFO - Epoch(val) [1][6250/6250]    coco/bbox_mAP: 0.8770  coco/bbox_mAP_50: 1.0000  coco/bbox_mAP_75: 0.9900  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: -1.0000  coco/bbox_mAP_l: 0.8770  data_time: 0.0014  time: 0.0583
# wandb: WARNING No program path found when generating artifact job source for a non-colab notebook run. See https://docs.wandb.ai/guides/launch/create-job
# wandb: WARNING Source type is set to 'artifact' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.694 MB of 0.694 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▇▃▇▅▅▇▇▅▆▁▃▇▆▇▇▇▅▇▇▇▇▆█▆▇▇▅█▇▇▆▆▇▇▇▇▇</td></tr><tr><td>coco/bbox_mAP</td><td>▁</td></tr><tr><td>coco/bbox_mAP_50</td><td>▁</td></tr><tr><td>coco/bbox_mAP_75</td><td>▁</td></tr><tr><td>coco/bbox_mAP_l</td><td>▁</td></tr><tr><td>coco/bbox_mAP_m</td><td>▁</td></tr><tr><td>coco/bbox_mAP_s</td><td>▁</td></tr><tr><td>data_time</td><td>▆▇▆▆▆█▇▆▆▆▆▆▆▆▆▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▇▆▆▆▅▅▅▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>iter</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▆▃▄▃▃▄▃▆▂▃▃▂▂▁▃▂▂▂▂▂▂▂▂▂▂▃▂▃▃▂▁▁▂▁▁</td></tr><tr><td>loss_bbox</td><td>█▇▆▄▄▄▃▄▃▆▂▃▃▂▂▁▂▂▂▂▂▂▁▂▁▂▂▃▂▂▃▂▁▁▂▁▁</td></tr><tr><td>loss_cls</td><td>█▆▅▃▃▃▃▄▃▅▃▄▃▂▂▁▃▂▂▃▂▂▂▂▂▂▂▂▃▃▃▂▁▁▁▁▂</td></tr><tr><td>loss_rpn_bbox</td><td>██▅▅▄▅▃▄▄▄▃▄▂▃▃▃▃▂▂▃▃▁▃▃▂▃▃▄▂▃▃▄▃▁▂▂▂</td></tr><tr><td>loss_rpn_cls</td><td>█▅▆▃▂▅▂▃▄▄▂▃▂▂▄▂▄▂▃▃▂▁▃▂▂▂▂▂▂▄▃▅▃▂▂▁▂</td></tr><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>memory</td><td>█▁▁▁█▁█▁▁▁▁█▁▁█▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time</td><td>████████▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▄▄▄▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>99.70703</td></tr><tr><td>coco/bbox_mAP</td><td>0.877</td></tr><tr><td>coco/bbox_mAP_50</td><td>1.0</td></tr><tr><td>coco/bbox_mAP_75</td><td>0.99</td></tr><tr><td>coco/bbox_mAP_l</td><td>0.877</td></tr><tr><td>coco/bbox_mAP_m</td><td>-1.0</td></tr><tr><td>coco/bbox_mAP_s</td><td>-1.0</td></tr><tr><td>data_time</td><td>0.00135</td></tr><tr><td>epoch</td><td>1</td></tr><tr><td>iter</td><td>18500</td></tr><tr><td>loss</td><td>0.01878</td></tr><tr><td>loss_bbox</td><td>0.01115</td></tr><tr><td>loss_cls</td><td>0.0061</td></tr><tr><td>loss_rpn_bbox</td><td>0.00126</td></tr><tr><td>loss_rpn_cls</td><td>0.00028</td></tr><tr><td>lr</td><td>0.02</td></tr><tr><td>memory</td><td>2814</td></tr><tr><td>time</td><td>0.05833</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lambent-moon-120</strong> at: <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/79d67aoo' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/79d67aoo</a><br/>Synced 6 W&B file(s), 0 media file(s), 101 artifact file(s) and 0 other file(s)
# Find logs at: <code>./mmengine_workdir/human_detector_synthetic_cabin_ir/Rear_Mirror/20240221_173857/vis_data/wandb/run-20240221_173900-79d67aoo/logs</code>
# new_checkpoint_path /workspace/mmengine_workdir/human_detector_synthetic_cabin_ir/Rear_Mirror/epoch_1.pth

# %%
detector.test()
# Out:
# loading annotations into memory...
# Done (t=0.16s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# 02/21 20:14:40 - mmengine - INFO - Epoch(test) [ 500/6251]    eta: 0:05:39  time: 0.0564  data_time: 0.0012  memory: 607
# 02/21 20:15:09 - mmengine - INFO - Epoch(test) [1000/6251]    eta: 0:05:06  time: 0.0564  data_time: 0.0013  memory: 607
# 02/21 20:15:38 - mmengine - INFO - Epoch(test) [1500/6251]    eta: 0:04:37  time: 0.0595  data_time: 0.0012  memory: 607
# 02/21 20:16:08 - mmengine - INFO - Epoch(test) [2000/6251]    eta: 0:04:08  time: 0.0601  data_time: 0.0013  memory: 607
# 02/21 20:16:37 - mmengine - INFO - Epoch(test) [2500/6251]    eta: 0:03:39  time: 0.0573  data_time: 0.0013  memory: 607
# 02/21 20:17:06 - mmengine - INFO - Epoch(test) [3000/6251]    eta: 0:03:10  time: 0.0590  data_time: 0.0013  memory: 607
# 02/21 20:17:35 - mmengine - INFO - Epoch(test) [3500/6251]    eta: 0:02:40  time: 0.0589  data_time: 0.0012  memory: 607
# 02/21 20:18:04 - mmengine - INFO - Epoch(test) [4000/6251]    eta: 0:02:11  time: 0.0571  data_time: 0.0013  memory: 607
# 02/21 20:18:34 - mmengine - INFO - Epoch(test) [4500/6251]    eta: 0:01:42  time: 0.0585  data_time: 0.0013  memory: 607
# 02/21 20:19:03 - mmengine - INFO - Epoch(test) [5000/6251]    eta: 0:01:13  time: 0.0577  data_time: 0.0013  memory: 607
# 02/21 20:19:33 - mmengine - INFO - Epoch(test) [5500/6251]    eta: 0:00:43  time: 0.0605  data_time: 0.0013  memory: 607
# 02/21 20:20:02 - mmengine - INFO - Epoch(test) [6000/6251]    eta: 0:00:14  time: 0.0597  data_time: 0.0013  memory: 607
# 02/21 20:20:17 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.93s).
# Accumulating evaluation results...
# DONE (t=0.34s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.879
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.879
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.913
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.913
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.913
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.913
# 02/21 20:20:18 - mmengine - INFO - bbox_mAP_copypaste: 0.879 0.990 0.989 -1.000 -1.000 0.879
# 02/21 20:20:18 - mmengine - INFO - Epoch(test) [6251/6251]    coco/bbox_mAP: 0.8790  coco/bbox_mAP_50: 0.9900  coco/bbox_mAP_75: 0.9890  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: -1.0000  coco/bbox_mAP_l: 0.8790  data_time: 0.0013  time: 0.0585
