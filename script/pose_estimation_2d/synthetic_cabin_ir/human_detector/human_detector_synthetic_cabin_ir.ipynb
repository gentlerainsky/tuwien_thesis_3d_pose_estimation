# %%
from src.modules.human_detector.human_detector import HumanDetector
from src.modules.human_detector.main import detect_person
import pathlib

# %%
detector = HumanDetector(
    config_path='./src/modules/human_detector/config/faster_rcnn.py',
    # pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
    #     "faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth",
    pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
        "faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth",
    checkpoint_path="./mmengine_workdir/human_detector_synthetic_cabin_ir/epoch_1.pth",
    data_root_path='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/',
    device='cuda:0',
    working_directory='./mmengine_workdir/human_detector_synthetic_cabin_ir',
    log_level='INFO'
)
# https://github.com/open-mmlab/mmdetection/blob/main/configs/faster_rcnn/
detector.finetune()
# Out:
# 11/19 15:51:19 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1722906000
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1722906000
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/19 15:51:20 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[
#             103.53,
#             116.28,
#             123.675,
#         ],
#         std=[
#             1.0,
#             1.0,
#             1.0,
#         ],
#         bgr_to_rgb=False,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet50_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[
#                 8,
#             ],
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=1,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)),
#     _scope_='mmdet')
# dataset_type = 'CocoDataset'
# data_root = '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='RandomChoiceResize',
#         scales=[
#             (
#                 1333,
#                 640,
#             ),
#             (
#                 1333,
#                 672,
#             ),
#             (
#                 1333,
#                 704,
#             ),
#             (
#                 1333,
#                 736,
#             ),
#             (
#                 1333,
#                 768,
#             ),
#             (
#                 1333,
#                 800,
#             ),
#         ],
#         keep_ratio=True,
#         _scope_='mmdet'),
#     dict(type='RandomFlip', prob=0.5, _scope_='mmdet'),
#     dict(type='PackDetInputs', _scope_='mmdet'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None, _scope_='mmdet'),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True, _scope_='mmdet'),
#     dict(type='LoadAnnotations', with_bbox=True, _scope_='mmdet'),
#     dict(
#         type='PackDetInputs',
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         _scope_='mmdet'),
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmdet'),
#     batch_sampler=dict(type='AspectRatioBatchSampler', _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver',
#         ann_file='annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='RandomChoiceResize',
#                 scales=[
#                     (
#                         1333,
#                         640,
#                     ),
#                     (
#                         1333,
#                         672,
#                     ),
#                     (
#                         1333,
#                         704,
#                     ),
#                     (
#                         1333,
#                         736,
#                     ),
#                     (
#                         1333,
#                         768,
#                     ),
#                     (
#                         1333,
#                         800,
#                     ),
#                 ],
#                 keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs'),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver',
#         ann_file='annotations/person_keypoints_test.json',
#         data_prefix=dict(img='images/test/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('person', ), palette=[
#             (
#                 220,
#                 20,
#                 60,
#             ),
#         ]),
#         _scope_='mmdet'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/annotations/person_keypoints_test.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# train_cfg = dict(
#     type='EpochBasedTrainLoop', max_epochs=1, val_interval=1, _scope_='mmdet')
# val_cfg = dict(type='ValLoop', _scope_='mmdet')
# test_cfg = dict(type='TestLoop', _scope_='mmdet')
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         start_factor=0.001,
#         by_epoch=False,
#         begin=0,
#         end=500,
#         _scope_='mmdet'),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[
#             8,
#             11,
#         ],
#         gamma=0.1,
#         _scope_='mmdet'),
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001),
#     _scope_='mmdet')
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmdet'),
#     logger=dict(type='LoggerHook', interval=500, _scope_='mmdet'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmdet'),
#     checkpoint=dict(type='CheckpointHook', interval=1, _scope_='mmdet'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmdet'),
#     visualization=dict(type='DetVisualizationHook', _scope_='mmdet'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmdet'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmdet')
# log_processor = dict(
#     type='LogProcessor', window_size=50, by_epoch=True, _scope_='mmdet')
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth'
# resume = False
# metainfo = dict(
#     classes=('person', ), palette=[
#         (
#             220,
#             20,
#             60,
#         ),
#     ])
# work_dir = './mmengine_workdir/human_detector_synthetic_cabin_ir'
# wandb: Currently logged in as: gentlerainsky. Use `wandb login --relogin` to force relogin
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/workspace/mmengine_workdir/human_detector_synthetic_cabin_ir/20231119_155119/vis_data/wandb/run-20231119_155121-cvflo686</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/cvflo686' target="_blank">major-dragon-79</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/cvflo686' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/cvflo686</a>
# 11/19 15:51:28 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/19 15:51:28 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.59s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# 11/19 15:51:30 - mmengine - INFO - load model from: open-mmlab://detectron2/resnet50_caffe
# 11/19 15:51:30 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://detectron2/resnet50_caffe
# 11/19 15:51:30 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: conv1.bias
#
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 11/19 15:51:30 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco-person/faster_rcnn_r50_fpn_1x_coco-person_20201216_175929-d022e227.pth
# 11/19 15:51:30 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/19 15:51:30 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/19 15:51:30 - mmengine - INFO - Checkpoints will be saved to /workspace/mmengine_workdir/human_detector_synthetic_cabin_ir.
# 11/19 15:53:39 - mmengine - INFO - Epoch(train) [1][  500/18750]  lr: 2.0000e-02  eta: 1:18:20  time: 0.2546  data_time: 0.0027  memory: 2816  loss: 0.0257  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0036  loss_cls: 0.0069  acc: 99.9023  loss_bbox: 0.0146
# 11/19 15:55:52 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 15:55:52 - mmengine - INFO - Epoch(train) [1][ 1000/18750]  lr: 2.0000e-02  eta: 1:17:30  time: 0.2531  data_time: 0.0027  memory: 2816  loss: 0.0195  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0032  loss_cls: 0.0043  acc: 99.8047  loss_bbox: 0.0116
# 11/19 15:58:02 - mmengine - INFO - Epoch(train) [1][ 1500/18750]  lr: 2.0000e-02  eta: 1:15:09  time: 0.2485  data_time: 0.0027  memory: 2816  loss: 0.0170  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0028  loss_cls: 0.0042  acc: 99.9023  loss_bbox: 0.0094
# 11/19 16:00:14 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:00:14 - mmengine - INFO - Epoch(train) [1][ 2000/18750]  lr: 2.0000e-02  eta: 1:13:07  time: 0.2839  data_time: 0.0030  memory: 2816  loss: 0.0167  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0028  loss_cls: 0.0037  acc: 99.8047  loss_bbox: 0.0097
# 11/19 16:02:26 - mmengine - INFO - Epoch(train) [1][ 2500/18750]  lr: 2.0000e-02  eta: 1:11:03  time: 0.2601  data_time: 0.0027  memory: 2816  loss: 0.0167  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0026  loss_cls: 0.0041  acc: 99.7070  loss_bbox: 0.0096
# 11/19 16:04:40 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:04:40 - mmengine - INFO - Epoch(train) [1][ 3000/18750]  lr: 2.0000e-02  eta: 1:09:07  time: 0.2654  data_time: 0.0028  memory: 2816  loss: 0.0144  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0021  loss_cls: 0.0041  acc: 99.7070  loss_bbox: 0.0080
# 11/19 16:06:55 - mmengine - INFO - Epoch(train) [1][ 3500/18750]  lr: 2.0000e-02  eta: 1:07:07  time: 0.2744  data_time: 0.0029  memory: 2816  loss: 0.0128  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0023  loss_cls: 0.0030  acc: 100.0000  loss_bbox: 0.0071
# 11/19 16:09:08 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:09:08 - mmengine - INFO - Epoch(train) [1][ 4000/18750]  lr: 2.0000e-02  eta: 1:05:00  time: 0.2712  data_time: 0.0028  memory: 2816  loss: 0.0117  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0021  loss_cls: 0.0029  acc: 99.9023  loss_bbox: 0.0064
# 11/19 16:11:18 - mmengine - INFO - Epoch(train) [1][ 4500/18750]  lr: 2.0000e-02  eta: 1:02:39  time: 0.2616  data_time: 0.0030  memory: 2816  loss: 0.0122  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0021  loss_cls: 0.0030  acc: 99.8047  loss_bbox: 0.0069
# 11/19 16:13:27 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:13:27 - mmengine - INFO - Epoch(train) [1][ 5000/18750]  lr: 2.0000e-02  eta: 1:00:21  time: 0.2627  data_time: 0.0028  memory: 2816  loss: 0.0117  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0022  loss_cls: 0.0030  acc: 99.9023  loss_bbox: 0.0063
# 11/19 16:15:36 - mmengine - INFO - Epoch(train) [1][ 5500/18750]  lr: 2.0000e-02  eta: 0:58:02  time: 0.2559  data_time: 0.0027  memory: 2816  loss: 0.0109  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0021  loss_cls: 0.0025  acc: 100.0000  loss_bbox: 0.0060
# 11/19 16:17:43 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:17:43 - mmengine - INFO - Epoch(train) [1][ 6000/18750]  lr: 2.0000e-02  eta: 0:55:42  time: 0.2603  data_time: 0.0028  memory: 2816  loss: 0.0099  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0020  loss_cls: 0.0021  acc: 99.8047  loss_bbox: 0.0055
# 11/19 16:19:52 - mmengine - INFO - Epoch(train) [1][ 6500/18750]  lr: 2.0000e-02  eta: 0:53:27  time: 0.2566  data_time: 0.0030  memory: 2816  loss: 0.0118  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0020  loss_cls: 0.0029  acc: 100.0000  loss_bbox: 0.0067
# 11/19 16:22:00 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:22:00 - mmengine - INFO - Epoch(train) [1][ 7000/18750]  lr: 2.0000e-02  eta: 0:51:11  time: 0.2653  data_time: 0.0028  memory: 2816  loss: 0.0109  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0020  loss_cls: 0.0026  acc: 99.9023  loss_bbox: 0.0060
# 11/19 16:24:11 - mmengine - INFO - Epoch(train) [1][ 7500/18750]  lr: 2.0000e-02  eta: 0:49:00  time: 0.2671  data_time: 0.0031  memory: 2816  loss: 0.0114  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0021  loss_cls: 0.0026  acc: 100.0000  loss_bbox: 0.0065
# 11/19 16:26:20 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:26:20 - mmengine - INFO - Epoch(train) [1][ 8000/18750]  lr: 2.0000e-02  eta: 0:46:47  time: 0.2600  data_time: 0.0027  memory: 2816  loss: 0.0098  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0019  loss_cls: 0.0026  acc: 99.8047  loss_bbox: 0.0051
# 11/19 16:28:29 - mmengine - INFO - Epoch(train) [1][ 8500/18750]  lr: 2.0000e-02  eta: 0:44:35  time: 0.2619  data_time: 0.0027  memory: 2816  loss: 0.0112  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0019  loss_cls: 0.0028  acc: 100.0000  loss_bbox: 0.0062
# 11/19 16:30:39 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:30:39 - mmengine - INFO - Epoch(train) [1][ 9000/18750]  lr: 2.0000e-02  eta: 0:42:24  time: 0.2607  data_time: 0.0028  memory: 2816  loss: 0.0096  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0023  acc: 99.8047  loss_bbox: 0.0053
# 11/19 16:32:48 - mmengine - INFO - Epoch(train) [1][ 9500/18750]  lr: 2.0000e-02  eta: 0:40:12  time: 0.2584  data_time: 0.0029  memory: 2816  loss: 0.0102  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0019  loss_cls: 0.0024  acc: 100.0000  loss_bbox: 0.0056
# 11/19 16:35:00 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:35:00 - mmengine - INFO - Epoch(train) [1][10000/18750]  lr: 2.0000e-02  eta: 0:38:03  time: 0.2705  data_time: 0.0030  memory: 2815  loss: 0.0097  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0022  acc: 100.0000  loss_bbox: 0.0055
# 11/19 16:37:10 - mmengine - INFO - Epoch(train) [1][10500/18750]  lr: 2.0000e-02  eta: 0:35:52  time: 0.2804  data_time: 0.0028  memory: 2816  loss: 0.0098  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0024  acc: 99.9023  loss_bbox: 0.0054
# 11/19 16:39:24 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:39:24 - mmengine - INFO - Epoch(train) [1][11000/18750]  lr: 2.0000e-02  eta: 0:33:44  time: 0.2648  data_time: 0.0028  memory: 2816  loss: 0.0091  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0019  loss_cls: 0.0024  acc: 100.0000  loss_bbox: 0.0046
# 11/19 16:41:34 - mmengine - INFO - Epoch(train) [1][11500/18750]  lr: 2.0000e-02  eta: 0:31:33  time: 0.2623  data_time: 0.0028  memory: 2816  loss: 0.0086  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0017  loss_cls: 0.0019  acc: 100.0000  loss_bbox: 0.0050
# 11/19 16:43:46 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:43:46 - mmengine - INFO - Epoch(train) [1][12000/18750]  lr: 2.0000e-02  eta: 0:29:23  time: 0.2623  data_time: 0.0028  memory: 2816  loss: 0.0090  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0019  acc: 100.0000  loss_bbox: 0.0051
# 11/19 16:45:56 - mmengine - INFO - Epoch(train) [1][12500/18750]  lr: 2.0000e-02  eta: 0:27:13  time: 0.2610  data_time: 0.0026  memory: 2816  loss: 0.0088  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0020  acc: 99.8047  loss_bbox: 0.0048
# 11/19 16:48:08 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:48:08 - mmengine - INFO - Epoch(train) [1][13000/18750]  lr: 2.0000e-02  eta: 0:25:02  time: 0.2680  data_time: 0.0029  memory: 2816  loss: 0.0086  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0018  loss_cls: 0.0020  acc: 100.0000  loss_bbox: 0.0047
# 11/19 16:50:20 - mmengine - INFO - Epoch(train) [1][13500/18750]  lr: 2.0000e-02  eta: 0:22:52  time: 0.2594  data_time: 0.0028  memory: 2816  loss: 0.0092  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0016  loss_cls: 0.0024  acc: 100.0000  loss_bbox: 0.0049
# 11/19 16:52:33 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:52:33 - mmengine - INFO - Epoch(train) [1][14000/18750]  lr: 2.0000e-02  eta: 0:20:42  time: 0.2696  data_time: 0.0028  memory: 2816  loss: 0.0122  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0019  loss_cls: 0.0034  acc: 99.8047  loss_bbox: 0.0067
# 11/19 16:54:45 - mmengine - INFO - Epoch(train) [1][14500/18750]  lr: 2.0000e-02  eta: 0:18:32  time: 0.2656  data_time: 0.0027  memory: 2816  loss: 0.0096  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0021  loss_cls: 0.0023  acc: 99.5117  loss_bbox: 0.0051
# 11/19 16:56:59 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 16:56:59 - mmengine - INFO - Epoch(train) [1][15000/18750]  lr: 2.0000e-02  eta: 0:16:22  time: 0.2647  data_time: 0.0029  memory: 2816  loss: 0.0088  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0016  loss_cls: 0.0023  acc: 99.8047  loss_bbox: 0.0048
# 11/19 16:59:15 - mmengine - INFO - Epoch(train) [1][15500/18750]  lr: 2.0000e-02  eta: 0:14:12  time: 0.2789  data_time: 0.0031  memory: 2816  loss: 0.0103  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0030  acc: 99.9023  loss_bbox: 0.0053
# 11/19 17:01:27 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 17:01:27 - mmengine - INFO - Epoch(train) [1][16000/18750]  lr: 2.0000e-02  eta: 0:12:01  time: 0.2604  data_time: 0.0028  memory: 2816  loss: 0.0082  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0017  acc: 99.9023  loss_bbox: 0.0046
# 11/19 17:03:42 - mmengine - INFO - Epoch(train) [1][16500/18750]  lr: 2.0000e-02  eta: 0:09:50  time: 0.2840  data_time: 0.0030  memory: 2816  loss: 0.0090  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0020  acc: 99.9023  loss_bbox: 0.0051
# 11/19 17:05:52 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 17:05:52 - mmengine - INFO - Epoch(train) [1][17000/18750]  lr: 2.0000e-02  eta: 0:07:39  time: 0.2570  data_time: 0.0027  memory: 2816  loss: 0.0100  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0023  acc: 99.9023  loss_bbox: 0.0056
# 11/19 17:08:01 - mmengine - INFO - Epoch(train) [1][17500/18750]  lr: 2.0000e-02  eta: 0:05:27  time: 0.2492  data_time: 0.0026  memory: 2816  loss: 0.0116  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0019  loss_cls: 0.0028  acc: 99.9023  loss_bbox: 0.0063
# 11/19 17:10:09 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 17:10:09 - mmengine - INFO - Epoch(train) [1][18000/18750]  lr: 2.0000e-02  eta: 0:03:16  time: 0.2534  data_time: 0.0026  memory: 2816  loss: 0.0116  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0019  loss_cls: 0.0027  acc: 100.0000  loss_bbox: 0.0068
# 11/19 17:12:22 - mmengine - INFO - Epoch(train) [1][18500/18750]  lr: 2.0000e-02  eta: 0:01:05  time: 0.2546  data_time: 0.0029  memory: 2816  loss: 0.0099  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0020  loss_cls: 0.0024  acc: 99.9023  loss_bbox: 0.0053
# 11/19 17:13:27 - mmengine - INFO - Exp name: faster_rcnn_20231119_155119
# 11/19 17:13:27 - mmengine - INFO - Saving checkpoint at 1 epochs
# 11/19 17:13:58 - mmengine - INFO - Epoch(val) [1][ 500/6250]    eta: 0:05:47  time: 0.0607  data_time: 0.0015  memory: 2816
# 11/19 17:14:28 - mmengine - INFO - Epoch(val) [1][1000/6250]    eta: 0:05:14  time: 0.0599  data_time: 0.0016  memory: 609
# 11/19 17:14:59 - mmengine - INFO - Epoch(val) [1][1500/6250]    eta: 0:04:49  time: 0.0600  data_time: 0.0016  memory: 609
# 11/19 17:15:31 - mmengine - INFO - Epoch(val) [1][2000/6250]    eta: 0:04:21  time: 0.0628  data_time: 0.0015  memory: 609
# 11/19 17:16:01 - mmengine - INFO - Epoch(val) [1][2500/6250]    eta: 0:03:49  time: 0.0609  data_time: 0.0013  memory: 609
# 11/19 17:16:31 - mmengine - INFO - Epoch(val) [1][3000/6250]    eta: 0:03:18  time: 0.0632  data_time: 0.0017  memory: 609
# 11/19 17:17:01 - mmengine - INFO - Epoch(val) [1][3500/6250]    eta: 0:02:47  time: 0.0593  data_time: 0.0015  memory: 609
# 11/19 17:17:32 - mmengine - INFO - Epoch(val) [1][4000/6250]    eta: 0:02:17  time: 0.0614  data_time: 0.0019  memory: 609
# 11/19 17:18:03 - mmengine - INFO - Epoch(val) [1][4500/6250]    eta: 0:01:46  time: 0.0607  data_time: 0.0016  memory: 609
# 11/19 17:18:33 - mmengine - INFO - Epoch(val) [1][5000/6250]    eta: 0:01:16  time: 0.0591  data_time: 0.0015  memory: 609
# 11/19 17:19:03 - mmengine - INFO - Epoch(val) [1][5500/6250]    eta: 0:00:45  time: 0.0588  data_time: 0.0015  memory: 609
# 11/19 17:19:33 - mmengine - INFO - Epoch(val) [1][6000/6250]    eta: 0:00:15  time: 0.0590  data_time: 0.0015  memory: 609
# 11/19 17:19:48 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.11s).
# Accumulating evaluation results...
# DONE (t=0.14s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.961
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.978
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.978
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.978
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.978
# 11/19 17:19:50 - mmengine - INFO - bbox_mAP_copypaste: 0.961 1.000 1.000 -1.000 -1.000 0.961
# 11/19 17:19:50 - mmengine - INFO - Epoch(val) [1][6250/6250]    coco/bbox_mAP: 0.9610  coco/bbox_mAP_50: 1.0000  coco/bbox_mAP_75: 1.0000  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: -1.0000  coco/bbox_mAP_l: 0.9610  data_time: 0.0017  time: 0.0608
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'artifact' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.447 MB of 0.489 MB uploaded (0.431 MB deduped)\r'), FloatProgress(value=0.913704…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▇▅▇▅▄▄█▇▅▇█▅█▇█▅█▅██▇███▅██▅▁▅▇▇▇▇▇█▇</td></tr><tr><td>coco/bbox_mAP</td><td>▁</td></tr><tr><td>coco/bbox_mAP_50</td><td>▁</td></tr><tr><td>coco/bbox_mAP_75</td><td>▁</td></tr><tr><td>coco/bbox_mAP_l</td><td>▁</td></tr><tr><td>coco/bbox_mAP_m</td><td>▁</td></tr><tr><td>coco/bbox_mAP_s</td><td>▁</td></tr><tr><td>data_time</td><td>▆▆▆█▆▇▇▇█▇▆▆▇▆█▆▆▇▇█▆▇▆▆▅▇▇▆▆▇█▇█▆▅▆▇▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>iter</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▄▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▃▂▁▂▁▁▂▂▂▂</td></tr><tr><td>loss_bbox</td><td>█▆▄▅▅▃▃▂▃▂▂▂▂▂▂▁▂▂▂▂▂▁▁▁▁▁▁▂▁▁▂▁▁▂▂▃▂</td></tr><tr><td>loss_cls</td><td>█▄▄▄▄▄▃▃▃▃▂▂▃▂▂▂▃▂▂▂▂▂▁▁▁▁▂▃▂▂▃▁▁▂▃▂▂</td></tr><tr><td>loss_rpn_bbox</td><td>█▇▅▅▄▃▄▃▃▃▃▃▂▃▃▂▂▂▂▂▂▂▁▂▂▂▁▂▃▁▂▂▂▂▂▂▂</td></tr><tr><td>loss_rpn_cls</td><td>█▅▇▅▆▂▄▂▂▂▃▄▂▃▂▂▄▂▃▂▂▂▁▂▂▁▂▃▁▁▃▂▂▃█▂▃</td></tr><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>memory</td><td>███████████████████▁█████████████████</td></tr><tr><td>time</td><td>▇▇▇█▇▇██▇▇▇▇▇▇▇▇▇▇▇██▇▇▇▇▇▇█▇▇█▇█▇▇▇▇▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>99.90234</td></tr><tr><td>coco/bbox_mAP</td><td>0.961</td></tr><tr><td>coco/bbox_mAP_50</td><td>1.0</td></tr><tr><td>coco/bbox_mAP_75</td><td>1.0</td></tr><tr><td>coco/bbox_mAP_l</td><td>0.961</td></tr><tr><td>coco/bbox_mAP_m</td><td>-1.0</td></tr><tr><td>coco/bbox_mAP_s</td><td>-1.0</td></tr><tr><td>data_time</td><td>0.00172</td></tr><tr><td>epoch</td><td>1</td></tr><tr><td>iter</td><td>18500</td></tr><tr><td>loss</td><td>0.00994</td></tr><tr><td>loss_bbox</td><td>0.0053</td></tr><tr><td>loss_cls</td><td>0.0024</td></tr><tr><td>loss_rpn_bbox</td><td>0.002</td></tr><tr><td>loss_rpn_cls</td><td>0.00023</td></tr><tr><td>lr</td><td>0.02</td></tr><tr><td>memory</td><td>2816</td></tr><tr><td>time</td><td>0.06084</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">major-dragon-79</strong> at: <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/cvflo686' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/cvflo686</a><br/>Synced 6 W&B file(s), 0 media file(s), 61 artifact file(s) and 0 other file(s)
# Find logs at: <code>./mmengine_workdir/human_detector_synthetic_cabin_ir/20231119_155119/vis_data/wandb/run-20231119_155121-cvflo686/logs</code>
# new_checkpoint_path /workspace/mmengine_workdir/human_detector_synthetic_cabin_ir/epoch_1.pth

# %%
detector.test()
# Out:
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# 11/19 17:20:25 - mmengine - INFO - Epoch(test) [ 500/6251]    eta: 0:05:46  time: 0.0595  data_time: 0.0023  memory: 609
# 11/19 17:20:57 - mmengine - INFO - Epoch(test) [1000/6251]    eta: 0:05:25  time: 0.0681  data_time: 0.0029  memory: 609
# 11/19 17:21:27 - mmengine - INFO - Epoch(test) [1500/6251]    eta: 0:04:52  time: 0.0596  data_time: 0.0021  memory: 609
# 11/19 17:21:58 - mmengine - INFO - Epoch(test) [2000/6251]    eta: 0:04:21  time: 0.0626  data_time: 0.0016  memory: 609
# 11/19 17:22:29 - mmengine - INFO - Epoch(test) [2500/6251]    eta: 0:03:50  time: 0.0595  data_time: 0.0015  memory: 609
# 11/19 17:22:59 - mmengine - INFO - Epoch(test) [3000/6251]    eta: 0:03:19  time: 0.0606  data_time: 0.0017  memory: 609
# 11/19 17:23:29 - mmengine - INFO - Epoch(test) [3500/6251]    eta: 0:02:48  time: 0.0634  data_time: 0.0023  memory: 609
# 11/19 17:23:59 - mmengine - INFO - Epoch(test) [4000/6251]    eta: 0:02:17  time: 0.0585  data_time: 0.0015  memory: 609
# 11/19 17:24:29 - mmengine - INFO - Epoch(test) [4500/6251]    eta: 0:01:46  time: 0.0586  data_time: 0.0015  memory: 609
# 11/19 17:25:00 - mmengine - INFO - Epoch(test) [5000/6251]    eta: 0:01:16  time: 0.0602  data_time: 0.0015  memory: 609
# 11/19 17:25:30 - mmengine - INFO - Epoch(test) [5500/6251]    eta: 0:00:45  time: 0.0581  data_time: 0.0021  memory: 609
# 11/19 17:26:00 - mmengine - INFO - Epoch(test) [6000/6251]    eta: 0:00:15  time: 0.0580  data_time: 0.0015  memory: 609
# 11/19 17:26:16 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.96s).
# Accumulating evaluation results...
# DONE (t=0.38s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.968
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.990
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.968
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.985
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.985
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.985
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.985
# 11/19 17:26:17 - mmengine - INFO - bbox_mAP_copypaste: 0.968 0.990 0.990 -1.000 -1.000 0.968
# 11/19 17:26:18 - mmengine - INFO - Epoch(test) [6251/6251]    coco/bbox_mAP: 0.9680  coco/bbox_mAP_50: 0.9900  coco/bbox_mAP_75: 0.9900  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: -1.0000  coco/bbox_mAP_l: 0.9680  data_time: 0.0018  time: 0.0609
