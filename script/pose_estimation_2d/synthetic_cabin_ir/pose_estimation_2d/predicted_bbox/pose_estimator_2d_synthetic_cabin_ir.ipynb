# %%
from src.modules.pose_estimator_2d.pose_estimator_2d import PoseEstimator2D

pose_estimator_2d = PoseEstimator2D(
    config_path='src/modules/pose_estimator_2d/config/hrnet.py',
    # config_path='src/modules/pose_estimator_2d/config/test_config.py',
    # pretrained_path='https://download.openmmlab.com/mmpose/v1' \
    #     '/body_2d_keypoint/topdown_heatmap/coco' \
    #         '/td-hm_hrnet-w32_8xb64-210e_coco-256x192-81c58e40_20220909.pth',
    pretrained_path='https://download.openmmlab.com/mmpose/v1/'\
        'body_2d_keypoint/topdown_heatmap/coco/'\
            'td-hm_hrnet-w48_udp-8xb32-210e_coco-384x288-70d7ab01_20220913.pth',
    checkpoint_path="./mmengine_workdir/pose_estimator_2d_synthetic_cabin_ir/best_coco_AP_epoch_0.pth",
    data_root_path='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/',
    device='cuda:0',
    working_directory='./mmengine_workdir/pose_estimator_2d_synthetic_cabin_ir',
    log_level='INFO'
)

# pose_estimator_2d.load_pretrained()
# pose_estimator_2d_result = pose_estimator_2d.inference(img_path, bbox.detach().cpu().numpy(), bbox_format='xywh')
# keypoints_2D = pose_estimator_2d_result[0].pred_instances['keypoints'][0]
# print(keypoints_2D)
pose_estimator_2d.finetune()
# Out:
# 11/19 17:54:34 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 614280008
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 614280008
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/19 17:54:35 - mmengine - INFO - Config:
# default_scope = 'mmpose'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmpose'),
#     logger=dict(type='LoggerHook', interval=50, _scope_='mmpose'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmpose'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         interval=10,
#         save_best='coco/AP',
#         rule='greater',
#         _scope_='mmpose'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmpose'),
#     visualization=dict(
#         type='PoseVisualizationHook', enable=False, _scope_='mmpose'))
# custom_hooks = [
#     dict(type='SyncBuffersHook', _scope_='mmpose'),
# ]
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmpose'),
# ]
# visualizer = dict(
#     type='PoseLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmpose')
# log_processor = dict(
#     type='LogProcessor',
#     window_size=50,
#     by_epoch=True,
#     num_digits=6,
#     _scope_='mmpose')
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmpose/v1/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w48_udp-8xb32-210e_coco-384x288-70d7ab01_20220913.pth'
# resume = False
# backend_args = dict(backend='local')
# train_cfg = dict(by_epoch=True, max_epochs=10, val_interval=1)
# val_cfg = dict()
# test_cfg = dict()
# optim_wrapper = dict(optimizer=dict(type='Adam', lr=0.0005, _scope_='mmpose'))
# param_scheduler = [
#     dict(
#         type='LinearLR',
#         begin=0,
#         end=500,
#         start_factor=0.001,
#         by_epoch=False,
#         _scope_='mmpose'),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=210,
#         milestones=[
#             170,
#             200,
#         ],
#         gamma=0.1,
#         by_epoch=True,
#         _scope_='mmpose'),
# ]
# auto_scale_lr = dict(base_batch_size=512)
# codec = dict(
#     type='UDPHeatmap',
#     input_size=(
#         288,
#         384,
#     ),
#     heatmap_size=(
#         72,
#         96,
#     ),
#     sigma=3,
#     _scope_='mmpose')
# model = dict(
#     type='TopdownPoseEstimator',
#     data_preprocessor=dict(
#         type='PoseDataPreprocessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True),
#     backbone=dict(
#         type='HRNet',
#         in_channels=3,
#         extra=dict(
#             stage1=dict(
#                 num_modules=1,
#                 num_branches=1,
#                 block='BOTTLENECK',
#                 num_blocks=(4, ),
#                 num_channels=(64, )),
#             stage2=dict(
#                 num_modules=1,
#                 num_branches=2,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                 )),
#             stage3=dict(
#                 num_modules=4,
#                 num_branches=3,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                     192,
#                 )),
#             stage4=dict(
#                 num_modules=3,
#                 num_branches=4,
#                 block='BASIC',
#                 num_blocks=(
#                     4,
#                     4,
#                     4,
#                     4,
#                 ),
#                 num_channels=(
#                     48,
#                     96,
#                     192,
#                     384,
#                 ))),
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmpose/pretrain_models/hrnet_w48-8ef0771d.pth'
#         )),
#     head=dict(
#         type='HeatmapHead',
#         in_channels=48,
#         out_channels=17,
#         deconv_out_channels=None,
#         loss=dict(type='KeypointMSELoss', use_target_weight=True),
#         decoder=dict(
#             type='UDPHeatmap',
#             input_size=(
#                 288,
#                 384,
#             ),
#             heatmap_size=(
#                 72,
#                 96,
#             ),
#             sigma=3)),
#     test_cfg=dict(flip_test=True, flip_mode='heatmap', shift_heatmap=False),
#     _scope_='mmpose')
# dataset_type = 'CocoDataset'
# data_mode = 'topdown'
# data_root = '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver'
# train_pipeline = [
#     dict(type='LoadImage', _scope_='mmpose'),
#     dict(type='GetBBoxCenterScale', _scope_='mmpose'),
#     dict(type='RandomFlip', direction='horizontal', _scope_='mmpose'),
#     dict(type='RandomHalfBody', _scope_='mmpose'),
#     dict(type='RandomBBoxTransform', _scope_='mmpose'),
#     dict(
#         type='TopdownAffine',
#         input_size=(
#             288,
#             384,
#         ),
#         use_udp=True,
#         _scope_='mmpose'),
#     dict(
#         type='GenerateTarget',
#         encoder=dict(
#             type='UDPHeatmap',
#             input_size=(
#                 288,
#                 384,
#             ),
#             heatmap_size=(
#                 72,
#                 96,
#             ),
#             sigma=3),
#         _scope_='mmpose'),
#     dict(type='PackPoseInputs', _scope_='mmpose'),
# ]
# val_pipeline = [
#     dict(type='LoadImage', _scope_='mmpose'),
#     dict(type='GetBBoxCenterScale', _scope_='mmpose'),
#     dict(
#         type='TopdownAffine',
#         input_size=(
#             288,
#             384,
#         ),
#         use_udp=True,
#         _scope_='mmpose'),
#     dict(type='PackPoseInputs', _scope_='mmpose'),
# ]
# train_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver',
#         data_mode='topdown',
#         ann_file=
#         '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train'),
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='RandomFlip', direction='horizontal'),
#             dict(type='RandomHalfBody'),
#             dict(type='RandomBBoxTransform'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(
#                 type='GenerateTarget',
#                 encoder=dict(
#                     type='UDPHeatmap',
#                     input_size=(
#                         288,
#                         384,
#                     ),
#                     heatmap_size=(
#                         72,
#                         96,
#                     ),
#                     sigma=3)),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# val_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(
#         type='DefaultSampler', shuffle=False, round_up=False,
#         _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver',
#         data_mode='topdown',
#         ann_file=
#         '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#         bbox_file=
#         '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/person_detection_results/human_detection_val.json',
#         data_prefix=dict(img='images/val'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# test_dataloader = dict(
#     batch_size=16,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(
#         type='DefaultSampler', shuffle=False, round_up=False,
#         _scope_='mmpose'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver',
#         data_mode='topdown',
#         ann_file=
#         '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/annotations/person_keypoints_test.json',
#         bbox_file=
#         '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/person_detection_results/human_detection_test.json',
#         data_prefix=dict(img='images/test'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImage'),
#             dict(type='GetBBoxCenterScale'),
#             dict(type='TopdownAffine', input_size=(
#                 288,
#                 384,
#             ), use_udp=True),
#             dict(type='PackPoseInputs'),
#         ],
#         _scope_='mmpose'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     _scope_='mmpose')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_ir/A_Pillar_Codriver/annotations/person_keypoints_test.json',
#     _scope_='mmpose')
# work_dir = './mmengine_workdir/pose_estimator_2d_synthetic_cabin_ir'
# wandb: Currently logged in as: gentlerainsky. Use `wandb login --relogin` to force relogin
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/workspace/mmengine_workdir/pose_estimator_2d_synthetic_cabin_ir/20231119_175433/vis_data/wandb/run-20231119_175441-b1r5eebi</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/b1r5eebi' target="_blank">lilac-bush-81</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/b1r5eebi' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/b1r5eebi</a>
# 11/19 17:54:51 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/19 17:54:51 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) PoseVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /opt/conda/lib/python3.10/site-packages/mmpose/datasets/datasets/utils.py:102: UserWarning: The metainfo config file "configs/_base_/datasets/coco.py" does not exist. A matched config file "/opt/conda/lib/python3.10/site-packages/mmpose/.mim/configs/_base_/datasets/coco.py" will be used instead.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.59s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# 11/19 17:55:01 - mmengine - INFO - load model from: https://download.openmmlab.com/mmpose/pretrain_models/hrnet_w48-8ef0771d.pth
# 11/19 17:55:01 - mmengine - INFO - Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/pretrain_models/hrnet_w48-8ef0771d.pth
# 11/19 17:55:02 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: head.0.0.0.conv1.weight, head.0.0.0.bn1.weight, head.0.0.0.bn1.bias, head.0.0.0.bn1.running_mean, head.0.0.0.bn1.running_var, head.0.0.0.conv2.weight, head.0.0.0.bn2.weight, head.0.0.0.bn2.bias, head.0.0.0.bn2.running_mean, head.0.0.0.bn2.running_var, head.0.0.0.conv3.weight, head.0.0.0.bn3.weight, head.0.0.0.bn3.bias, head.0.0.0.bn3.running_mean, head.0.0.0.bn3.running_var, head.0.0.0.downsample.0.weight, head.0.0.0.downsample.1.weight, head.0.0.0.downsample.1.bias, head.0.0.0.downsample.1.running_mean, head.0.0.0.downsample.1.running_var, head.0.1.0.conv1.weight, head.0.1.0.bn1.weight, head.0.1.0.bn1.bias, head.0.1.0.bn1.running_mean, head.0.1.0.bn1.running_var, head.0.1.0.conv2.weight, head.0.1.0.bn2.weight, head.0.1.0.bn2.bias, head.0.1.0.bn2.running_mean, head.0.1.0.bn2.running_var, head.0.1.0.conv3.weight, head.0.1.0.bn3.weight, head.0.1.0.bn3.bias, head.0.1.0.bn3.running_mean, head.0.1.0.bn3.running_var, head.0.1.0.downsample.0.weight, head.0.1.0.downsample.1.weight, head.0.1.0.downsample.1.bias, head.0.1.0.downsample.1.running_mean, head.0.1.0.downsample.1.running_var, head.0.2.0.conv1.weight, head.0.2.0.bn1.weight, head.0.2.0.bn1.bias, head.0.2.0.bn1.running_mean, head.0.2.0.bn1.running_var, head.0.2.0.conv2.weight, head.0.2.0.bn2.weight, head.0.2.0.bn2.bias, head.0.2.0.bn2.running_mean, head.0.2.0.bn2.running_var, head.0.2.0.conv3.weight, head.0.2.0.bn3.weight, head.0.2.0.bn3.bias, head.0.2.0.bn3.running_mean, head.0.2.0.bn3.running_var, head.0.2.0.downsample.0.weight, head.0.2.0.downsample.1.weight, head.0.2.0.downsample.1.bias, head.0.2.0.downsample.1.running_mean, head.0.2.0.downsample.1.running_var, head.1.0.0.conv1.weight, head.1.0.0.bn1.weight, head.1.0.0.bn1.bias, head.1.0.0.bn1.running_mean, head.1.0.0.bn1.running_var, head.1.0.0.conv2.weight, head.1.0.0.bn2.weight, head.1.0.0.bn2.bias, head.1.0.0.bn2.running_mean, head.1.0.0.bn2.running_var, head.1.0.0.conv3.weight, head.1.0.0.bn3.weight, head.1.0.0.bn3.bias, head.1.0.0.bn3.running_mean, head.1.0.0.bn3.running_var, head.1.0.0.downsample.0.weight, head.1.0.0.downsample.1.weight, head.1.0.0.downsample.1.bias, head.1.0.0.downsample.1.running_mean, head.1.0.0.downsample.1.running_var, head.1.1.0.conv1.weight, head.1.1.0.bn1.weight, head.1.1.0.bn1.bias, head.1.1.0.bn1.running_mean, head.1.1.0.bn1.running_var, head.1.1.0.conv2.weight, head.1.1.0.bn2.weight, head.1.1.0.bn2.bias, head.1.1.0.bn2.running_mean, head.1.1.0.bn2.running_var, head.1.1.0.conv3.weight, head.1.1.0.bn3.weight, head.1.1.0.bn3.bias, head.1.1.0.bn3.running_mean, head.1.1.0.bn3.running_var, head.1.1.0.downsample.0.weight, head.1.1.0.downsample.1.weight, head.1.1.0.downsample.1.bias, head.1.1.0.downsample.1.running_mean, head.1.1.0.downsample.1.running_var, head.2.0.0.conv1.weight, head.2.0.0.bn1.weight, head.2.0.0.bn1.bias, head.2.0.0.bn1.running_mean, head.2.0.0.bn1.running_var, head.2.0.0.conv2.weight, head.2.0.0.bn2.weight, head.2.0.0.bn2.bias, head.2.0.0.bn2.running_mean, head.2.0.0.bn2.running_var, head.2.0.0.conv3.weight, head.2.0.0.bn3.weight, head.2.0.0.bn3.bias, head.2.0.0.bn3.running_mean, head.2.0.0.bn3.running_var, head.2.0.0.downsample.0.weight, head.2.0.0.downsample.1.weight, head.2.0.0.downsample.1.bias, head.2.0.0.downsample.1.running_mean, head.2.0.0.downsample.1.running_var, head.3.0.0.conv1.weight, head.3.0.0.bn1.weight, head.3.0.0.bn1.bias, head.3.0.0.bn1.running_mean, head.3.0.0.bn1.running_var, head.3.0.0.conv2.weight, head.3.0.0.bn2.weight, head.3.0.0.bn2.bias, head.3.0.0.bn2.running_mean, head.3.0.0.bn2.running_var, head.3.0.0.conv3.weight, head.3.0.0.bn3.weight, head.3.0.0.bn3.bias, head.3.0.0.bn3.running_mean, head.3.0.0.bn3.running_var, head.3.0.0.downsample.0.weight, head.3.0.0.downsample.1.weight, head.3.0.0.downsample.1.bias, head.3.0.0.downsample.1.running_mean, head.3.0.0.downsample.1.running_var, fc.weight, fc.bias, stage4.2.fuse_layers.1.0.0.0.weight, stage4.2.fuse_layers.1.0.0.1.weight, stage4.2.fuse_layers.1.0.0.1.bias, stage ...
#
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w48_udp-8xb32-210e_coco-384x288-70d7ab01_20220913.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: data_preprocessor.mean, data_preprocessor.std
#
# 11/19 17:55:02 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmpose/v1/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w48_udp-8xb32-210e_coco-384x288-70d7ab01_20220913.pth
# 11/19 17:55:03 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/19 17:55:03 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/19 17:55:03 - mmengine - INFO - Checkpoints will be saved to /workspace/mmengine_workdir/pose_estimator_2d_synthetic_cabin_ir.
# 11/19 17:55:56 - mmengine - INFO - Epoch(train)  [1][  50/2344]  lr: 4.954910e-05  eta: 6:59:28  time: 1.076057  data_time: 0.041291  memory: 7744  loss: 0.001370  loss_kpt: 0.001370  acc_pose: 0.671175
# 11/19 17:56:49 - mmengine - INFO - Epoch(train)  [1][ 100/2344]  lr: 9.959920e-05  eta: 6:55:37  time: 1.060829  data_time: 0.026681  memory: 7744  loss: 0.000973  loss_kpt: 0.000973  acc_pose: 0.775180
# 11/19 17:57:41 - mmengine - INFO - Epoch(train)  [1][ 150/2344]  lr: 1.496493e-04  eta: 6:50:21  time: 1.034596  data_time: 0.025988  memory: 7744  loss: 0.000751  loss_kpt: 0.000751  acc_pose: 0.865061
# 11/19 17:58:33 - mmengine - INFO - Epoch(train)  [1][ 200/2344]  lr: 1.996994e-04  eta: 6:47:58  time: 1.041610  data_time: 0.025754  memory: 7744  loss: 0.000637  loss_kpt: 0.000637  acc_pose: 0.852684
# 11/19 17:59:26 - mmengine - INFO - Epoch(train)  [1][ 250/2344]  lr: 2.497495e-04  eta: 6:47:39  time: 1.060678  data_time: 0.024669  memory: 7744  loss: 0.000565  loss_kpt: 0.000565  acc_pose: 0.951261
# 11/19 18:00:18 - mmengine - INFO - Epoch(train)  [1][ 300/2344]  lr: 2.997996e-04  eta: 6:45:12  time: 1.030350  data_time: 0.026506  memory: 7744  loss: 0.000510  loss_kpt: 0.000510  acc_pose: 0.908384
# 11/19 18:01:09 - mmengine - INFO - Epoch(train)  [1][ 350/2344]  lr: 3.498497e-04  eta: 6:43:14  time: 1.030862  data_time: 0.025808  memory: 7744  loss: 0.000456  loss_kpt: 0.000456  acc_pose: 0.860659
# 11/19 18:02:01 - mmengine - INFO - Epoch(train)  [1][ 400/2344]  lr: 3.998998e-04  eta: 6:41:55  time: 1.038617  data_time: 0.025549  memory: 7744  loss: 0.000448  loss_kpt: 0.000448  acc_pose: 0.916444
# 11/19 18:02:52 - mmengine - INFO - Epoch(train)  [1][ 450/2344]  lr: 4.499499e-04  eta: 6:39:57  time: 1.020732  data_time: 0.025216  memory: 7744  loss: 0.000405  loss_kpt: 0.000405  acc_pose: 0.964643
# 11/19 18:03:43 - mmengine - INFO - Epoch(train)  [1][ 500/2344]  lr: 5.000000e-04  eta: 6:37:44  time: 1.008492  data_time: 0.027004  memory: 7744  loss: 0.000405  loss_kpt: 0.000405  acc_pose: 0.805331
# 11/19 18:04:35 - mmengine - INFO - Epoch(train)  [1][ 550/2344]  lr: 5.000000e-04  eta: 6:36:49  time: 1.038901  data_time: 0.025792  memory: 7744  loss: 0.000415  loss_kpt: 0.000415  acc_pose: 0.953571
# 11/19 18:05:27 - mmengine - INFO - Epoch(train)  [1][ 600/2344]  lr: 5.000000e-04  eta: 6:36:05  time: 1.044697  data_time: 0.027173  memory: 7744  loss: 0.000395  loss_kpt: 0.000395  acc_pose: 0.953889
# 11/19 18:06:18 - mmengine - INFO - Epoch(train)  [1][ 650/2344]  lr: 5.000000e-04  eta: 6:34:40  time: 1.021268  data_time: 0.024870  memory: 7744  loss: 0.000369  loss_kpt: 0.000369  acc_pose: 0.913651
# 11/19 18:07:10 - mmengine - INFO - Epoch(train)  [1][ 700/2344]  lr: 5.000000e-04  eta: 6:33:52  time: 1.041815  data_time: 0.024874  memory: 7744  loss: 0.000353  loss_kpt: 0.000353  acc_pose: 0.911340
# 11/19 18:08:02 - mmengine - INFO - Epoch(train)  [1][ 750/2344]  lr: 5.000000e-04  eta: 6:32:57  time: 1.037239  data_time: 0.024714  memory: 7744  loss: 0.000371  loss_kpt: 0.000371  acc_pose: 0.918849
# 11/19 18:08:54 - mmengine - INFO - Epoch(train)  [1][ 800/2344]  lr: 5.000000e-04  eta: 6:32:06  time: 1.040097  data_time: 0.024876  memory: 7744  loss: 0.000352  loss_kpt: 0.000352  acc_pose: 0.964683
# 11/19 18:09:47 - mmengine - INFO - Epoch(train)  [1][ 850/2344]  lr: 5.000000e-04  eta: 6:31:34  time: 1.053782  data_time: 0.030032  memory: 7744  loss: 0.000331  loss_kpt: 0.000331  acc_pose: 0.958066
# 11/19 18:10:38 - mmengine - INFO - Epoch(train)  [1][ 900/2344]  lr: 5.000000e-04  eta: 6:30:38  time: 1.036549  data_time: 0.025588  memory: 7744  loss: 0.000333  loss_kpt: 0.000333  acc_pose: 0.947233
# 11/19 18:11:29 - mmengine - INFO - Epoch(train)  [1][ 950/2344]  lr: 5.000000e-04  eta: 6:29:18  time: 1.016452  data_time: 0.026740  memory: 7744  loss: 0.000314  loss_kpt: 0.000314  acc_pose: 0.977372
# 11/19 18:12:21 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 18:12:21 - mmengine - INFO - Epoch(train)  [1][1000/2344]  lr: 5.000000e-04  eta: 6:28:22  time: 1.035128  data_time: 0.026093  memory: 7744  loss: 0.000320  loss_kpt: 0.000320  acc_pose: 0.891978
# 11/19 18:13:12 - mmengine - INFO - Epoch(train)  [1][1050/2344]  lr: 5.000000e-04  eta: 6:27:10  time: 1.019627  data_time: 0.024963  memory: 7744  loss: 0.000315  loss_kpt: 0.000315  acc_pose: 0.939237
# 11/19 18:14:04 - mmengine - INFO - Epoch(train)  [1][1100/2344]  lr: 5.000000e-04  eta: 6:26:12  time: 1.031661  data_time: 0.023893  memory: 7744  loss: 0.000302  loss_kpt: 0.000302  acc_pose: 0.944219
# 11/19 18:14:55 - mmengine - INFO - Epoch(train)  [1][1150/2344]  lr: 5.000000e-04  eta: 6:25:21  time: 1.037572  data_time: 0.027696  memory: 7744  loss: 0.000318  loss_kpt: 0.000318  acc_pose: 0.978889
# 11/19 18:15:48 - mmengine - INFO - Epoch(train)  [1][1200/2344]  lr: 5.000000e-04  eta: 6:24:47  time: 1.057363  data_time: 0.025589  memory: 7744  loss: 0.000310  loss_kpt: 0.000310  acc_pose: 0.947601
# 11/19 18:16:41 - mmengine - INFO - Epoch(train)  [1][1250/2344]  lr: 5.000000e-04  eta: 6:24:11  time: 1.055959  data_time: 0.023584  memory: 7744  loss: 0.000307  loss_kpt: 0.000307  acc_pose: 0.936261
# 11/19 18:17:34 - mmengine - INFO - Epoch(train)  [1][1300/2344]  lr: 5.000000e-04  eta: 6:23:35  time: 1.057601  data_time: 0.024322  memory: 7744  loss: 0.000313  loss_kpt: 0.000313  acc_pose: 0.955556
# 11/19 18:18:27 - mmengine - INFO - Epoch(train)  [1][1350/2344]  lr: 5.000000e-04  eta: 6:22:57  time: 1.056845  data_time: 0.024186  memory: 7744  loss: 0.000297  loss_kpt: 0.000297  acc_pose: 0.973294
# 11/19 18:19:19 - mmengine - INFO - Epoch(train)  [1][1400/2344]  lr: 5.000000e-04  eta: 6:22:14  time: 1.050953  data_time: 0.025227  memory: 7744  loss: 0.000291  loss_kpt: 0.000291  acc_pose: 0.955150
# 11/19 18:20:12 - mmengine - INFO - Epoch(train)  [1][1450/2344]  lr: 5.000000e-04  eta: 6:21:26  time: 1.045623  data_time: 0.028367  memory: 7744  loss: 0.000301  loss_kpt: 0.000301  acc_pose: 0.908939
# 11/19 18:21:04 - mmengine - INFO - Epoch(train)  [1][1500/2344]  lr: 5.000000e-04  eta: 6:20:40  time: 1.049004  data_time: 0.025725  memory: 7744  loss: 0.000281  loss_kpt: 0.000281  acc_pose: 0.951508
# 11/19 18:21:55 - mmengine - INFO - Epoch(train)  [1][1550/2344]  lr: 5.000000e-04  eta: 6:19:30  time: 1.016208  data_time: 0.027341  memory: 7744  loss: 0.000280  loss_kpt: 0.000280  acc_pose: 0.953889
# 11/19 18:22:44 - mmengine - INFO - Epoch(train)  [1][1600/2344]  lr: 5.000000e-04  eta: 6:18:04  time: 0.990615  data_time: 0.024427  memory: 7744  loss: 0.000263  loss_kpt: 0.000263  acc_pose: 0.945566
# 11/19 18:23:34 - mmengine - INFO - Epoch(train)  [1][1650/2344]  lr: 5.000000e-04  eta: 6:16:42  time: 0.992615  data_time: 0.023824  memory: 7744  loss: 0.000271  loss_kpt: 0.000271  acc_pose: 0.950238
# 11/19 18:24:24 - mmengine - INFO - Epoch(train)  [1][1700/2344]  lr: 5.000000e-04  eta: 6:15:21  time: 0.992351  data_time: 0.024764  memory: 7744  loss: 0.000285  loss_kpt: 0.000285  acc_pose: 0.919277
# 11/19 18:25:14 - mmengine - INFO - Epoch(train)  [1][1750/2344]  lr: 5.000000e-04  eta: 6:14:06  time: 0.997631  data_time: 0.025478  memory: 7744  loss: 0.000293  loss_kpt: 0.000293  acc_pose: 0.952601
# 11/19 18:26:04 - mmengine - INFO - Epoch(train)  [1][1800/2344]  lr: 5.000000e-04  eta: 6:12:53  time: 0.999664  data_time: 0.027713  memory: 7744  loss: 0.000268  loss_kpt: 0.000268  acc_pose: 0.995556
# 11/19 18:26:54 - mmengine - INFO - Epoch(train)  [1][1850/2344]  lr: 5.000000e-04  eta: 6:11:48  time: 1.011218  data_time: 0.023958  memory: 7744  loss: 0.000273  loss_kpt: 0.000273  acc_pose: 0.953344
# 11/19 18:27:48 - mmengine - INFO - Epoch(train)  [1][1900/2344]  lr: 5.000000e-04  eta: 6:11:23  time: 1.079788  data_time: 0.029451  memory: 7744  loss: 0.000275  loss_kpt: 0.000275  acc_pose: 0.878596
# 11/19 18:28:41 - mmengine - INFO - Epoch(train)  [1][1950/2344]  lr: 5.000000e-04  eta: 6:10:41  time: 1.052742  data_time: 0.025824  memory: 7744  loss: 0.000280  loss_kpt: 0.000280  acc_pose: 0.930833
# 11/19 18:29:34 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 18:29:34 - mmengine - INFO - Epoch(train)  [1][2000/2344]  lr: 5.000000e-04  eta: 6:10:05  time: 1.064114  data_time: 0.025102  memory: 7744  loss: 0.000255  loss_kpt: 0.000255  acc_pose: 0.961944
# 11/19 18:30:25 - mmengine - INFO - Epoch(train)  [1][2050/2344]  lr: 5.000000e-04  eta: 6:09:09  time: 1.027227  data_time: 0.024619  memory: 7744  loss: 0.000258  loss_kpt: 0.000258  acc_pose: 0.966389
# 11/19 18:31:20 - mmengine - INFO - Epoch(train)  [1][2100/2344]  lr: 5.000000e-04  eta: 6:08:49  time: 1.098880  data_time: 0.025452  memory: 7744  loss: 0.000246  loss_kpt: 0.000246  acc_pose: 0.973333
# 11/19 18:32:14 - mmengine - INFO - Epoch(train)  [1][2150/2344]  lr: 5.000000e-04  eta: 6:08:11  time: 1.065659  data_time: 0.023921  memory: 7744  loss: 0.000269  loss_kpt: 0.000269  acc_pose: 0.954603
# 11/19 18:33:07 - mmengine - INFO - Epoch(train)  [1][2200/2344]  lr: 5.000000e-04  eta: 6:07:36  time: 1.071215  data_time: 0.023938  memory: 7744  loss: 0.000275  loss_kpt: 0.000275  acc_pose: 0.903565
# 11/19 18:34:01 - mmengine - INFO - Epoch(train)  [1][2250/2344]  lr: 5.000000e-04  eta: 6:07:03  time: 1.078762  data_time: 0.023872  memory: 7744  loss: 0.000252  loss_kpt: 0.000252  acc_pose: 0.966667
# 11/19 18:34:54 - mmengine - INFO - Epoch(train)  [1][2300/2344]  lr: 5.000000e-04  eta: 6:06:15  time: 1.049243  data_time: 0.025445  memory: 7744  loss: 0.000260  loss_kpt: 0.000260  acc_pose: 0.915278
# 11/19 18:35:41 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 18:36:09 - mmengine - INFO - Epoch(val)  [1][ 50/391]    eta: 0:03:11  time: 0.560711  data_time: 0.022700  memory: 7744
# 11/19 18:36:35 - mmengine - INFO - Epoch(val)  [1][100/391]    eta: 0:02:38  time: 0.526696  data_time: 0.005342  memory: 1147
# 11/19 18:37:03 - mmengine - INFO - Epoch(val)  [1][150/391]    eta: 0:02:11  time: 0.543465  data_time: 0.005217  memory: 1147
# 11/19 18:37:29 - mmengine - INFO - Epoch(val)  [1][200/391]    eta: 0:01:43  time: 0.532867  data_time: 0.005077  memory: 1147
# 11/19 18:37:56 - mmengine - INFO - Epoch(val)  [1][250/391]    eta: 0:01:16  time: 0.541014  data_time: 0.005377  memory: 1147
# 11/19 18:38:24 - mmengine - INFO - Epoch(val)  [1][300/391]    eta: 0:00:49  time: 0.545157  data_time: 0.005647  memory: 1147
# 11/19 18:38:51 - mmengine - INFO - Epoch(val)  [1][350/391]    eta: 0:00:22  time: 0.542669  data_time: 0.005182  memory: 1147
# 11/19 18:39:13 - mmengine - INFO - Evaluating CocoMetric...
# Loading and preparing results...
# DONE (t=0.17s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=1.23s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.946
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.980
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.946
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.956
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.987
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.956
# 11/19 18:39:15 - mmengine - INFO - Epoch(val) [1][391/391]    coco/AP: 0.945674  coco/AP .5: 1.000000  coco/AP .75: 0.979715  coco/AP (M): -1.000000  coco/AP (L): 0.945674  coco/AR: 0.956048  coco/AR .5: 1.000000  coco/AR .75: 0.986880  coco/AR (M): -1.000000  coco/AR (L): 0.956048  data_time: 0.007538  time: 0.541418
# 11/19 18:39:17 - mmengine - INFO - The best checkpoint with 0.9457 coco/AP at 1 epoch is saved to best_coco_AP_epoch_1.pth.
# 11/19 18:40:09 - mmengine - INFO - Epoch(train)  [2][  50/2344]  lr: 5.000000e-04  eta: 6:04:53  time: 1.038870  data_time: 0.029879  memory: 7744  loss: 0.000258  loss_kpt: 0.000258  acc_pose: 0.943611
# 11/19 18:41:02 - mmengine - INFO - Epoch(train)  [2][ 100/2344]  lr: 5.000000e-04  eta: 6:04:09  time: 1.058380  data_time: 0.022318  memory: 7744  loss: 0.000262  loss_kpt: 0.000262  acc_pose: 0.948443
# 11/19 18:41:54 - mmengine - INFO - Epoch(train)  [2][ 150/2344]  lr: 5.000000e-04  eta: 6:03:15  time: 1.035024  data_time: 0.022825  memory: 7744  loss: 0.000258  loss_kpt: 0.000258  acc_pose: 0.968086
# 11/19 18:42:45 - mmengine - INFO - Epoch(train)  [2][ 200/2344]  lr: 5.000000e-04  eta: 6:02:19  time: 1.032858  data_time: 0.022183  memory: 7744  loss: 0.000249  loss_kpt: 0.000249  acc_pose: 0.976190
# 11/19 18:43:38 - mmengine - INFO - Epoch(train)  [2][ 250/2344]  lr: 5.000000e-04  eta: 6:01:32  time: 1.051401  data_time: 0.022430  memory: 7744  loss: 0.000243  loss_kpt: 0.000243  acc_pose: 0.955070
# 11/19 18:44:30 - mmengine - INFO - Epoch(train)  [2][ 300/2344]  lr: 5.000000e-04  eta: 6:00:36  time: 1.031473  data_time: 0.021952  memory: 7744  loss: 0.000253  loss_kpt: 0.000253  acc_pose: 0.979167
# 11/19 18:45:22 - mmengine - INFO - Epoch(train)  [2][ 350/2344]  lr: 5.000000e-04  eta: 5:59:49  time: 1.052069  data_time: 0.021388  memory: 7744  loss: 0.000236  loss_kpt: 0.000236  acc_pose: 0.971181
# 11/19 18:46:14 - mmengine - INFO - Epoch(train)  [2][ 400/2344]  lr: 5.000000e-04  eta: 5:58:58  time: 1.044554  data_time: 0.021415  memory: 7744  loss: 0.000242  loss_kpt: 0.000242  acc_pose: 0.940952
# 11/19 18:47:07 - mmengine - INFO - Epoch(train)  [2][ 450/2344]  lr: 5.000000e-04  eta: 5:58:11  time: 1.053568  data_time: 0.021576  memory: 7744  loss: 0.000234  loss_kpt: 0.000234  acc_pose: 0.953919
# 11/19 18:48:01 - mmengine - INFO - Epoch(train)  [2][ 500/2344]  lr: 5.000000e-04  eta: 5:57:35  time: 1.084585  data_time: 0.021657  memory: 7744  loss: 0.000225  loss_kpt: 0.000225  acc_pose: 0.983333
# 11/19 18:48:54 - mmengine - INFO - Epoch(train)  [2][ 550/2344]  lr: 5.000000e-04  eta: 5:56:47  time: 1.054961  data_time: 0.022108  memory: 7744  loss: 0.000235  loss_kpt: 0.000235  acc_pose: 0.963900
# 11/19 18:49:49 - mmengine - INFO - Epoch(train)  [2][ 600/2344]  lr: 5.000000e-04  eta: 5:56:16  time: 1.101208  data_time: 0.023747  memory: 7744  loss: 0.000228  loss_kpt: 0.000228  acc_pose: 0.970238
# 11/19 18:50:42 - mmengine - INFO - Epoch(train)  [2][ 650/2344]  lr: 5.000000e-04  eta: 5:55:26  time: 1.048975  data_time: 0.023753  memory: 7744  loss: 0.000226  loss_kpt: 0.000226  acc_pose: 0.983333
# 11/19 18:50:48 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 18:51:36 - mmengine - INFO - Epoch(train)  [2][ 700/2344]  lr: 5.000000e-04  eta: 5:54:48  time: 1.086160  data_time: 0.024326  memory: 7744  loss: 0.000237  loss_kpt: 0.000237  acc_pose: 0.961944
# 11/19 18:52:31 - mmengine - INFO - Epoch(train)  [2][ 750/2344]  lr: 5.000000e-04  eta: 5:54:17  time: 1.109836  data_time: 0.024754  memory: 7744  loss: 0.000239  loss_kpt: 0.000239  acc_pose: 0.969722
# 11/19 18:53:26 - mmengine - INFO - Epoch(train)  [2][ 800/2344]  lr: 5.000000e-04  eta: 5:53:40  time: 1.091140  data_time: 0.026689  memory: 7744  loss: 0.000234  loss_kpt: 0.000234  acc_pose: 0.982778
# 11/19 18:54:22 - mmengine - INFO - Epoch(train)  [2][ 850/2344]  lr: 5.000000e-04  eta: 5:53:11  time: 1.119864  data_time: 0.024350  memory: 7744  loss: 0.000218  loss_kpt: 0.000218  acc_pose: 0.978333
# 11/19 18:55:16 - mmengine - INFO - Epoch(train)  [2][ 900/2344]  lr: 5.000000e-04  eta: 5:52:31  time: 1.085886  data_time: 0.024086  memory: 7744  loss: 0.000226  loss_kpt: 0.000226  acc_pose: 0.961111
# 11/19 18:56:10 - mmengine - INFO - Epoch(train)  [2][ 950/2344]  lr: 5.000000e-04  eta: 5:51:47  time: 1.073220  data_time: 0.025050  memory: 7744  loss: 0.000225  loss_kpt: 0.000225  acc_pose: 0.964722
# 11/19 18:57:03 - mmengine - INFO - Epoch(train)  [2][1000/2344]  lr: 5.000000e-04  eta: 5:50:59  time: 1.062590  data_time: 0.023680  memory: 7744  loss: 0.000225  loss_kpt: 0.000225  acc_pose: 0.920092
# 11/19 18:57:57 - mmengine - INFO - Epoch(train)  [2][1050/2344]  lr: 5.000000e-04  eta: 5:50:19  time: 1.090655  data_time: 0.024062  memory: 7744  loss: 0.000231  loss_kpt: 0.000231  acc_pose: 0.986667
# 11/19 18:58:52 - mmengine - INFO - Epoch(train)  [2][1100/2344]  lr: 5.000000e-04  eta: 5:49:38  time: 1.086214  data_time: 0.025221  memory: 7744  loss: 0.000215  loss_kpt: 0.000215  acc_pose: 0.960388
# 11/19 18:59:46 - mmengine - INFO - Epoch(train)  [2][1150/2344]  lr: 5.000000e-04  eta: 5:48:56  time: 1.087719  data_time: 0.025929  memory: 7744  loss: 0.000221  loss_kpt: 0.000221  acc_pose: 0.973016
# 11/19 19:00:38 - mmengine - INFO - Epoch(train)  [2][1200/2344]  lr: 5.000000e-04  eta: 5:48:01  time: 1.040500  data_time: 0.024037  memory: 7744  loss: 0.000220  loss_kpt: 0.000220  acc_pose: 0.984615
# 11/19 19:01:31 - mmengine - INFO - Epoch(train)  [2][1250/2344]  lr: 5.000000e-04  eta: 5:47:08  time: 1.046881  data_time: 0.027149  memory: 7744  loss: 0.000230  loss_kpt: 0.000230  acc_pose: 0.958056
# 11/19 19:02:22 - mmengine - INFO - Epoch(train)  [2][1300/2344]  lr: 5.000000e-04  eta: 5:46:09  time: 1.026075  data_time: 0.026034  memory: 7744  loss: 0.000226  loss_kpt: 0.000226  acc_pose: 0.896977
# 11/19 19:03:14 - mmengine - INFO - Epoch(train)  [2][1350/2344]  lr: 5.000000e-04  eta: 5:45:13  time: 1.036238  data_time: 0.024248  memory: 7744  loss: 0.000232  loss_kpt: 0.000232  acc_pose: 0.952187
# 11/19 19:04:05 - mmengine - INFO - Epoch(train)  [2][1400/2344]  lr: 5.000000e-04  eta: 5:44:14  time: 1.024774  data_time: 0.025749  memory: 7744  loss: 0.000243  loss_kpt: 0.000243  acc_pose: 0.974127
# 11/19 19:04:56 - mmengine - INFO - Epoch(train)  [2][1450/2344]  lr: 5.000000e-04  eta: 5:43:15  time: 1.021398  data_time: 0.025908  memory: 7744  loss: 0.000220  loss_kpt: 0.000220  acc_pose: 0.974722
# 11/19 19:05:45 - mmengine - INFO - Epoch(train)  [2][1500/2344]  lr: 5.000000e-04  eta: 5:42:08  time: 0.990164  data_time: 0.025257  memory: 7744  loss: 0.000228  loss_kpt: 0.000228  acc_pose: 0.959683
# 11/19 19:06:35 - mmengine - INFO - Epoch(train)  [2][1550/2344]  lr: 5.000000e-04  eta: 5:41:00  time: 0.987980  data_time: 0.024017  memory: 7744  loss: 0.000217  loss_kpt: 0.000217  acc_pose: 0.951538
# 11/19 19:07:26 - mmengine - INFO - Epoch(train)  [2][1600/2344]  lr: 5.000000e-04  eta: 5:40:00  time: 1.014823  data_time: 0.024180  memory: 7744  loss: 0.000208  loss_kpt: 0.000208  acc_pose: 0.974167
# 11/19 19:08:16 - mmengine - INFO - Epoch(train)  [2][1650/2344]  lr: 5.000000e-04  eta: 5:38:57  time: 1.002600  data_time: 0.024442  memory: 7744  loss: 0.000232  loss_kpt: 0.000232  acc_pose: 0.972551
# 11/19 19:08:22 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 19:09:06 - mmengine - INFO - Epoch(train)  [2][1700/2344]  lr: 5.000000e-04  eta: 5:37:53  time: 0.995491  data_time: 0.030134  memory: 7744  loss: 0.000215  loss_kpt: 0.000215  acc_pose: 0.960833
# 11/19 19:09:54 - mmengine - INFO - Epoch(train)  [2][1750/2344]  lr: 5.000000e-04  eta: 5:36:42  time: 0.967869  data_time: 0.027539  memory: 7744  loss: 0.000205  loss_kpt: 0.000205  acc_pose: 0.972659
# 11/19 19:10:42 - mmengine - INFO - Epoch(train)  [2][1800/2344]  lr: 5.000000e-04  eta: 5:35:31  time: 0.963995  data_time: 0.023434  memory: 7744  loss: 0.000223  loss_kpt: 0.000223  acc_pose: 0.957778
# 11/19 19:11:31 - mmengine - INFO - Epoch(train)  [2][1850/2344]  lr: 5.000000e-04  eta: 5:34:25  time: 0.980435  data_time: 0.025089  memory: 7744  loss: 0.000212  loss_kpt: 0.000212  acc_pose: 0.985714
# 11/19 19:12:20 - mmengine - INFO - Epoch(train)  [2][1900/2344]  lr: 5.000000e-04  eta: 5:33:17  time: 0.974543  data_time: 0.025071  memory: 7744  loss: 0.000206  loss_kpt: 0.000206  acc_pose: 0.982460
# 11/19 19:13:11 - mmengine - INFO - Epoch(train)  [2][1950/2344]  lr: 5.000000e-04  eta: 5:32:22  time: 1.028705  data_time: 0.025825  memory: 7744  loss: 0.000210  loss_kpt: 0.000210  acc_pose: 0.962222
# 11/19 19:14:03 - mmengine - INFO - Epoch(train)  [2][2000/2344]  lr: 5.000000e-04  eta: 5:31:26  time: 1.023885  data_time: 0.027760  memory: 7744  loss: 0.000231  loss_kpt: 0.000231  acc_pose: 0.986905
# 11/19 19:14:54 - mmengine - INFO - Epoch(train)  [2][2050/2344]  lr: 5.000000e-04  eta: 5:30:31  time: 1.025115  data_time: 0.025515  memory: 7744  loss: 0.000201  loss_kpt: 0.000201  acc_pose: 0.956389
# 11/19 19:15:45 - mmengine - INFO - Epoch(train)  [2][2100/2344]  lr: 5.000000e-04  eta: 5:29:33  time: 1.015831  data_time: 0.026758  memory: 7744  loss: 0.000218  loss_kpt: 0.000218  acc_pose: 0.962680
# 11/19 19:16:35 - mmengine - INFO - Epoch(train)  [2][2150/2344]  lr: 5.000000e-04  eta: 5:28:34  time: 1.006082  data_time: 0.026469  memory: 7744  loss: 0.000212  loss_kpt: 0.000212  acc_pose: 0.959177
# 11/19 19:17:26 - mmengine - INFO - Epoch(train)  [2][2200/2344]  lr: 5.000000e-04  eta: 5:27:39  time: 1.026915  data_time: 0.027177  memory: 7744  loss: 0.000214  loss_kpt: 0.000214  acc_pose: 0.966667
# 11/19 19:18:17 - mmengine - INFO - Epoch(train)  [2][2250/2344]  lr: 5.000000e-04  eta: 5:26:41  time: 1.011859  data_time: 0.027705  memory: 7744  loss: 0.000214  loss_kpt: 0.000214  acc_pose: 0.931410
# 11/19 19:19:08 - mmengine - INFO - Epoch(train)  [2][2300/2344]  lr: 5.000000e-04  eta: 5:25:45  time: 1.021588  data_time: 0.026136  memory: 7744  loss: 0.000221  loss_kpt: 0.000221  acc_pose: 0.964722
# 11/19 19:19:52 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 19:20:19 - mmengine - INFO - Epoch(val)  [2][ 50/391]    eta: 0:02:58  time: 0.524473  data_time: 0.009963  memory: 7744
# 11/19 19:20:45 - mmengine - INFO - Epoch(val)  [2][100/391]    eta: 0:02:33  time: 0.530234  data_time: 0.005289  memory: 1147
# 11/19 19:21:04 - mmengine - INFO - Epoch(val)  [2][150/391]    eta: 0:01:54  time: 0.375658  data_time: 0.004795  memory: 1147
# 11/19 19:21:22 - mmengine - INFO - Epoch(val)  [2][200/391]    eta: 0:01:25  time: 0.354691  data_time: 0.004851  memory: 1147
# 11/19 19:21:40 - mmengine - INFO - Epoch(val)  [2][250/391]    eta: 0:01:00  time: 0.358261  data_time: 0.004803  memory: 1147
# 11/19 19:21:58 - mmengine - INFO - Epoch(val)  [2][300/391]    eta: 0:00:38  time: 0.364742  data_time: 0.004907  memory: 1147
# 11/19 19:22:16 - mmengine - INFO - Epoch(val)  [2][350/391]    eta: 0:00:16  time: 0.373190  data_time: 0.004783  memory: 1147
# 11/19 19:22:32 - mmengine - INFO - Evaluating CocoMetric...
# Loading and preparing results...
# DONE (t=0.16s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=1.02s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.961
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.990
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.961
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.969
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.992
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.969
# 11/19 19:22:33 - mmengine - INFO - Epoch(val) [2][391/391]    coco/AP: 0.960666  coco/AP .5: 1.000000  coco/AP .75: 0.989879  coco/AP (M): -1.000000  coco/AP (L): 0.960666  coco/AR: 0.968560  coco/AR .5: 1.000000  coco/AR .75: 0.992160  coco/AR (M): -1.000000  coco/AR (L): 0.968560  data_time: 0.005530  time: 0.406315
# 11/19 19:22:33 - mmengine - INFO - The previous best checkpoint /workspace/mmengine_workdir/pose_estimator_2d_synthetic_cabin_ir/best_coco_AP_epoch_1.pth is removed
# 11/19 19:22:35 - mmengine - INFO - The best checkpoint with 0.9607 coco/AP at 2 epoch is saved to best_coco_AP_epoch_2.pth.
# 11/19 19:23:07 - mmengine - INFO - Epoch(train)  [3][  50/2344]  lr: 5.000000e-04  eta: 5:22:43  time: 0.636945  data_time: 0.025587  memory: 7744  loss: 0.000212  loss_kpt: 0.000212  acc_pose: 0.960794
# 11/19 19:23:41 - mmengine - INFO - Epoch(train)  [3][ 100/2344]  lr: 5.000000e-04  eta: 5:20:39  time: 0.665729  data_time: 0.022711  memory: 7744  loss: 0.000217  loss_kpt: 0.000217  acc_pose: 0.960379
# 11/19 19:24:13 - mmengine - INFO - Epoch(train)  [3][ 150/2344]  lr: 5.000000e-04  eta: 5:18:33  time: 0.643937  data_time: 0.017877  memory: 7744  loss: 0.000219  loss_kpt: 0.000219  acc_pose: 0.932094
# 11/19 19:24:47 - mmengine - INFO - Epoch(train)  [3][ 200/2344]  lr: 5.000000e-04  eta: 5:16:38  time: 0.693043  data_time: 0.018516  memory: 7744  loss: 0.000222  loss_kpt: 0.000222  acc_pose: 0.968889
# 11/19 19:25:20 - mmengine - INFO - Epoch(train)  [3][ 250/2344]  lr: 5.000000e-04  eta: 5:14:36  time: 0.642397  data_time: 0.018751  memory: 7744  loss: 0.000204  loss_kpt: 0.000204  acc_pose: 0.922583
# 11/19 19:25:52 - mmengine - INFO - Epoch(train)  [3][ 300/2344]  lr: 5.000000e-04  eta: 5:12:38  time: 0.658039  data_time: 0.026250  memory: 7744  loss: 0.000207  loss_kpt: 0.000207  acc_pose: 0.991071
# 11/19 19:26:00 - mmengine - INFO - Exp name: hrnet_20231119_175433
# ...
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.969
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.994
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.969
# 11/19 22:32:31 - mmengine - INFO - Epoch(val) [9][391/391]    coco/AP: 0.960802  coco/AP .5: 1.000000  coco/AP .75: 0.990005  coco/AP (M): -1.000000  coco/AP (L): 0.960802  coco/AR: 0.968720  coco/AR .5: 1.000000  coco/AR .75: 0.994400  coco/AR (M): -1.000000  coco/AR (L): 0.968720  data_time: 0.005306  time: 0.342633
# 11/19 22:33:03 - mmengine - INFO - Epoch(train) [10][  50/2344]  lr: 5.000000e-04  eta: 0:27:44  time: 0.642149  data_time: 0.025683  memory: 7744  loss: 0.000128  loss_kpt: 0.000128  acc_pose: 0.974405
# 11/19 22:33:35 - mmengine - INFO - Epoch(train) [10][ 100/2344]  lr: 5.000000e-04  eta: 0:27:07  time: 0.633559  data_time: 0.018439  memory: 7744  loss: 0.000131  loss_kpt: 0.000131  acc_pose: 0.964683
# 11/19 22:34:07 - mmengine - INFO - Epoch(train) [10][ 150/2344]  lr: 5.000000e-04  eta: 0:26:31  time: 0.631833  data_time: 0.018136  memory: 7744  loss: 0.000135  loss_kpt: 0.000135  acc_pose: 0.964722
# 11/19 22:34:38 - mmengine - INFO - Epoch(train) [10][ 200/2344]  lr: 5.000000e-04  eta: 0:25:54  time: 0.633591  data_time: 0.018163  memory: 7744  loss: 0.000137  loss_kpt: 0.000137  acc_pose: 0.991389
# 11/19 22:35:10 - mmengine - INFO - Epoch(train) [10][ 250/2344]  lr: 5.000000e-04  eta: 0:25:17  time: 0.638786  data_time: 0.021257  memory: 7744  loss: 0.000142  loss_kpt: 0.000142  acc_pose: 0.986032
# 11/19 22:35:42 - mmengine - INFO - Epoch(train) [10][ 300/2344]  lr: 5.000000e-04  eta: 0:24:41  time: 0.630952  data_time: 0.017990  memory: 7744  loss: 0.000124  loss_kpt: 0.000124  acc_pose: 0.969722
# 11/19 22:36:14 - mmengine - INFO - Epoch(train) [10][ 350/2344]  lr: 5.000000e-04  eta: 0:24:04  time: 0.633046  data_time: 0.018192  memory: 7744  loss: 0.000122  loss_kpt: 0.000122  acc_pose: 0.986944
# 11/19 22:36:45 - mmengine - INFO - Epoch(train) [10][ 400/2344]  lr: 5.000000e-04  eta: 0:23:27  time: 0.633093  data_time: 0.017910  memory: 7744  loss: 0.000134  loss_kpt: 0.000134  acc_pose: 0.977103
# 11/19 22:37:17 - mmengine - INFO - Epoch(train) [10][ 450/2344]  lr: 5.000000e-04  eta: 0:22:51  time: 0.632513  data_time: 0.018096  memory: 7744  loss: 0.000129  loss_kpt: 0.000129  acc_pose: 0.995833
# 11/19 22:37:49 - mmengine - INFO - Epoch(train) [10][ 500/2344]  lr: 5.000000e-04  eta: 0:22:14  time: 0.637530  data_time: 0.017972  memory: 7744  loss: 0.000137  loss_kpt: 0.000137  acc_pose: 0.989773
# 11/19 22:38:20 - mmengine - INFO - Epoch(train) [10][ 550/2344]  lr: 5.000000e-04  eta: 0:21:37  time: 0.631272  data_time: 0.017808  memory: 7744  loss: 0.000129  loss_kpt: 0.000129  acc_pose: 0.972143
# 11/19 22:38:52 - mmengine - INFO - Epoch(train) [10][ 600/2344]  lr: 5.000000e-04  eta: 0:21:01  time: 0.632514  data_time: 0.018122  memory: 7744  loss: 0.000141  loss_kpt: 0.000141  acc_pose: 0.974167
# 11/19 22:39:24 - mmengine - INFO - Epoch(train) [10][ 650/2344]  lr: 5.000000e-04  eta: 0:20:24  time: 0.633084  data_time: 0.017848  memory: 7744  loss: 0.000127  loss_kpt: 0.000127  acc_pose: 0.960937
# 11/19 22:39:55 - mmengine - INFO - Epoch(train) [10][ 700/2344]  lr: 5.000000e-04  eta: 0:19:48  time: 0.637847  data_time: 0.022133  memory: 7744  loss: 0.000133  loss_kpt: 0.000133  acc_pose: 1.000000
# 11/19 22:40:27 - mmengine - INFO - Epoch(train) [10][ 750/2344]  lr: 5.000000e-04  eta: 0:19:11  time: 0.631213  data_time: 0.017805  memory: 7744  loss: 0.000136  loss_kpt: 0.000136  acc_pose: 1.000000
# 11/19 22:40:59 - mmengine - INFO - Epoch(train) [10][ 800/2344]  lr: 5.000000e-04  eta: 0:18:35  time: 0.633499  data_time: 0.017989  memory: 7744  loss: 0.000132  loss_kpt: 0.000132  acc_pose: 0.987500
# 11/19 22:41:30 - mmengine - INFO - Epoch(train) [10][ 850/2344]  lr: 5.000000e-04  eta: 0:17:59  time: 0.631253  data_time: 0.017761  memory: 7744  loss: 0.000136  loss_kpt: 0.000136  acc_pose: 1.000000
# 11/19 22:42:02 - mmengine - INFO - Epoch(train) [10][ 900/2344]  lr: 5.000000e-04  eta: 0:17:22  time: 0.632377  data_time: 0.018012  memory: 7744  loss: 0.000131  loss_kpt: 0.000131  acc_pose: 0.943056
# 11/19 22:42:05 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 22:42:34 - mmengine - INFO - Epoch(train) [10][ 950/2344]  lr: 5.000000e-04  eta: 0:16:46  time: 0.634088  data_time: 0.018230  memory: 7744  loss: 0.000134  loss_kpt: 0.000134  acc_pose: 0.982778
# 11/19 22:43:05 - mmengine - INFO - Epoch(train) [10][1000/2344]  lr: 5.000000e-04  eta: 0:16:09  time: 0.634507  data_time: 0.018210  memory: 7744  loss: 0.000122  loss_kpt: 0.000122  acc_pose: 0.994872
# 11/19 22:43:37 - mmengine - INFO - Epoch(train) [10][1050/2344]  lr: 5.000000e-04  eta: 0:15:33  time: 0.631626  data_time: 0.017909  memory: 7744  loss: 0.000120  loss_kpt: 0.000120  acc_pose: 0.978611
# 11/19 22:44:09 - mmengine - INFO - Epoch(train) [10][1100/2344]  lr: 5.000000e-04  eta: 0:14:57  time: 0.636272  data_time: 0.018055  memory: 7744  loss: 0.000125  loss_kpt: 0.000125  acc_pose: 0.987500
# 11/19 22:44:40 - mmengine - INFO - Epoch(train) [10][1150/2344]  lr: 5.000000e-04  eta: 0:14:20  time: 0.632669  data_time: 0.018267  memory: 7744  loss: 0.000123  loss_kpt: 0.000123  acc_pose: 0.983056
# 11/19 22:45:12 - mmengine - INFO - Epoch(train) [10][1200/2344]  lr: 5.000000e-04  eta: 0:13:44  time: 0.635243  data_time: 0.019154  memory: 7744  loss: 0.000128  loss_kpt: 0.000128  acc_pose: 0.991667
# 11/19 22:45:44 - mmengine - INFO - Epoch(train) [10][1250/2344]  lr: 5.000000e-04  eta: 0:13:08  time: 0.636966  data_time: 0.018194  memory: 7744  loss: 0.000119  loss_kpt: 0.000119  acc_pose: 0.950606
# 11/19 22:46:16 - mmengine - INFO - Epoch(train) [10][1300/2344]  lr: 5.000000e-04  eta: 0:12:32  time: 0.635910  data_time: 0.018134  memory: 7744  loss: 0.000139  loss_kpt: 0.000139  acc_pose: 0.953889
# 11/19 22:46:47 - mmengine - INFO - Epoch(train) [10][1350/2344]  lr: 5.000000e-04  eta: 0:11:55  time: 0.631574  data_time: 0.017827  memory: 7744  loss: 0.000128  loss_kpt: 0.000128  acc_pose: 0.981777
# 11/19 22:47:19 - mmengine - INFO - Epoch(train) [10][1400/2344]  lr: 5.000000e-04  eta: 0:11:19  time: 0.633896  data_time: 0.017964  memory: 7744  loss: 0.000134  loss_kpt: 0.000134  acc_pose: 0.956917
# 11/19 22:47:51 - mmengine - INFO - Epoch(train) [10][1450/2344]  lr: 5.000000e-04  eta: 0:10:43  time: 0.635348  data_time: 0.018242  memory: 7744  loss: 0.000136  loss_kpt: 0.000136  acc_pose: 0.972698
# 11/19 22:48:22 - mmengine - INFO - Epoch(train) [10][1500/2344]  lr: 5.000000e-04  eta: 0:10:07  time: 0.632203  data_time: 0.018407  memory: 7744  loss: 0.000133  loss_kpt: 0.000133  acc_pose: 0.979167
# 11/19 22:48:55 - mmengine - INFO - Epoch(train) [10][1550/2344]  lr: 5.000000e-04  eta: 0:09:31  time: 0.642025  data_time: 0.022360  memory: 7744  loss: 0.000134  loss_kpt: 0.000134  acc_pose: 0.995556
# 11/19 22:49:26 - mmengine - INFO - Epoch(train) [10][1600/2344]  lr: 5.000000e-04  eta: 0:08:55  time: 0.632876  data_time: 0.017983  memory: 7744  loss: 0.000122  loss_kpt: 0.000122  acc_pose: 0.990794
# 11/19 22:49:58 - mmengine - INFO - Epoch(train) [10][1650/2344]  lr: 5.000000e-04  eta: 0:08:19  time: 0.633556  data_time: 0.018196  memory: 7744  loss: 0.000126  loss_kpt: 0.000126  acc_pose: 0.978205
# 11/19 22:50:30 - mmengine - INFO - Epoch(train) [10][1700/2344]  lr: 5.000000e-04  eta: 0:07:43  time: 0.632785  data_time: 0.018217  memory: 7744  loss: 0.000139  loss_kpt: 0.000139  acc_pose: 0.978205
# 11/19 22:51:01 - mmengine - INFO - Epoch(train) [10][1750/2344]  lr: 5.000000e-04  eta: 0:07:06  time: 0.632211  data_time: 0.018128  memory: 7744  loss: 0.000130  loss_kpt: 0.000130  acc_pose: 0.983056
# 11/19 22:51:33 - mmengine - INFO - Epoch(train) [10][1800/2344]  lr: 5.000000e-04  eta: 0:06:30  time: 0.635175  data_time: 0.019197  memory: 7744  loss: 0.000131  loss_kpt: 0.000131  acc_pose: 0.980794
# 11/19 22:52:05 - mmengine - INFO - Epoch(train) [10][1850/2344]  lr: 5.000000e-04  eta: 0:05:54  time: 0.633224  data_time: 0.017968  memory: 7744  loss: 0.000132  loss_kpt: 0.000132  acc_pose: 0.961677
# 11/19 22:52:36 - mmengine - INFO - Epoch(train) [10][1900/2344]  lr: 5.000000e-04  eta: 0:05:18  time: 0.633427  data_time: 0.017906  memory: 7744  loss: 0.000145  loss_kpt: 0.000145  acc_pose: 1.000000
# 11/19 22:52:39 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 22:53:08 - mmengine - INFO - Epoch(train) [10][1950/2344]  lr: 5.000000e-04  eta: 0:04:42  time: 0.636326  data_time: 0.017852  memory: 7744  loss: 0.000139  loss_kpt: 0.000139  acc_pose: 0.977381
# 11/19 22:53:40 - mmengine - INFO - Epoch(train) [10][2000/2344]  lr: 5.000000e-04  eta: 0:04:06  time: 0.632990  data_time: 0.017862  memory: 7744  loss: 0.000123  loss_kpt: 0.000123  acc_pose: 0.947500
# 11/19 22:54:11 - mmengine - INFO - Epoch(train) [10][2050/2344]  lr: 5.000000e-04  eta: 0:03:31  time: 0.633984  data_time: 0.018156  memory: 7744  loss: 0.000126  loss_kpt: 0.000126  acc_pose: 0.991667
# 11/19 22:54:43 - mmengine - INFO - Epoch(train) [10][2100/2344]  lr: 5.000000e-04  eta: 0:02:55  time: 0.633952  data_time: 0.018159  memory: 7744  loss: 0.000130  loss_kpt: 0.000130  acc_pose: 0.932799
# 11/19 22:55:15 - mmengine - INFO - Epoch(train) [10][2150/2344]  lr: 5.000000e-04  eta: 0:02:19  time: 0.634406  data_time: 0.018362  memory: 7744  loss: 0.000125  loss_kpt: 0.000125  acc_pose: 0.991667
# 11/19 22:55:47 - mmengine - INFO - Epoch(train) [10][2200/2344]  lr: 5.000000e-04  eta: 0:01:43  time: 0.635335  data_time: 0.018152  memory: 7744  loss: 0.000127  loss_kpt: 0.000127  acc_pose: 0.965000
# 11/19 22:56:18 - mmengine - INFO - Epoch(train) [10][2250/2344]  lr: 5.000000e-04  eta: 0:01:07  time: 0.631439  data_time: 0.018219  memory: 7744  loss: 0.000126  loss_kpt: 0.000126  acc_pose: 0.987500
# 11/19 22:56:50 - mmengine - INFO - Epoch(train) [10][2300/2344]  lr: 5.000000e-04  eta: 0:00:31  time: 0.631661  data_time: 0.018170  memory: 7744  loss: 0.000130  loss_kpt: 0.000130  acc_pose: 0.973106
# 11/19 22:57:17 - mmengine - INFO - Exp name: hrnet_20231119_175433
# 11/19 22:57:17 - mmengine - INFO - Saving checkpoint at 10 epochs
# 11/19 22:57:38 - mmengine - INFO - Epoch(val) [10][ 50/391]    eta: 0:01:58  time: 0.347156  data_time: 0.009120  memory: 7744
# 11/19 22:57:55 - mmengine - INFO - Epoch(val) [10][100/391]    eta: 0:01:40  time: 0.343033  data_time: 0.005125  memory: 1147
# 11/19 22:58:13 - mmengine - INFO - Epoch(val) [10][150/391]    eta: 0:01:23  time: 0.345908  data_time: 0.005115  memory: 1147
# 11/19 22:58:30 - mmengine - INFO - Epoch(val) [10][200/391]    eta: 0:01:05  time: 0.342476  data_time: 0.005125  memory: 1147
# 11/19 22:58:47 - mmengine - INFO - Epoch(val) [10][250/391]    eta: 0:00:48  time: 0.344058  data_time: 0.005138  memory: 1147
# 11/19 22:59:04 - mmengine - INFO - Epoch(val) [10][300/391]    eta: 0:00:31  time: 0.343532  data_time: 0.004752  memory: 1147
# 11/19 22:59:21 - mmengine - INFO - Epoch(val) [10][350/391]    eta: 0:00:14  time: 0.341345  data_time: 0.004737  memory: 1147
# 11/19 22:59:36 - mmengine - INFO - Evaluating CocoMetric...
# Loading and preparing results...
# DONE (t=0.16s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.89s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.966
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.990
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.966
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.974
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.995
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.974
# 11/19 22:59:37 - mmengine - INFO - Epoch(val) [10][391/391]    coco/AP: 0.965889  coco/AP .5: 1.000000  coco/AP .75: 0.990000  coco/AP (M): -1.000000  coco/AP (L): 0.965889  coco/AR: 0.974112  coco/AR .5: 1.000000  coco/AR .75: 0.995200  coco/AR (M): -1.000000  coco/AR (L): 0.974112  data_time: 0.005488  time: 0.343052
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'artifact' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# VBox(children=(Label(value='0.480 MB of 0.480 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc_pose</td><td>▁▆▆█▆▆▃▇▇▇▆█▆▇▇█▇▇▇▇▇▇█▆▆██▇▇▇█▇▇▇███▇▇▇</td></tr><tr><td>coco/AP</td><td>▁▅▆▆▅▆█▇▅▆</td></tr><tr><td>coco/AP (L)</td><td>▁▅▆▆▅▆█▇▅▆</td></tr><tr><td>coco/AP (M)</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>coco/AP .5</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>coco/AP .75</td><td>▁█████████</td></tr><tr><td>coco/AR</td><td>▁▅▆▆▅▆█▇▅▇</td></tr><tr><td>coco/AR (L)</td><td>▁▅▆▆▅▆█▇▅▇</td></tr><tr><td>coco/AR (M)</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>coco/AR .5</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>coco/AR .75</td><td>▁▅█▆▆██▆▇▇</td></tr><tr><td>data_time</td><td>▆▆▆▇█▄▆▅▄▁▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>iter</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_kpt</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>▁███████████████████████████████████████</td></tr><tr><td>memory</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time</td><td>███▇███▇▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc_pose</td><td>0.97311</td></tr><tr><td>coco/AP</td><td>0.96589</td></tr><tr><td>coco/AP (L)</td><td>0.96589</td></tr><tr><td>coco/AP (M)</td><td>-1.0</td></tr><tr><td>coco/AP .5</td><td>1.0</td></tr><tr><td>coco/AP .75</td><td>0.99</td></tr><tr><td>coco/AR</td><td>0.97411</td></tr><tr><td>coco/AR (L)</td><td>0.97411</td></tr><tr><td>coco/AR (M)</td><td>-1.0</td></tr><tr><td>coco/AR .5</td><td>1.0</td></tr><tr><td>coco/AR .75</td><td>0.9952</td></tr><tr><td>data_time</td><td>0.00549</td></tr><tr><td>epoch</td><td>10</td></tr><tr><td>iter</td><td>23396</td></tr><tr><td>loss</td><td>0.00013</td></tr><tr><td>loss_kpt</td><td>0.00013</td></tr><tr><td>lr</td><td>0.0005</td></tr><tr><td>memory</td><td>7744</td></tr><tr><td>time</td><td>0.34305</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lilac-bush-81</strong> at: <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/b1r5eebi' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/b1r5eebi</a><br/>Synced 6 W&B file(s), 0 media file(s), 64 artifact file(s) and 0 other file(s)
# Find logs at: <code>./mmengine_workdir/pose_estimator_2d_synthetic_cabin_ir/20231119_175433/vis_data/wandb/run-20231119_175441-b1r5eebi/logs</code>

# %%
pose_estimator_2d.test()
# Out:
# /opt/conda/lib/python3.10/site-packages/mmpose/datasets/datasets/utils.py:102: UserWarning: The metainfo config file "configs/_base_/datasets/coco.py" does not exist. A matched config file "/opt/conda/lib/python3.10/site-packages/mmpose/.mim/configs/_base_/datasets/coco.py" will be used instead.
#   warnings.warn(
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# 11/20 13:26:29 - mmengine - INFO - Epoch(test) [ 50/391]    eta: 0:02:02  time: 0.358780  data_time: 0.014198  memory: 1147
# 11/20 13:26:46 - mmengine - INFO - Epoch(test) [100/391]    eta: 0:01:42  time: 0.348662  data_time: 0.004803  memory: 1147
# 11/20 13:27:04 - mmengine - INFO - Epoch(test) [150/391]    eta: 0:01:25  time: 0.352718  data_time: 0.004820  memory: 1147
# 11/20 13:27:22 - mmengine - INFO - Epoch(test) [200/391]    eta: 0:01:07  time: 0.353537  data_time: 0.004844  memory: 1147
# 11/20 13:27:39 - mmengine - INFO - Epoch(test) [250/391]    eta: 0:00:49  time: 0.357433  data_time: 0.004809  memory: 1147
# 11/20 13:27:57 - mmengine - INFO - Epoch(test) [300/391]    eta: 0:00:32  time: 0.357798  data_time: 0.004803  memory: 1147
# 11/20 13:28:16 - mmengine - INFO - Epoch(test) [350/391]    eta: 0:00:14  time: 0.370923  data_time: 0.004757  memory: 1147
# 11/20 13:28:32 - mmengine - INFO - Evaluating CocoMetric...
# Loading and preparing results...
# DONE (t=0.16s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *keypoints*
# DONE (t=0.87s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.970
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.990
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.970
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 20 ] =  0.976
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets= 20 ] =  1.000
#  Average Recall     (AR) @[ IoU=0.75      | area=   all | maxDets= 20 ] =  0.995
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets= 20 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets= 20 ] =  0.976
# 11/20 13:28:33 - mmengine - INFO - Epoch(test) [391/391]    coco/AP: 0.969732  coco/AP .5: 1.000000  coco/AP .75: 0.990060  coco/AP (M): -1.000000  coco/AP (L): 0.969732  coco/AR: 0.975668  coco/AR .5: 1.000000  coco/AR .75: 0.995041  coco/AR (M): -1.000000  coco/AR (L): 0.975668  data_time: 0.006016  time: 0.357673
