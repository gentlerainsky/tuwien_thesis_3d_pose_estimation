# %%
import pandas as pd
from pathlib import Path
from IPython.display import display
import cv2
from modules.data_preprocessing.drive_and_act_preprocessor import DriveAndActPreprocessor

# %%
# !rm -rf /root/data/processed/drive_and_act

# %%
# activity_df = pd.read_csv('/root/data/raw/drive_and_act/iccv_activities_3s/activities_3s/a_column_co_driver/midlevel.chunks_90.csv')

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     output = activity_df[
#         # (activity_df['file_id'] == 'vp15/run2_2018-05-30-13-34-33.ids_2')
#         (activity_df['file_id'] == 'vp7/run2b_2018-05-23-13-54-07.ids_2')
#         # & (activity_df['frame_start'] <= 300)
#         # & (activity_df['frame_end'] >= 300)
#         ]
#         # ].activity.iloc[0]
#     display(output)
# output.shape[0]

# %%
drive_and_act_preprocessor = DriveAndActPreprocessor(
    dataset_root='/root/data/raw/drive_and_act',
    video_root='a_column_co_driver',
    source_annotation_3d_root='iccv_openpose_3d/openpose_3d',
    activity_annotation_path='iccv_activities_3s/activities_3s/a_column_co_driver/midlevel.chunks_90.csv',
    destination_root='/root/data/processed/drive_and_act',
    image_folder='images',
    train_image_folder='train',
    val_image_folder='val',
    test_image_folder='test',
    destination_annotation_folder='annotations',
    train_subset=['vp1', 'vp2', 'vp3', 'vp4', 'vp5', 'vp6', 'vp7', 'vp8', 'vp9', 'vp10'],
    val_subset=['vp11', 'vp12'],
    test_subset=['vp13', 'vp14', 'vp15'],
    sampling_rate=30
)
# Out:
# created a folder at /root/data/processed/drive_and_act.
# created a folder at /root/data/processed/drive_and_act/images.
# created a folder at /root/data/processed/drive_and_act/images/train.
# created a folder at /root/data/processed/drive_and_act/images/val.
# created a folder at /root/data/processed/drive_and_act/images/test.
# created a folder at /root/data/processed/drive_and_act/annotations.

# %%
# %%time
drive_and_act_preprocessor.extract_all()
# Out:
# extracting
# ['vp15', 'vp8', 'vp3', 'vp12', 'vp9', 'vp13', 'vp2', 'vp6', 'vp7', 'vp10', 'vp11', 'vp14', 'vp5', 'vp1', 'vp4']
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run2_2018-05-30-13-34-33.ids_2.mp4.
# total_frames = 38957
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run2_2018-05-30-13-34-33.ids_2.mp4. Using 77.20252203941345 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run1_2018-05-30-13-05-35.ids_2.mp4.
# total_frames = 37263
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run1_2018-05-30-13-05-35.ids_2.mp4. Using 72.92144560813904 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run1d_2018-05-23-14-54-38.ids_2.mp4.
# total_frames = 45657
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run1d_2018-05-23-14-54-38.ids_2.mp4. Using 86.90848016738892 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run2_2018-05-23-15-30-27.ids_2.mp4.
# total_frames = 39543
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run2_2018-05-23-15-30-27.ids_2.mp4. Using 76.08047318458557 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run1b_2018-05-08-08-46-01.ids_2.mp4.
# total_frames = 40138
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run1b_2018-05-08-08-46-01.ids_2.mp4. Using 62.463194370269775 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run2_2018-05-29-16-03-37.ids_2.mp4.
# total_frames = 32406
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run2_2018-05-29-16-03-37.ids_2.mp4. Using 63.53966736793518 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run2_2018-05-24-16-21-35.ids_2.mp4.
# total_frames = 50236
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run2_2018-05-24-16-21-35.ids_2.mp4. Using 96.29270648956299 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run1_2018-05-24-15-44-28.ids_2.mp4.
# total_frames = 39483
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run1_2018-05-24-15-44-28.ids_2.mp4. Using 75.68785858154297 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1_2018-05-23-16-18-22.ids_2.mp4.
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1_2018-05-23-16-18-22.ids_2.mp4. Using 2.86102294921875e-06 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1b_2018-05-23-16-19-17.ids_2.mp4.
# total_frames = 30258
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1b_2018-05-23-16-19-17.ids_2.mp4. Using 60.40879011154175 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run2_2018-05-30-11-34-54.ids_2.mp4.
# total_frames = 40290
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run2_2018-05-30-11-34-54.ids_2.mp4. Using 77.47920107841492 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run1_2018-05-29-15-21-10.ids_2.mp4.
# total_frames = 46052
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run1_2018-05-29-15-21-10.ids_2.mp4. Using 89.4208755493164 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run2_2018-05-24-17-22-26.ids_2.mp4.
# total_frames = 40389
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run2_2018-05-24-17-22-26.ids_2.mp4. Using 77.36744284629822 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run1_2018-05-03-14-08-31.ids_2.mp4.
# total_frames = 45230
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run1_2018-05-03-14-08-31.ids_2.mp4. Using 71.70236229896545 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run2_2018-05-23-11-05-00.ids_2.mp4.
# total_frames = 42412
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run2_2018-05-23-11-05-00.ids_2.mp4. Using 79.02345705032349 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run1_2018-05-23-10-21-45.ids_2.mp4.
# total_frames = 53525
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run1_2018-05-23-10-21-45.ids_2.mp4. Using 99.17707180976868 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run2b_2018-05-23-13-54-07.ids_2.mp4.
# total_frames = 26495
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run2b_2018-05-23-13-54-07.ids_2.mp4. Using 50.403918743133545 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run1_2018-05-23-13-16-52.ids_2.mp4.
# total_frames = 39750
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run1_2018-05-23-13-16-52.ids_2.mp4. Using 76.20454740524292 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run2_2018-05-24-14-08-46.ids_2.mp4.
# total_frames = 41150
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run2_2018-05-24-14-08-46.ids_2.mp4. Using 78.20193982124329 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run1_2018-05-24-13-14-41.ids_2.mp4.
# total_frames = 41951
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run1_2018-05-24-13-14-41.ids_2.mp4. Using 78.590491771698 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run2_2018-05-24-14-35-56.ids_2.mp4.
# total_frames = 27238
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run2_2018-05-24-14-35-56.ids_2.mp4. Using 51.00518226623535 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run1_2018-05-24-13-44-01.ids_2.mp4.
# total_frames = 37220
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run1_2018-05-24-13-44-01.ids_2.mp4. Using 69.48602366447449 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run2_2018-05-30-10-42-33.ids_2.mp4.
# total_frames = 44250
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run2_2018-05-30-10-42-33.ids_2.mp4. Using 85.13191723823547 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run1_2018-05-30-10-11-09.ids_2.mp4.
# total_frames = 48706
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run1_2018-05-30-10-11-09.ids_2.mp4. Using 88.00550436973572 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run1_2018-05-22-15-10-41.ids_2.mp4.
# total_frames = 52828
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run1_2018-05-22-15-10-41.ids_2.mp4. Using 91.34379148483276 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run2b_2018-05-22-15-50-07.ids_2.mp4.
# total_frames = 38615
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run2b_2018-05-22-15-50-07.ids_2.mp4. Using 68.44761157035828 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run1b_2018-05-29-14-02-47.ids_2.mp4.
# total_frames = 37729
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run1b_2018-05-29-14-02-47.ids_2.mp4. Using 72.7007622718811 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run2_2018-05-29-14-33-44.ids_2.mp4.
# total_frames = 42427
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run2_2018-05-29-14-33-44.ids_2.mp4. Using 82.52060103416443 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run1_2018-05-22-13-28-51.ids_2.mp4.
# total_frames = 66072
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run1_2018-05-22-13-28-51.ids_2.mp4. Using 115.7432610988617 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run2_2018-05-22-14-25-04.ids_2.mp4.
# total_frames = 54127
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run2_2018-05-22-14-25-04.ids_2.mp4. Using 94.70861053466797 seconds
# CPU times: user 4h 39min 45s, sys: 8min 19s, total: 4h 48min 4s
# Wall time: 37min 50s
