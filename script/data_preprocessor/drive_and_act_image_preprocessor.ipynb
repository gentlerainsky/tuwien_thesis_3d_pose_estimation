# %%
import pandas as pd
from pathlib import Path
from IPython.display import display
import cv2
from modules.data_preprocessing.drive_and_act_preprocessor import DriveAndActPreprocessor

# %%
# !rm -rf /root/data/processed/drive_and_act

# %%
# activity_df = pd.read_csv('/root/data/raw/drive_and_act/iccv_activities_3s/activities_3s/a_column_co_driver/midlevel.chunks_90.csv')

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     output = activity_df[
#         # (activity_df['file_id'] == 'vp15/run2_2018-05-30-13-34-33.ids_2')
#         (activity_df['file_id'] == 'vp7/run2b_2018-05-23-13-54-07.ids_2')
#         # & (activity_df['frame_start'] <= 300)
#         # & (activity_df['frame_end'] >= 300)
#         ]
#         # ].activity.iloc[0]
#     display(output)
# output.shape[0]

# %%
drive_and_act_preprocessor = DriveAndActPreprocessor(
    dataset_root='/root/data/raw/drive_and_act',
    video_root='a_column_co_driver',
    source_annotation_3d_root='iccv_openpose_3d/openpose_3d',
    activity_annotation_path='iccv_activities_3s/activities_3s/a_column_co_driver/midlevel.chunks_90.csv',
    destination_root='/root/data/processed/drive_and_act',
    image_folder='images',
    train_image_folder='train',
    val_image_folder='val',
    test_image_folder='test',
    destination_annotation_folder='annotations',
    train_subset=['vp1', 'vp2', 'vp3', 'vp4', 'vp5', 'vp6', 'vp7', 'vp8', 'vp9', 'vp10', 'vp11', 'vp12', 'vp13', 'vp14', 'vp15'],
    val_subset=[],
    test_subset=[],
    sampling_rate=30
)
# Out:
# created a folder at /root/data/processed/drive_and_act.
# created a folder at /root/data/processed/drive_and_act/images.
# created a folder at /root/data/processed/drive_and_act/images/train.
# created a folder at /root/data/processed/drive_and_act/images/val.
# created a folder at /root/data/processed/drive_and_act/images/test.
# created a folder at /root/data/processed/drive_and_act/annotations.

# %%
# %%time
drive_and_act_preprocessor.extract_all()
# Out:
# extracting
# ['vp15', 'vp8', 'vp3', 'vp12', 'vp9', 'vp13', 'vp2', 'vp6', 'vp7', 'vp10', 'vp11', 'vp14', 'vp5', 'vp1', 'vp4']
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run2_2018-05-30-13-34-33.ids_2.mp4.
# total_frames = 38957
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run2_2018-05-30-13-34-33.ids_2.mp4. Using 115.50068640708923 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run1_2018-05-30-13-05-35.ids_2.mp4.
# total_frames = 37263
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp15/run1_2018-05-30-13-05-35.ids_2.mp4. Using 111.03246092796326 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run1d_2018-05-23-14-54-38.ids_2.mp4.
# total_frames = 45657
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run1d_2018-05-23-14-54-38.ids_2.mp4. Using 132.25748825073242 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run2_2018-05-23-15-30-27.ids_2.mp4.
# total_frames = 39543
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp8/run2_2018-05-23-15-30-27.ids_2.mp4. Using 112.09363746643066 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run1b_2018-05-08-08-46-01.ids_2.mp4.
# total_frames = 40138
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run1b_2018-05-08-08-46-01.ids_2.mp4. Using 107.03703737258911 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run2_2018-05-29-16-03-37.ids_2.mp4.
# total_frames = 32406
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp3/run2_2018-05-29-16-03-37.ids_2.mp4. Using 95.3144018650055 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run2_2018-05-24-16-21-35.ids_2.mp4.
# total_frames = 50236
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run2_2018-05-24-16-21-35.ids_2.mp4. Using 148.96120643615723 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run1_2018-05-24-15-44-28.ids_2.mp4.
# total_frames = 39483
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp12/run1_2018-05-24-15-44-28.ids_2.mp4. Using 119.26108431816101 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1_2018-05-23-16-18-22.ids_2.mp4.
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1_2018-05-23-16-18-22.ids_2.mp4. Using 4.291534423828125e-06 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1b_2018-05-23-16-19-17.ids_2.mp4.
# total_frames = 30258
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp9/run1b_2018-05-23-16-19-17.ids_2.mp4. Using 96.98533368110657 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run2_2018-05-30-11-34-54.ids_2.mp4.
# total_frames = 40290
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run2_2018-05-30-11-34-54.ids_2.mp4. Using 121.95582222938538 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run1_2018-05-29-15-21-10.ids_2.mp4.
# total_frames = 46052
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp13/run1_2018-05-29-15-21-10.ids_2.mp4. Using 137.77631402015686 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run2_2018-05-24-17-22-26.ids_2.mp4.
# total_frames = 40389
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run2_2018-05-24-17-22-26.ids_2.mp4. Using 118.50181317329407 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run1_2018-05-03-14-08-31.ids_2.mp4.
# total_frames = 45230
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp2/run1_2018-05-03-14-08-31.ids_2.mp4. Using 121.6672670841217 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run2_2018-05-23-11-05-00.ids_2.mp4.
# total_frames = 42412
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run2_2018-05-23-11-05-00.ids_2.mp4. Using 123.67418360710144 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run1_2018-05-23-10-21-45.ids_2.mp4.
# total_frames = 53525
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp6/run1_2018-05-23-10-21-45.ids_2.mp4. Using 158.15929865837097 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run2b_2018-05-23-13-54-07.ids_2.mp4.
# total_frames = 26495
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run2b_2018-05-23-13-54-07.ids_2.mp4. Using 79.4454915523529 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run1_2018-05-23-13-16-52.ids_2.mp4.
# total_frames = 39750
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp7/run1_2018-05-23-13-16-52.ids_2.mp4. Using 122.44807147979736 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run2_2018-05-24-14-08-46.ids_2.mp4.
# total_frames = 41150
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run2_2018-05-24-14-08-46.ids_2.mp4. Using 132.16607236862183 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run1_2018-05-24-13-14-41.ids_2.mp4.
# total_frames = 41951
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp10/run1_2018-05-24-13-14-41.ids_2.mp4. Using 130.27326607704163 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run2_2018-05-24-14-35-56.ids_2.mp4.
# total_frames = 27238
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run2_2018-05-24-14-35-56.ids_2.mp4. Using 83.66695404052734 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run1_2018-05-24-13-44-01.ids_2.mp4.
# total_frames = 37220
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp11/run1_2018-05-24-13-44-01.ids_2.mp4. Using 110.25894212722778 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run2_2018-05-30-10-42-33.ids_2.mp4.
# total_frames = 44250
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run2_2018-05-30-10-42-33.ids_2.mp4. Using 132.98754334449768 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run1_2018-05-30-10-11-09.ids_2.mp4.
# total_frames = 48706
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp14/run1_2018-05-30-10-11-09.ids_2.mp4. Using 144.57714939117432 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run1_2018-05-22-15-10-41.ids_2.mp4.
# total_frames = 52828
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run1_2018-05-22-15-10-41.ids_2.mp4. Using 156.00958847999573 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run2b_2018-05-22-15-50-07.ids_2.mp4.
# total_frames = 38615
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp5/run2b_2018-05-22-15-50-07.ids_2.mp4. Using 112.15278053283691 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run1b_2018-05-29-14-02-47.ids_2.mp4.
# total_frames = 37729
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run1b_2018-05-29-14-02-47.ids_2.mp4. Using 71.59937715530396 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run2_2018-05-29-14-33-44.ids_2.mp4.
# total_frames = 42427
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp1/run2_2018-05-29-14-33-44.ids_2.mp4. Using 79.98403406143188 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run1_2018-05-22-13-28-51.ids_2.mp4.
# total_frames = 66072
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run1_2018-05-22-13-28-51.ids_2.mp4. Using 114.67726349830627 seconds
# start processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run2_2018-05-22-14-25-04.ids_2.mp4.
# total_frames = 54127
# frame_rate = 30
# finish processing /root/data/raw/drive_and_act/a_column_co_driver/vp4/run2_2018-05-22-14-25-04.ids_2.mp4. Using 98.12323188781738 seconds
# CPU times: user 6h 54min 12s, sys: 9min 52s, total: 7h 4min 5s
# Wall time: 56min 30s
