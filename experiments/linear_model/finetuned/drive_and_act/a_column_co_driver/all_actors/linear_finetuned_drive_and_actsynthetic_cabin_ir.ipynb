# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_drive_and_act_dataset, drive_and_act_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'a_column_co_driver'
pretrained_dataset_name='synthetic_cabin_ir'
pretrained_datasubset_name=f'{viewpoint}_predicted'

pretrained_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=pretrained_dataset_name,
    trained_datasubset_name=pretrained_datasubset_name,
)
constructed_loader = construct_drive_and_act_dataset(
    dataset_root_path=drive_and_act_dataset_root_path,
    viewpoint=viewpoint
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    model_suffix='all_actors',
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
    pretrained_dataset_name=pretrained_dataset_name,
    pretrained_datasubset_name=pretrained_datasubset_name,
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    pretrained_model_path=pretrained_model_path,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# skipping problematic image 3628
# skipping problematic image 5874
# skipping problematic image 14835
# Annotation is not found for 15783
# Annotation is not found for 17258
# Annotation is not found for 17259
# Annotation is not found for 21271
# Annotation is not found for 21272
# Annotation is not found for 21273
# Annotation is not found for 21274
# Annotation is not found for 21275
# Annotation is not found for 21276
# skipping problematic image 32959
# Annotation is not found for 33527
# skipping problematic image 28113
# train_dataset 22881 val_dataset 6240 test_dataset 11017
# loaded from ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir/A_Pillar_Codriver_predicted
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/A_Pillar_Codriver_predicted/transfer_learning/synthetic_cabin_ir/A_Pillar_Codriver_predicted/all_actors/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# train_dataset 22881 val_dataset 6240 test_dataset 11017
# loaded from ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir/A_Pillar_Codriver_predicted
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 6208 samples : 135.4164183139801
# activity_macro_mpjpe 151.63956582546234
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 1785 batches: 130.2703456593161
# val MPJPE from: 6208 samples : 84.7240462899208
# activity_macro_mpjpe 127.15233862400055
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 1785 batches: 118.73916645928257
# val MPJPE from: 6208 samples : 81.35629445314407
# activity_macro_mpjpe 117.91951209306717
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 1785 batches: 113.29061688662243
# val MPJPE from: 6208 samples : 80.854631960392
# activity_macro_mpjpe 113.13749104738235
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 1785 batches: 109.59756146459019
# val MPJPE from: 6208 samples : 80.42453229427338
# activity_macro_mpjpe 110.20883917808533
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 1785 batches: 107.00280248951844
# val MPJPE from: 6208 samples : 78.91649752855301
# activity_macro_mpjpe 108.01946371793747
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 1785 batches: 105.07893276815655
# val MPJPE from: 6208 samples : 78.91996949911118
# activity_macro_mpjpe 106.45930469036102
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 1785 batches: 103.40321513534593
# val MPJPE from: 6208 samples : 77.69137620925903
# activity_macro_mpjpe 105.12684285640717
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 1785 batches: 102.92506137815845
# val MPJPE from: 6208 samples : 77.50728726387024
# activity_macro_mpjpe 104.08302396535873
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 1785 batches: 101.47090446130902
# val MPJPE from: 6208 samples : 76.96555554866791
# activity_macro_mpjpe 103.18826884031296
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 1785 batches: 100.59643049700921
# val MPJPE from: 6208 samples : 77.09496468305588
# activity_macro_mpjpe 102.46992111206055
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 1785 batches: 100.16128406638191
# val MPJPE from: 6208 samples : 78.49132269620895
# activity_macro_mpjpe 101.98424011468887
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 1785 batches: 98.80255827215873
# val MPJPE from: 6208 samples : 77.58194953203201
# activity_macro_mpjpe 101.50489956140518
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 1785 batches: 98.72370972937229
# val MPJPE from: 6208 samples : 75.89387148618698
# activity_macro_mpjpe 100.97138583660126
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 1785 batches: 98.69893469980785
# val MPJPE from: 6208 samples : 76.73093676567078
# activity_macro_mpjpe 100.56687891483307
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 1785 batches: 98.23032468557358
# val MPJPE from: 6208 samples : 76.4884278178215
# activity_macro_mpjpe 100.19687563180923
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 1785 batches: 98.12023674740512
# val MPJPE from: 6208 samples : 76.95510983467102
# activity_macro_mpjpe 99.89994764328003
# Validation: 0it [00:00, ?it/s]
# check #17
# training loss from 1785 batches: 97.53934114503593
# val MPJPE from: 6208 samples : 76.67800039052963
# activity_macro_mpjpe 99.61973130702972
# Validation: 0it [00:00, ?it/s]
# check #18
# training loss from 1785 batches: 98.3245467730597
# val MPJPE from: 6208 samples : 77.15383172035217
# activity_macro_mpjpe 99.39594566822052

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/A_Pillar_Codriver_predicted/transfer_learning/synthetic_cabin_ir/A_Pillar_Codriver_predicted/all_actors/lightning_logs/version_0/checkpoints/epoch=64-step=23205.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/A_Pillar_Codriver_predicted/transfer_learning/synthetic_cabin_ir/A_Pillar_Codriver_predicted/all_actors/lightning_logs/version_0/checkpoints/epoch=64-step=23205.ckpt
# Testing: 0it [00:00, ?it/s]
# activity_macro_mpjpe 98.16936403512955
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   activity_macro_mpjpe    │     98.16936403512955     │
# │           mpjpe           │     68.08162480592728     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 68.08162480592728
# PJPE =
#                       PJPE
# nose             58.736988
# left_eye         55.551655
# right_eye        53.482273
# left_ear         14.277382
# right_ear        38.023441
# left_shoulder    18.108997
# right_shoulder   22.785963
# left_elbow       74.722954
# right_elbow      76.308258
# left_wrist       89.518814
# right_wrist     116.567734
# left_hip         65.897652
# right_hip        62.276291
# Activity-based Macro Average MPJPE = 98.16936403512955
# activity_mpjpe =
#                                                 MPJPE
# sitting_still                               65.317526
# closing_door_inside                        128.866047
# entering_car                               200.522020
# pressing_automation_button                  59.954710
# fetching_an_object                         151.496440
# drinking                                    75.321071
# opening_bottle                              77.441968
# closing_bottle                              77.640973
# eating                                      63.683212
# placing_an_object                          146.874979
# preparing_food                             152.095839
# opening_backpack                           188.524440
# reading_newspaper                           86.401254
# using_multimedia_display                    96.294753
# writing                                     91.939792
# taking_off_sunglasses                      105.365440
# unfastening_seat_belt                       95.150918
# putting_on_jacket                          227.797776
# talking_on_phone                           111.916445
# fastening_seat_belt                        125.345394
# putting_on_sunglasses                       80.074184
# reading_magazine                            65.038525
# taking_off_jacket                          243.220374
# looking_or_moving_around (e.g. searching)  159.182683
# opening_laptop                             113.787070
# working_on_laptop                           76.534040
# interacting_with_phone                      69.874749
# closing_laptop                             120.401844
# exiting_car                                260.233134
# taking_laptop_from_backpack                175.391614
# putting_laptop_into_backpack               275.211751
# opening_door_inside                        162.771598

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    drive_and_act_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    drive_and_act_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
