# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_drive_and_act_dataset, drive_and_act_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'a_column_co_driver'
pretrained_dataset_name='synthetic_cabin_ir_1m'
pretrained_datasubset_name=f'{viewpoint}_gt'

pretrained_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=pretrained_dataset_name,
    trained_datasubset_name=pretrained_datasubset_name,
)
constructed_loader = construct_drive_and_act_dataset(
    dataset_root_path=drive_and_act_dataset_root_path,
    viewpoint=viewpoint
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    model_suffix='all_actors',
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
    pretrained_dataset_name=pretrained_dataset_name,
    pretrained_datasubset_name=pretrained_datasubset_name,
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    pretrained_model_path=pretrained_model_path,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# skipping problematic image 3628
# skipping problematic image 5874
# skipping problematic image 14835
# Annotation is not found for 15783
# Annotation is not found for 17258
# Annotation is not found for 17259
# Annotation is not found for 21271
# Annotation is not found for 21272
# Annotation is not found for 21273
# Annotation is not found for 21274
# Annotation is not found for 21275
# Annotation is not found for 21276
# skipping problematic image 32959
# Annotation is not found for 33527
# skipping problematic image 28113
# train_dataset 22881 val_dataset 6240 test_dataset 11017
# loaded from ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/A_Pillar_Codriver_predicted/transfer_learning/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/all_actors/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# train_dataset 22881 val_dataset 6240 test_dataset 11017
# loaded from ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 6208 samples : 116.29676073789597
# activity_macro_mpjpe 132.50574469566345
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 1785 batches: 127.7765087512027
# val MPJPE from: 6208 samples : 81.09284937381744
# activity_macro_mpjpe 99.21256452798843
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 1785 batches: 116.74607285514934
# val MPJPE from: 6208 samples : 76.10518485307693
# activity_macro_mpjpe 94.12870556116104
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 1785 batches: 111.39735003479389
# val MPJPE from: 6208 samples : 77.73151248693466
# activity_macro_mpjpe 95.69539874792099
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 1785 batches: 108.28859387826519
# val MPJPE from: 6208 samples : 77.65693962574005
# activity_macro_mpjpe 95.70483863353729
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 1785 batches: 105.62081512700276
# val MPJPE from: 6208 samples : 76.71941816806793
# activity_macro_mpjpe 94.86059099435806
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 1785 batches: 103.73852398632621
# val MPJPE from: 6208 samples : 77.11923867464066
# activity_macro_mpjpe 95.3146368265152
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 1785 batches: 102.48403813825601
# val MPJPE from: 6208 samples : 75.90249925851822
# activity_macro_mpjpe 94.04569864273071
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 1785 batches: 101.83703198569829
# val MPJPE from: 6208 samples : 75.96532255411148
# activity_macro_mpjpe 94.11932528018951
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 1785 batches: 100.57730601281345
# val MPJPE from: 6208 samples : 75.49774646759033
# activity_macro_mpjpe 93.60574185848236
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 1785 batches: 99.6354469773816
# val MPJPE from: 6208 samples : 75.30172169208527
# activity_macro_mpjpe 93.44494342803955
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 1785 batches: 99.43379387468184
# val MPJPE from: 6208 samples : 75.81129670143127
# activity_macro_mpjpe 93.91430020332336
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 1785 batches: 97.99762834020022
# val MPJPE from: 6208 samples : 75.90138167142868
# activity_macro_mpjpe 93.99806708097458
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 1785 batches: 98.19029672306125
# val MPJPE from: 6208 samples : 74.63889569044113
# activity_macro_mpjpe 92.73239225149155
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 1785 batches: 98.21020055468344
# val MPJPE from: 6208 samples : 75.76967030763626
# activity_macro_mpjpe 93.90781074762344
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 1785 batches: 97.36881642615428
# val MPJPE from: 6208 samples : 75.40706545114517
# activity_macro_mpjpe 93.51536631584167
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 1785 batches: 97.43785417797852
# val MPJPE from: 6208 samples : 75.49011707305908
# activity_macro_mpjpe 93.64478290081024
# Validation: 0it [00:00, ?it/s]
# check #17
# training loss from 1785 batches: 97.04017904208821
# val MPJPE from: 6208 samples : 75.5879282951355
# activity_macro_mpjpe 93.74076873064041
# Validation: 0it [00:00, ?it/s]
# check #18
# training loss from 1785 batches: 97.55458528337692
# val MPJPE from: 6208 samples : 75.57503134012222
# activity_macro_mpjpe 93.73631328344345

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/A_Pillar_Codriver_predicted/transfer_learning/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/all_actors/lightning_logs/version_0/checkpoints/epoch=64-step=23205.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/A_Pillar_Codriver_predicted/transfer_learning/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/all_actors/lightning_logs/version_0/checkpoints/epoch=64-step=23205.ckpt
# Testing: 0it [00:00, ?it/s]
# activity_macro_mpjpe 84.0861052274704
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   activity_macro_mpjpe    │     84.0861052274704      │
# │           mpjpe           │     67.09414720535278     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 67.09414720535278
# PJPE =
#                       PJPE
# nose             58.003002
# left_eye         54.658566
# right_eye        53.107277
# left_ear         14.444862
# right_ear        36.945263
# left_shoulder    17.957275
# right_shoulder   23.131010
# left_elbow       73.229889
# right_elbow      75.022141
# left_wrist       86.399910
# right_wrist     115.334373
# left_hip         64.398819
# right_hip        62.247704
# Activity-based Macro Average MPJPE = 84.0861052274704
# activity_mpjpe =
#                                                 MPJPE
# entering_car                               192.468196
# closing_door_inside                        126.479283
# sitting_still                               64.768195
# pressing_automation_button                  59.406638
# drinking                                    74.437432
# closing_bottle                              76.201566
# fetching_an_object                         151.619881
# opening_bottle                              74.395411
# placing_an_object                          146.858588
# opening_backpack                           188.823983
# preparing_food                             158.410579
# eating                                      60.874362
# reading_newspaper                           84.321789
# using_multimedia_display                    95.307849
# taking_off_sunglasses                      104.559176
# writing                                     91.523997
# unfastening_seat_belt                       94.901554
# putting_on_jacket                          223.167032
# putting_on_sunglasses                       79.597242
# talking_on_phone                           105.474301
# fastening_seat_belt                        127.050608
# reading_magazine                            64.693511
# taking_off_jacket                          241.289988
# looking_or_moving_around (e.g. searching)  158.436254
# opening_laptop                             115.776494
# working_on_laptop                           73.466472
# interacting_with_phone                      68.991058
# closing_laptop                             133.842438
# exiting_car                                259.225070
# taking_laptop_from_backpack                188.206524
# putting_laptop_into_backpack               277.469575
# opening_door_inside                        164.104402

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    drive_and_act_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    drive_and_act_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
