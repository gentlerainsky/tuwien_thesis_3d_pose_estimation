# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_drive_and_act_dataset, drive_and_act_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'inner_mirror'
pretrained_dataset_name='synthetic_cabin_ir_1m'
pretrained_datasubset_name=f'Rear_Mirror_gt'

pretrained_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=pretrained_dataset_name,
    trained_datasubset_name=pretrained_datasubset_name,
)
constructed_loader = construct_drive_and_act_dataset(
    dataset_root_path=drive_and_act_dataset_root_path,
    viewpoint=viewpoint
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    model_suffix='all_actors',
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
    pretrained_dataset_name=pretrained_dataset_name,
    pretrained_datasubset_name=pretrained_datasubset_name,
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    pretrained_model_path=pretrained_model_path,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# train_dataset 22896 val_dataset 6241 test_dataset 11017
# loaded from ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/Rear_Mirror_gt
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/inner_mirror/transfer_learning/synthetic_cabin_ir_1m/Rear_Mirror_gt/all_actors/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# train_dataset 22896 val_dataset 6241 test_dataset 11017
# loaded from ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/Rear_Mirror_gt
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 6208 samples : 178.13578248023987
# activity_macro_mpjpe 192.17447936534882
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 1785 batches: 119.90779136576238
# val MPJPE from: 6208 samples : 72.59202003479004
# activity_macro_mpjpe 91.73934161663055
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 1785 batches: 110.02398876248957
# val MPJPE from: 6208 samples : 69.25677508115768
# activity_macro_mpjpe 88.2948487997055
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 1785 batches: 104.11220062263206
# val MPJPE from: 6208 samples : 70.13478875160217
# activity_macro_mpjpe 89.08127248287201
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 1785 batches: 100.81023739791718
# val MPJPE from: 6208 samples : 70.72948664426804
# activity_macro_mpjpe 89.84144777059555
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 1785 batches: 98.33713595022341
# val MPJPE from: 6208 samples : 69.81115788221359
# activity_macro_mpjpe 88.70846778154373
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 1785 batches: 96.00681588679802
# val MPJPE from: 6208 samples : 69.2245215177536
# activity_macro_mpjpe 88.2006362080574
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 1785 batches: 94.3573418848154
# val MPJPE from: 6208 samples : 69.59675997495651
# activity_macro_mpjpe 88.46703916788101
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 1785 batches: 93.3088865684194
# val MPJPE from: 6208 samples : 68.75713914632797
# activity_macro_mpjpe 87.64248341321945
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 1785 batches: 92.62325361120601
# val MPJPE from: 6208 samples : 68.86303424835205
# activity_macro_mpjpe 87.69534528255463
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 1785 batches: 91.71435135085376
# val MPJPE from: 6208 samples : 67.93271750211716
# activity_macro_mpjpe 86.82414889335632
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 1785 batches: 89.76670470015675
# val MPJPE from: 6208 samples : 66.91702455282211
# activity_macro_mpjpe 85.81509441137314
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 1785 batches: 90.85553391140049
# val MPJPE from: 6208 samples : 68.81546229124069
# activity_macro_mpjpe 87.65922486782074
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 1785 batches: 90.2376871232559
# val MPJPE from: 6208 samples : 67.75467842817307
# activity_macro_mpjpe 86.73188835382462
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 1785 batches: 89.4169778967438
# val MPJPE from: 6208 samples : 68.3017298579216
# activity_macro_mpjpe 87.22557872533798
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 1785 batches: 89.33769404178574
# val MPJPE from: 6208 samples : 67.37130135297775
# activity_macro_mpjpe 86.28349751234055
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 1785 batches: 89.32327778608192
# val MPJPE from: 6208 samples : 67.70377606153488
# activity_macro_mpjpe 86.67361736297607

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/inner_mirror/transfer_learning/synthetic_cabin_ir_1m/Rear_Mirror_gt/all_actors/lightning_logs/version_0/checkpoints/epoch=54-step=19635.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/inner_mirror/transfer_learning/synthetic_cabin_ir_1m/Rear_Mirror_gt/all_actors/lightning_logs/version_0/checkpoints/epoch=54-step=19635.ckpt
# Testing: 0it [00:00, ?it/s]
# activity_macro_mpjpe 77.2622600197792
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   activity_macro_mpjpe    │     77.2622600197792      │
# │           mpjpe           │    58.920133858919144     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 58.920133858919144
# PJPE =
#                      PJPE
# nose            49.780178
# left_eye        46.428200
# right_eye       45.437599
# left_ear        12.639721
# right_ear       33.793221
# left_shoulder   17.005020
# right_shoulder  23.047045
# left_elbow      68.877357
# right_elbow     63.018196
# left_wrist      74.407616
# right_wrist     82.286057
# left_hip        63.662663
# right_hip       63.510643
# Activity-based Macro Average MPJPE = 77.2622600197792
# activity_mpjpe =
#                                                 MPJPE
# closing_door_inside                        121.632680
# entering_car                               191.735148
# fastening_seat_belt                        117.045760
# sitting_still                               59.817780
# fetching_an_object                         140.242010
# pressing_automation_button                  50.871734
# putting_on_jacket                          204.610914
# unfastening_seat_belt                       87.090202
# placing_an_object                          130.356953
# taking_off_jacket                          235.341489
# opening_backpack                           198.066741
# taking_laptop_from_backpack                149.533674
# working_on_laptop                           78.298599
# interacting_with_phone                      78.613147
# closing_laptop                             124.002993
# putting_laptop_into_backpack               257.403314
# drinking                                    61.041694
# opening_bottle                              60.566153
# closing_bottle                              74.683137
# eating                                      47.455251
# using_multimedia_display                    82.759701
# reading_magazine                            63.088536
# taking_off_sunglasses                      116.778120
# writing                                     83.038971
# putting_on_sunglasses                       83.830871
# reading_newspaper                           77.801198
# talking_on_phone                            93.209222
# exiting_car                                298.747897
# opening_door_inside                        196.547821
# preparing_food                             124.674715
# looking_or_moving_around (e.g. searching)  154.885173
# opening_laptop                             104.607083

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    drive_and_act_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
import matplotlib.pyplot as plt
mapper = experiment.test_loader.dataset.activity_image_map
activity_count = {key: len(mapper[key]) for key in mapper.keys()}

plt.bar(activity_count.keys(), activity_count.values())
plt.xticks(rotation=90);
plt.yscale('log');

# %%
import random

sample_indices_1 = [
    random.choice(experiment.test_loader.dataset.activity_image_map['putting_on_jacket']),
    random.choice(experiment.test_loader.dataset.activity_image_map['taking_off_jacket']),
    random.choice(experiment.test_loader.dataset.activity_image_map['opening_door_inside']),
    random.choice(experiment.test_loader.dataset.activity_image_map['closing_door_inside'])
]

sample_indices_2 = [
    random.choice(experiment.test_loader.dataset.activity_image_map['putting_on_sunglasses']),
    random.choice(experiment.test_loader.dataset.activity_image_map['taking_off_sunglasses']),
    random.choice(experiment.test_loader.dataset.activity_image_map['entering_car']),
    random.choice(experiment.test_loader.dataset.activity_image_map['exiting_car'])
]

# %%
plot_samples(
    drive_and_act_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=sample_indices_1,
    is_plot_gt_skeleton=False
)

# %%
plot_samples(
    drive_and_act_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=sample_indices_2,
    is_plot_gt_skeleton=False
)
