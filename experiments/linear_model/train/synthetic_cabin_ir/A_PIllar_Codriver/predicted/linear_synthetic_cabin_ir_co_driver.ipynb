# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_synthetic_cabin_ir, synthetic_cabin_ir_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'A_Pillar_Codriver'

constructed_loader = construct_synthetic_cabin_ir(
    dataset_root_path=synthetic_cabin_ir_dataset_root_path,
    viewpoint=viewpoint
)
# Out:
# Global seed set to 1234

# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_synthetic_cabin_ir, synthetic_cabin_ir_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'A_Pillar_Codriver'

constructed_loader = construct_synthetic_cabin_ir(
    dataset_root_path=synthetic_cabin_ir_dataset_root_path,
    viewpoint=viewpoint
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# train_dataset 37499 val_dataset 6250 test_dataset 6251
# create new LitSimpleBaselineLinear model
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir/A_Pillar_Codriver_predicted/lightning_logs
# train_dataset 37499 val_dataset 6250 test_dataset 6251
# create new LitSimpleBaselineLinear model
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 6208 samples : 2410.5277061462402
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 2925 batches: 283.59837224086124
# val MPJPE from: 6208 samples : 57.34151974320412
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 2925 batches: 69.82583791909055
# val MPJPE from: 6208 samples : 42.67937317490578
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 2925 batches: 59.26961631474332
# val MPJPE from: 6208 samples : 41.25082865357399
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 2925 batches: 56.298722753412704
# val MPJPE from: 6208 samples : 39.96039927005768
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 2925 batches: 54.72217054066495
# val MPJPE from: 6208 samples : 38.20030391216278
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 2925 batches: 53.30913604961501
# val MPJPE from: 6208 samples : 39.187341928482056
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 2925 batches: 51.93393149691769
# val MPJPE from: 6208 samples : 37.8304198384285
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 2925 batches: 50.952447851498924
# val MPJPE from: 6208 samples : 37.51968592405319
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 2925 batches: 50.1314029059349
# val MPJPE from: 6208 samples : 37.78907284140587
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 2925 batches: 49.41644839369334
# val MPJPE from: 6208 samples : 37.59777545928955
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 2925 batches: 48.93135705437416
# val MPJPE from: 6208 samples : 37.36405074596405
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 2925 batches: 48.50309436647301
# val MPJPE from: 6208 samples : 36.74290329217911
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 2925 batches: 48.04952379347932
# val MPJPE from: 6208 samples : 36.99468821287155
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 2925 batches: 47.71321834534661
# val MPJPE from: 6208 samples : 37.23149001598358
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 2925 batches: 47.517808070804314
# val MPJPE from: 6208 samples : 36.69631481170654
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 2925 batches: 47.27442369119734
# val MPJPE from: 6208 samples : 36.823175847530365
# Validation: 0it [00:00, ?it/s]
# check #17
# training loss from 2925 batches: 47.17435951543669
# val MPJPE from: 6208 samples : 36.83105856180191
# Validation: 0it [00:00, ?it/s]
# check #18
# training loss from 2925 batches: 47.00252982541027
# val MPJPE from: 6208 samples : 36.896318197250366
# Validation: 0it [00:00, ?it/s]
# check #19
# training loss from 2925 batches: 46.868961406314476
# val MPJPE from: 6208 samples : 36.76065802574158
# Validation: 0it [00:00, ?it/s]
# check #20
# training loss from 2925 batches: 46.784413358849335
# val MPJPE from: 6208 samples : 37.06283122301102

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir/A_Pillar_Codriver_predicted/lightning_logs/version_0/checkpoints/epoch=74-step=43875.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir/A_Pillar_Codriver_predicted/lightning_logs/version_0/checkpoints/epoch=74-step=43875.ckpt
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │           mpjpe           │     39.16678950190544     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 39.16678950190544
# PJPE =
#                      PJPE
# nose            30.129047
# left_eye        28.644693
# right_eye       28.714178
# left_ear        24.781084
# right_ear       22.340555
# left_shoulder   11.572305
# right_shoulder  11.571041
# left_elbow      88.901001
# right_elbow     68.317062
# left_wrist      59.522297
# right_wrist     50.345078
# left_hip        42.082085
# right_hip       42.247589

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    Path(synthetic_cabin_ir_dataset_root_path)/ viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    synthetic_cabin_ir_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'test',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
