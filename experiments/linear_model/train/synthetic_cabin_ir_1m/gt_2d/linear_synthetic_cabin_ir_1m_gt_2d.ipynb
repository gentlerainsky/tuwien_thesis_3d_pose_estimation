# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_synthetic_cabin_ir,
    synthetic_cabin_ir_1m_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'A_Pillar_Codriver'

constructed_loader = construct_synthetic_cabin_ir(
    dataset_name='synthetic_cabin_ir_1m',
    dataset_root_path=synthetic_cabin_ir_1m_dataset_root_path,
    viewpoint=viewpoint,
    keypoint_2d_folder='annotations',
    keypoint_2d_file_prefix='person_keypoints',
    bbox_file_predix='ground_truth_human_detection',
    is_gt_2d_pose=True
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name']
)
print(saved_model_path)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt
# train_dataset 75000 val_dataset 37500 test_dataset 30349
# train_dataset 75000 val_dataset 37500 test_dataset 30349
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 128 samples : 2239.539384841919
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 5855 batches: 219.9170655439696
# val MPJPE from: 37440 samples : 68.22065263986588
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 5855 batches: 98.06991822056847
# val MPJPE from: 37440 samples : 62.09053471684456
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 5855 batches: 93.96272604532673
# val MPJPE from: 37440 samples : 60.301560908555984
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 5855 batches: 90.8795779289393
# val MPJPE from: 37440 samples : 58.47771838307381
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 5855 batches: 88.6552288377519
# val MPJPE from: 37440 samples : 57.6285794377327
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 5855 batches: 87.0120995020276
# val MPJPE from: 37440 samples : 55.99704384803772
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 5855 batches: 85.74684607127504
# val MPJPE from: 37440 samples : 55.81013485789299
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 5855 batches: 84.81496017804827
# val MPJPE from: 37440 samples : 55.06499111652374
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 5855 batches: 83.94568838134573
# val MPJPE from: 37440 samples : 55.15951290726662
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 5855 batches: 83.25966788244288
# val MPJPE from: 37440 samples : 54.09589409828186
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 5855 batches: 82.80035241687531
# val MPJPE from: 37440 samples : 53.84472385048866
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 5855 batches: 82.40348447295563
# val MPJPE from: 37440 samples : 54.171591997146606
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 5855 batches: 81.9949773274661
# val MPJPE from: 37440 samples : 53.67078259587288
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 5855 batches: 81.74778129635054
# val MPJPE from: 37440 samples : 53.82098630070686
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 5855 batches: 81.50078131030708
# val MPJPE from: 37440 samples : 53.87096107006073
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 5855 batches: 81.27730334166479
# val MPJPE from: 37440 samples : 53.28832566738129
# Validation: 0it [00:00, ?it/s]
# check #17
# training loss from 5855 batches: 81.15276247771962
# val MPJPE from: 37440 samples : 53.37804555892944
# Validation: 0it [00:00, ?it/s]
# check #18
# training loss from 5855 batches: 80.9949550450001
# val MPJPE from: 37440 samples : 53.227975964546204
# Validation: 0it [00:00, ?it/s]
# check #19
# training loss from 5855 batches: 80.86949195569647
# val MPJPE from: 37440 samples : 53.55082452297211
# Validation: 0it [00:00, ?it/s]
# check #20
# training loss from 5855 batches: 80.82271550935522
# val MPJPE from: 37440 samples : 53.42874675989151
# Validation: 0it [00:00, ?it/s]
# check #21
# training loss from 5855 batches: 80.76717424199279
# val MPJPE from: 37440 samples : 53.176190704107285
# Validation: 0it [00:00, ?it/s]
# check #22
# training loss from 5855 batches: 80.75387453315199
# val MPJPE from: 37440 samples : 52.94822156429291
# Validation: 0it [00:00, ?it/s]
# check #23
# training loss from 5855 batches: 80.65212395815234
# val MPJPE from: 37440 samples : 52.86051705479622
# Validation: 0it [00:00, ?it/s]
# check #24
# training loss from 5855 batches: 80.604567207606
# val MPJPE from: 37440 samples : 53.53651940822601
# Validation: 0it [00:00, ?it/s]
# check #25
# training loss from 5855 batches: 80.5675009050805
# val MPJPE from: 37440 samples : 53.20929363369942
# Validation: 0it [00:00, ?it/s]
# check #26
# training loss from 5855 batches: 80.49092071367878
# val MPJPE from: 37440 samples : 53.57528477907181
# Validation: 0it [00:00, ?it/s]
# check #27
# training loss from 5855 batches: 80.52327992135291
# val MPJPE from: 37440 samples : 53.15779894590378
# Validation: 0it [00:00, ?it/s]
# check #28
# training loss from 5855 batches: 80.49942027112544
# val MPJPE from: 37440 samples : 53.225334733724594

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/lightning_logs/version_0/checkpoints/epoch=114-step=134665.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/lightning_logs/version_0/checkpoints/epoch=114-step=134665.ckpt
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │           mpjpe           │     54.17352169752121     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 54.17352169752121
# PJPE =
#                       PJPE
# nose             38.651657
# left_eye         36.608440
# right_eye        37.224281
# left_ear         33.312317
# right_ear        32.573444
# left_shoulder    17.869001
# right_shoulder   17.867580
# left_elbow       67.116760
# right_elbow      71.967102
# left_wrist       97.553871
# right_wrist     123.532295
# left_hip         64.168694
# right_hip        65.704224

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    Path(synthetic_cabin_ir_1m_dataset_root_path)/ viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    synthetic_cabin_ir_1m_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'test',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
