# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_synthetic_cabin_ir,
    synthetic_cabin_ir_1m_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'A_Pillar_Codriver'

constructed_loader = construct_synthetic_cabin_ir(
    dataset_name='synthetic_cabin_ir_1m',
    dataset_root_path=synthetic_cabin_ir_1m_dataset_root_path,
    viewpoint=viewpoint,
    keypoint_2d_folder='annotations',
    keypoint_2d_file_prefix='person_keypoints',
    bbox_file_predix='ground_truth_human_detection',
    is_gt_2d_pose=True
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name']
)
print(saved_model_path)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ./saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt
# train_dataset 75000 val_dataset 37500 test_dataset 30349
# create new LitSimpleBaselineLinear model
# train_dataset 75000 val_dataset 37500 test_dataset 30349
# create new LitSimpleBaselineLinear model
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 37440 samples : 2188.07053565979
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 5855 batches: 224.10351552584555
# val MPJPE from: 37440 samples : 72.66563177108765
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 5855 batches: 102.70072741451474
# val MPJPE from: 37440 samples : 67.65440851449966
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 5855 batches: 98.20954164157659
# val MPJPE from: 37440 samples : 65.05144387483597
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 5855 batches: 94.76441430623058
# val MPJPE from: 37440 samples : 63.170209527015686
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 5855 batches: 92.42966257283874
# val MPJPE from: 37440 samples : 62.24258244037628
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 5855 batches: 90.57284062179514
# val MPJPE from: 37440 samples : 60.172758996486664
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 5855 batches: 89.1723381032504
# Validation: 0it [00:00, ?it/s]
# check #27
# training loss from 5855 batches: 83.44544998913315
# val MPJPE from: 37440 samples : 56.71219155192375
# Validation: 0it [00:00, ?it/s]
# check #28
# training loss from 5855 batches: 83.43962228369448
# val MPJPE from: 37440 samples : 57.806141674518585
# Validation: 0it [00:00, ?it/s]
# check #29
# training loss from 5855 batches: 83.48476105679008
# val MPJPE from: 37440 samples : 57.13686719536781
# Validation: 0it [00:00, ?it/s]
# check #30
# training loss from 5855 batches: 83.44479930721522
# val MPJPE from: 37440 samples : 57.16251954436302
# Validation: 0it [00:00, ?it/s]
# check #31
# training loss from 5855 batches: 83.39754735349489
# val MPJPE from: 37440 samples : 57.00831115245819
# Validation: 0it [00:00, ?it/s]
# check #32
# training loss from 5855 batches: 83.37928120469967
# val MPJPE from: 37440 samples : 56.88829347491264

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/lightning_logs/version_0/checkpoints/epoch=134-step=158085.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/synthetic_cabin_ir_1m/A_Pillar_Codriver_gt/lightning_logs/version_0/checkpoints/epoch=134-step=158085.ckpt
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │           mpjpe           │     58.30046162009239     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 58.30046162009239
# PJPE =
#                       PJPE
# nose             45.030190
# left_eye         42.847153
# right_eye        43.577126
# left_ear         39.064709
# right_ear        39.086823
# left_shoulder    17.265739
# right_shoulder   17.264835
# left_elbow       77.283066
# right_elbow      65.213364
# left_wrist      118.347305
# right_wrist     105.312698
# left_hip         75.950714
# right_hip        71.551788

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    Path(synthetic_cabin_ir_1m_dataset_root_path)/ viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    synthetic_cabin_ir_1m_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'test',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
