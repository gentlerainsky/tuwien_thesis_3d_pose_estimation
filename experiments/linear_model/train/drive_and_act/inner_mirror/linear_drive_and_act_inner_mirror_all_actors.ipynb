# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_drive_and_act_dataset, drive_and_act_dataset_root_path, all_train_actors
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

dataset_root_path = drive_and_act_dataset_root_path
viewpoint = 'inner_mirror'
subset_type = 'all_actors'

constructed_loader = construct_drive_and_act_dataset(
    dataset_root_path=dataset_root_path,
    viewpoint=viewpoint,
    train_actors=all_train_actors
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    model_suffix=subset_type,
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# train_dataset 22896 val_dataset 6241 test_dataset 11017
# create new LitSimpleBaselineLinear model
# train_dataset 22896 val_dataset 6241 test_dataset 11017
# create new LitSimpleBaselineLinear model
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/inner_mirror/all_actors/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 6208 samples : 2416.128396987915
# activity_macro_mpjpe 2407.4857234954834
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 1785 batches: 798.431040759848
# val MPJPE from: 6208 samples : 130.52809238433838
# activity_macro_mpjpe 148.3573615550995
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 1785 batches: 228.48471886887938
# val MPJPE from: 6208 samples : 81.14397525787354
# activity_macro_mpjpe 100.67334026098251
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 1785 batches: 136.9009170837763
# val MPJPE from: 6208 samples : 76.99166983366013
# activity_macro_mpjpe 96.56020998954773
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 1785 batches: 123.48834775409111
# val MPJPE from: 6208 samples : 73.29343259334564
# activity_macro_mpjpe 92.79974550008774
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 1785 batches: 116.40968359902459
# val MPJPE from: 6208 samples : 69.23459470272064
# activity_macro_mpjpe 88.52482587099075
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 1785 batches: 110.5687995584739
# val MPJPE from: 6208 samples : 69.74639743566513
# activity_macro_mpjpe 88.9856293797493
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 1785 batches: 106.08129375705532
# val MPJPE from: 6208 samples : 68.97088885307312
# activity_macro_mpjpe 88.13270926475525
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 1785 batches: 103.40500132960766
# val MPJPE from: 6208 samples : 69.24732774496078
# activity_macro_mpjpe 88.50044757127762
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 1785 batches: 101.78574212625915
# val MPJPE from: 6208 samples : 68.09747219085693
# activity_macro_mpjpe 87.29236572980881
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 1785 batches: 99.60000101758652
# val MPJPE from: 6208 samples : 67.91894137859344
# activity_macro_mpjpe 87.26085722446442
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 1785 batches: 97.37920688063491
# val MPJPE from: 6208 samples : 67.37376749515533
# activity_macro_mpjpe 86.4633321762085
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 1785 batches: 97.45231034124599
# val MPJPE from: 6208 samples : 67.72557646036148
# activity_macro_mpjpe 86.73766255378723
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 1785 batches: 96.6077857366463
# val MPJPE from: 6208 samples : 68.10610741376877
# activity_macro_mpjpe 87.34238147735596
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 1785 batches: 95.33983435200042
# val MPJPE from: 6208 samples : 67.4857497215271
# activity_macro_mpjpe 86.62565797567368
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 1785 batches: 95.10145329502451
# val MPJPE from: 6208 samples : 66.55962765216827
# activity_macro_mpjpe 85.76301485300064
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 1785 batches: 94.87654960581234
# val MPJPE from: 6208 samples : 67.93651729822159
# activity_macro_mpjpe 87.13579922914505
# Validation: 0it [00:00, ?it/s]
# check #17
# training loss from 1785 batches: 93.95596882124909
# val MPJPE from: 6208 samples : 66.82399660348892
# activity_macro_mpjpe 86.02920919656754
# Validation: 0it [00:00, ?it/s]
# check #18
# training loss from 1785 batches: 94.16325983880948
# val MPJPE from: 6208 samples : 67.0870989561081
# activity_macro_mpjpe 86.20363473892212
# Validation: 0it [00:00, ?it/s]
# check #19
# training loss from 1785 batches: 93.60199333781621
# val MPJPE from: 6208 samples : 66.61642342805862
# activity_macro_mpjpe 85.84218472242355
# Validation: 0it [00:00, ?it/s]
# check #20
# training loss from 1785 batches: 93.00911099720402
# val MPJPE from: 6208 samples : 66.67562574148178
# activity_macro_mpjpe 85.81835776567459

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/inner_mirror/all_actors/lightning_logs/version_0/checkpoints/epoch=74-step=26775.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/inner_mirror/all_actors/lightning_logs/version_0/checkpoints/epoch=74-step=26775.ckpt
# Testing: 0it [00:00, ?it/s]
# activity_macro_mpjpe 77.9118612408638
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   activity_macro_mpjpe    │     77.9118612408638      │
# │           mpjpe           │     59.56367403268814     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 59.56367403268814
# PJPE =
#                      PJPE
# nose            50.070705
# left_eye        48.367039
# right_eye       48.076210
# left_ear        12.622998
# right_ear       35.267517
# left_shoulder   15.531995
# right_shoulder  19.694431
# left_elbow      68.625244
# right_elbow     65.639893
# left_wrist      74.994629
# right_wrist     86.757416
# left_hip        62.275013
# right_hip       63.641296
# Activity-based Macro Average MPJPE = 77.9118612408638
# activity_mpjpe =
#                                                 MPJPE
# closing_door_inside                        122.546434
# entering_car                               187.927872
# fastening_seat_belt                        116.145737
# sitting_still                               59.453137
# fetching_an_object                         140.462011
# pressing_automation_button                  52.379780
# putting_on_jacket                          208.059669
# unfastening_seat_belt                       86.610772
# placing_an_object                          132.036686
# taking_off_jacket                          234.879017
# opening_backpack                           206.758916
# taking_laptop_from_backpack                138.236821
# working_on_laptop                           80.148622
# interacting_with_phone                      80.661573
# closing_laptop                             115.069866
# putting_laptop_into_backpack               298.459321
# drinking                                    57.180572
# opening_bottle                              60.642920
# closing_bottle                              74.773550
# eating                                      48.414283
# using_multimedia_display                    86.940393
# reading_magazine                            65.740779
# taking_off_sunglasses                      122.743703
# writing                                     85.888445
# putting_on_sunglasses                       89.999340
# reading_newspaper                           78.231603
# talking_on_phone                           100.851282
# exiting_car                                299.314559
# opening_door_inside                        196.121246
# preparing_food                             106.991939
# looking_or_moving_around (e.g. searching)  149.400383
# opening_laptop                             104.654104

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    Path(dataset_root_path)/ viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
