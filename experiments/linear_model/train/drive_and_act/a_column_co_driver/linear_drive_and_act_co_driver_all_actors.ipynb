# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_drive_and_act_dataset, drive_and_act_dataset_root_path, all_train_actors
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

dataset_root_path = drive_and_act_dataset_root_path
viewpoint = 'a_column_co_driver'
subset_type = 'all_actors'

constructed_loader = construct_drive_and_act_dataset(
    dataset_root_path=dataset_root_path,
    viewpoint=viewpoint,
    train_actors=all_train_actors
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    model_suffix=subset_type,
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# train_dataset 9489 val_dataset 6240 test_dataset 11017
# create new LitSimpleBaselineLinear model
# train_dataset 9489 val_dataset 6240 test_dataset 11017
# create new LitSimpleBaselineLinear model
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/a_column_co_driver/all_actors/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 6208 samples : 2565.674066543579
# activity_macro_mpjpe 2563.0903244018555
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 740 batches: 1009.3741886921832
# val MPJPE from: 6208 samples : 134.49883460998535
# activity_macro_mpjpe 148.95597100257874
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 740 batches: 188.00430783146135
# val MPJPE from: 6208 samples : 94.63910013437271
# activity_macro_mpjpe 112.88300901651382
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 740 batches: 150.8601625122734
# val MPJPE from: 6208 samples : 101.45914554595947
# activity_macro_mpjpe 119.32264268398285
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 740 batches: 142.6999798900372
# val MPJPE from: 6208 samples : 92.6952138543129
# activity_macro_mpjpe 110.82307994365692
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 740 batches: 139.78240562451853
# val MPJPE from: 6208 samples : 87.65888959169388
# activity_macro_mpjpe 105.35933077335358
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 740 batches: 134.3763755080668
# val MPJPE from: 6208 samples : 86.41496300697327
# activity_macro_mpjpe 104.61989790201187
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 740 batches: 131.2836010512468
# val MPJPE from: 6208 samples : 89.26283568143845
# activity_macro_mpjpe 107.27492719888687
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 740 batches: 128.60489044640516
# val MPJPE from: 6208 samples : 82.97406882047653
# activity_macro_mpjpe 101.01739317178726
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 740 batches: 125.20711880076577
# val MPJPE from: 6208 samples : 85.8239009976387
# activity_macro_mpjpe 103.95419597625732
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 740 batches: 123.1916216680327
# val MPJPE from: 6208 samples : 81.30188286304474
# activity_macro_mpjpe 99.43868964910507
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 740 batches: 124.19051263179327
# val MPJPE from: 6208 samples : 86.77618950605392
# activity_macro_mpjpe 104.94231432676315
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 740 batches: 121.32698079017369
# val MPJPE from: 6208 samples : 82.68637210130692
# activity_macro_mpjpe 100.71961581707001
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 740 batches: 120.71720579186001
# val MPJPE from: 6208 samples : 84.27926898002625
# activity_macro_mpjpe 102.39032655954361
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 740 batches: 120.13812775950174
# val MPJPE from: 6208 samples : 82.47599750757217
# activity_macro_mpjpe 100.55067390203476
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 740 batches: 118.80768743922582
# val MPJPE from: 6208 samples : 82.29385316371918
# activity_macro_mpjpe 100.30161589384079

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/a_column_co_driver/all_actors/lightning_logs/version_0/checkpoints/epoch=49-step=7400.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/a_column_co_driver/all_actors/lightning_logs/version_0/checkpoints/epoch=49-step=7400.ckpt
# Testing: 0it [00:00, ?it/s]
# activity_macro_mpjpe 89.03061598539352
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   activity_macro_mpjpe    │     89.03061598539352     │
# │           mpjpe           │     71.94647192955017     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 71.94647192955017
# PJPE =
#                       PJPE
# nose             59.780071
# left_eye         55.318371
# right_eye        56.973560
# left_ear         14.740798
# right_ear        40.185722
# left_shoulder    17.247667
# right_shoulder   21.679718
# left_elbow       80.505058
# right_elbow      83.458145
# left_wrist      102.468506
# right_wrist     126.725990
# left_hip         66.852966
# right_hip        67.031387
# Activity-based Macro Average MPJPE = 89.03061598539352
# activity_mpjpe =
#                                                 MPJPE
# closing_door_inside                        133.169755
# entering_car                               194.788903
# sitting_still                               73.405199
# closing_bottle                              79.361625
# drinking                                    74.263267
# fetching_an_object                         152.538016
# opening_bottle                              76.334089
# pressing_automation_button                  66.970102
# eating                                      64.196177
# opening_backpack                           201.853201
# placing_an_object                          145.174056
# preparing_food                             145.327777
# reading_newspaper                           86.920470
# taking_off_sunglasses                      107.823059
# using_multimedia_display                    96.405670
# writing                                     93.926169
# putting_on_jacket                          221.699789
# unfastening_seat_belt                       97.870499
# fastening_seat_belt                        127.865106
# putting_on_sunglasses                       83.382227
# talking_on_phone                           106.439337
# reading_magazine                            66.821992
# taking_off_jacket                          239.421472
# looking_or_moving_around (e.g. searching)  161.807358
# opening_laptop                             110.064551
# working_on_laptop                           74.377201
# interacting_with_phone                      71.861207
# closing_laptop                             128.080189
# exiting_car                                246.369317
# taking_laptop_from_backpack                193.370596
# putting_laptop_into_backpack               299.513340
# opening_door_inside                        161.731258

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    Path(dataset_root_path)/ viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
