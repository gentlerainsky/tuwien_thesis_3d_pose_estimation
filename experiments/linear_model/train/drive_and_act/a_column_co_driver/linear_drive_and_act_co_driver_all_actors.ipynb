# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.linear_model.lit_linear_model import LitSimpleBaselineLinear as LitModel
from modules.experiments.dataset import (
    construct_drive_and_act_dataset, drive_and_act_dataset_root_path, all_train_actors
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

dataset_root_path = drive_and_act_dataset_root_path
viewpoint = 'a_column_co_driver'

constructed_loader = construct_drive_and_act_dataset(
    dataset_root_path=dataset_root_path,
    viewpoint=viewpoint,
    train_actors=all_train_actors
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# skipping problematic image 3628
# skipping problematic image 5874
# skipping problematic image 14835
# Annotation is not found for 15783
# Annotation is not found for 17258
# Annotation is not found for 17259
# Annotation is not found for 21271
# Annotation is not found for 21272
# Annotation is not found for 21273
# Annotation is not found for 21274
# Annotation is not found for 21275
# Annotation is not found for 21276
# skipping problematic image 32959
# Annotation is not found for 33527
# skipping problematic image 28113
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# train_dataset 22881 val_dataset 6240 test_dataset 11017
# create new LitSimpleBaselineLinear model
# train_dataset 22881 val_dataset 6240 test_dataset 11017
# create new LitSimpleBaselineLinear model
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/a_column_co_driver_predicted/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type          | Params
# ----------------------------------------
# 0 | model | BaselineModel | 4.3 M
# ----------------------------------------
# 4.3 M     Trainable params
# 0         Non-trainable params
# 4.3 M     Total params
# 17.105    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 6208 samples : 2565.674066543579
# activity_macro_mpjpe 2563.0903244018555
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 1785 batches: 516.6664526492608
# val MPJPE from: 6208 samples : 83.01495015621185
# activity_macro_mpjpe 100.54244101047516
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 1785 batches: 142.46067080845017
# val MPJPE from: 6208 samples : 82.52653479576111
# activity_macro_mpjpe 100.62934458255768
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 1785 batches: 130.02765301813267
# val MPJPE from: 6208 samples : 83.41305702924728
# activity_macro_mpjpe 101.37966275215149
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 1785 batches: 121.40355199074544
# val MPJPE from: 6208 samples : 81.12514019012451
# activity_macro_mpjpe 99.16752576828003
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 1785 batches: 115.58634246013412
# val MPJPE from: 6208 samples : 81.29991590976715
# activity_macro_mpjpe 99.50041770935059
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 1785 batches: 111.95932139619057
# val MPJPE from: 6208 samples : 77.94976234436035
# activity_macro_mpjpe 95.96654772758484
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 1785 batches: 108.1744777012606
# val MPJPE from: 6208 samples : 77.15395092964172
# activity_macro_mpjpe 95.20446509122849
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 1785 batches: 106.4743776114381
# val MPJPE from: 6208 samples : 76.97365432977676
# activity_macro_mpjpe 95.18690407276154
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 1785 batches: 103.89946637367333
# val MPJPE from: 6208 samples : 76.16081088781357
# activity_macro_mpjpe 94.24922615289688
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 1785 batches: 102.5010560490504
# val MPJPE from: 6208 samples : 75.68934559822083
# activity_macro_mpjpe 93.86615455150604
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 1785 batches: 101.49616410418385
# val MPJPE from: 6208 samples : 75.79994946718216
# activity_macro_mpjpe 93.90381723642349
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 1785 batches: 99.9216700259711
# val MPJPE from: 6208 samples : 75.9379044175148
# activity_macro_mpjpe 94.054214656353
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 1785 batches: 99.5516047507775
# val MPJPE from: 6208 samples : 74.71826672554016
# activity_macro_mpjpe 92.8642526268959
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 1785 batches: 99.18846623653792
# val MPJPE from: 6208 samples : 75.53846389055252
# activity_macro_mpjpe 93.6797708272934
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 1785 batches: 98.34872182844734
# val MPJPE from: 6208 samples : 75.1863569021225
# activity_macro_mpjpe 93.33428740501404
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 1785 batches: 97.93301295249069
# val MPJPE from: 6208 samples : 75.27167350053787
# activity_macro_mpjpe 93.47575157880783
# Validation: 0it [00:00, ?it/s]
# check #17
# training loss from 1785 batches: 97.18017449983361
# val MPJPE from: 6208 samples : 75.02958178520203
# activity_macro_mpjpe 93.22644025087357
# Validation: 0it [00:00, ?it/s]
# check #18
# training loss from 1785 batches: 97.97632268079523
# val MPJPE from: 6208 samples : 75.34939795732498
# activity_macro_mpjpe 93.58972311019897

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/a_column_co_driver_predicted/lightning_logs/version_0/checkpoints/epoch=64-step=23205.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSimpleBaselineLinear/drive_and_act/a_column_co_driver_predicted/lightning_logs/version_0/checkpoints/epoch=64-step=23205.ckpt
# Testing: 0it [00:00, ?it/s]
# activity_macro_mpjpe 84.38409119844437
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │   activity_macro_mpjpe    │     84.38409119844437     │
# │           mpjpe           │     67.47358292341232     │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 67.47358292341232
# PJPE =
#                       PJPE
# nose             58.035458
# left_eye         54.368519
# right_eye        53.430637
# left_ear         14.172252
# right_ear        37.292686
# left_shoulder    17.497915
# right_shoulder   21.716858
# left_elbow       73.449829
# right_elbow      76.811920
# left_wrist       88.945366
# right_wrist     116.820946
# left_hip         63.089794
# right_hip        62.901184
# Activity-based Macro Average MPJPE = 84.38409119844437
# activity_mpjpe =
#                                                 MPJPE
# closing_door_inside                        132.310852
# entering_car                               194.919243
# sitting_still                               64.237908
# closing_bottle                              77.595107
# drinking                                    72.053976
# fetching_an_object                         151.615590
# opening_bottle                              73.659159
# pressing_automation_button                  61.197080
# eating                                      61.689768
# opening_backpack                           180.530250
# placing_an_object                          148.004174
# preparing_food                             160.992056
# reading_newspaper                           86.052835
# taking_off_sunglasses                      103.246711
# using_multimedia_display                    96.476823
# writing                                     92.328273
# putting_on_jacket                          227.378458
# unfastening_seat_belt                       94.895810
# fastening_seat_belt                        127.681956
# putting_on_sunglasses                       80.248922
# talking_on_phone                           106.919065
# reading_magazine                            66.086523
# taking_off_jacket                          242.068231
# looking_or_moving_around (e.g. searching)  159.389704
# opening_laptop                             115.186594
# working_on_laptop                           75.699948
# interacting_with_phone                      72.460413
# closing_laptop                             117.033869
# exiting_car                                259.105980
# taking_laptop_from_backpack                193.219498
# putting_laptop_into_backpack               262.901843
# opening_door_inside                        160.100803

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    Path(dataset_root_path)/ viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
