# %%
import pytorch_lightning as pl
from modules.lifter_2d_3d.model.semgcn.lit_semgcn import LitSemGCN as LitModel
from modules.experiments.dataset import (
    construct_synthetic_cabin_ir, synthetic_cabin_ir_dataset_root_path
)
from modules.utils.convention import get_saved_model_path
from modules.experiments.experiment import Experiment

pl.seed_everything(1234)

viewpoint = 'A_Pillar_Codriver'

constructed_loader = construct_synthetic_cabin_ir(
    dataset_root_path=synthetic_cabin_ir_dataset_root_path,
    viewpoint=viewpoint
)
saved_model_path = get_saved_model_path(
    model_name=LitModel.__name__,
    trained_dataset_name=constructed_loader['dataset_name'],
    trained_datasubset_name=constructed_loader['datasubset_name'],
)
experiment = Experiment(
    LitModel=LitModel,
    constructed_loader=constructed_loader,
    saved_model_path=saved_model_path,
    model_parameters=dict(
        exclude_ankle=True,
        exclude_knee=True
    )
)

experiment.setup()
experiment.train()
# Out:
# Global seed set to 1234
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# train_dataset 37499 val_dataset 6250 test_dataset 6251
# train_dataset 37499 val_dataset 6250 test_dataset 6251
# Missing logger folder: saved_lifter_2d_3d_model/LitSemGCN/synthetic_cabin_ir/A_Pillar_Codriver_predicted/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | SemGCN | 434 K
# ---------------------------------
# 434 K     Trainable params
# 0         Non-trainable params
# 434 K     Total params
# 1.739     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# check #0
# val MPJPE from: 128 samples : 603.0465364456177
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# check #1
# training loss from 2925 batches: 74.53373007157928
# val MPJPE from: 6208 samples : 58.93776938319206
# Validation: 0it [00:00, ?it/s]
# check #2
# training loss from 2925 batches: 46.034686305584046
# val MPJPE from: 6208 samples : 67.9246112704277
# Validation: 0it [00:00, ?it/s]
# check #3
# training loss from 2925 batches: 40.32430290921121
# val MPJPE from: 6208 samples : 50.32965913414955
# Validation: 0it [00:00, ?it/s]
# check #4
# training loss from 2925 batches: 36.11533577752928
# val MPJPE from: 6208 samples : 48.974040895700455
# Validation: 0it [00:00, ?it/s]
# check #5
# training loss from 2925 batches: 33.106774471891235
# val MPJPE from: 6208 samples : 42.817726731300354
# Validation: 0it [00:00, ?it/s]
# check #6
# training loss from 2925 batches: 30.822136256939324
# val MPJPE from: 6208 samples : 41.481874883174896
# Validation: 0it [00:00, ?it/s]
# check #7
# training loss from 2925 batches: 29.0039743285658
# val MPJPE from: 6208 samples : 42.30966791510582
# Validation: 0it [00:00, ?it/s]
# check #8
# training loss from 2925 batches: 27.427327865973496
# val MPJPE from: 6208 samples : 43.41378062963486
# Validation: 0it [00:00, ?it/s]
# check #9
# training loss from 2925 batches: 26.215254372129074
# val MPJPE from: 6208 samples : 42.68309101462364
# Validation: 0it [00:00, ?it/s]
# check #10
# training loss from 2925 batches: 25.26143665051358
# val MPJPE from: 6208 samples : 39.77440670132637
# Validation: 0it [00:00, ?it/s]
# check #11
# training loss from 2925 batches: 24.209666088478176
# val MPJPE from: 6208 samples : 45.475371181964874
# Validation: 0it [00:00, ?it/s]
# check #12
# training loss from 2925 batches: 23.471702993807632
# val MPJPE from: 6208 samples : 39.19988498091698
# Validation: 0it [00:00, ?it/s]
# check #13
# training loss from 2925 batches: 22.949973872711517
# val MPJPE from: 6208 samples : 42.808208614587784
# Validation: 0it [00:00, ?it/s]
# check #14
# training loss from 2925 batches: 22.31820390328892
# val MPJPE from: 6208 samples : 40.38465768098831
# Validation: 0it [00:00, ?it/s]
# check #15
# training loss from 2925 batches: 21.8632044031834
# val MPJPE from: 6208 samples : 44.69029977917671
# Validation: 0it [00:00, ?it/s]
# check #16
# training loss from 2925 batches: 21.427067315731293
# val MPJPE from: 6208 samples : 41.53433442115784
# Validation: 0it [00:00, ?it/s]
# check #17
# training loss from 2925 batches: 21.151285161319958
# val MPJPE from: 6208 samples : 39.15664926171303
# Validation: 0it [00:00, ?it/s]
# check #18
# training loss from 2925 batches: 20.886891457514885
# val MPJPE from: 6208 samples : 41.09405353665352
# Validation: 0it [00:00, ?it/s]
# check #19
# training loss from 2925 batches: 20.634364465363003
# val MPJPE from: 6208 samples : 42.08126291632652
# Validation: 0it [00:00, ?it/s]
# check #20
# training loss from 2925 batches: 20.43742461018583
# val MPJPE from: 6208 samples : 41.54538735747337
# Validation: 0it [00:00, ?it/s]
# check #21
# training loss from 2925 batches: 20.246141641440556
# val MPJPE from: 6208 samples : 42.53045469522476
# Validation: 0it [00:00, ?it/s]
# check #22
# training loss from 2925 batches: 20.165188510575863
# val MPJPE from: 6208 samples : 42.455948889255524

# %%
experiment.test()
experiment.print_result()
# Out:
# Restoring states from the checkpoint path at saved_lifter_2d_3d_model/LitSemGCN/synthetic_cabin_ir/A_Pillar_Codriver_predicted/lightning_logs/version_0/checkpoints/epoch=84-step=49725.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at saved_lifter_2d_3d_model/LitSemGCN/synthetic_cabin_ir/A_Pillar_Codriver_predicted/lightning_logs/version_0/checkpoints/epoch=84-step=49725.ckpt
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │           mpjpe           │     40.0838777422905      │
# └───────────────────────────┴───────────────────────────┘
# MPJPE = 40.0838777422905
# PJPE =
#                       PJPE
# nose             26.173218
# left_eye         23.660467
# right_eye        23.686954
# left_ear         20.957605
# right_ear        19.306332
# left_shoulder    15.174946
# right_shoulder   14.121302
# left_elbow       71.429337
# right_elbow     105.671860
# left_wrist       49.496525
# right_wrist      53.953823
# left_hip         48.996090
# right_hip        48.462109

# %% [markdown]
# ## Train Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
from pathlib import Path

dataset_length = len(experiment.train_loader.dataset)
plot_samples(
    Path(synthetic_cabin_ir_dataset_root_path)/ viewpoint,
    experiment.lit_model,
    experiment.train_loader,
    'train',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)

# %% [markdown]
# ## Test Samples

# %%
from modules.utils.visualization import (
    plot_samples
)
dataset_length = len(experiment.test_loader.dataset)
plot_samples(
    synthetic_cabin_ir_dataset_root_path / viewpoint,
    experiment.lit_model,
    experiment.test_loader,
    'test',
    img_figsize=(20, 10),
    plot_figsize=(20.5, 10),
    sample_indices=[
        int(dataset_length * 0.1),
        int(dataset_length * 0.5),
        int(dataset_length * 0.9),
    ],
    is_plot_gt_skeleton=False
)
