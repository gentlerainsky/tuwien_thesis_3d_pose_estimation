# %%
# from mmdet.datasets.coco import CocoDataset
from modules.human_detector.human_detector import HumanDetector

# %%
detector = HumanDetector(
    config_path='./src/modules/human_detector/config/faster_rcnn.py',
    pretrained_path="https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/"\
        "faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth",
    checkpoint_path="./mmengine_workdir/human_detector/epoch_1.pth",
    data_root_path='/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/',
    device='cuda:0',
    working_directory='./mmengine_workdir/human_detector',
    log_level='INFO'
)
# https://github.com/open-mmlab/mmdetection/blob/main/configs/faster_rcnn/
detector.finetune()
# detector.load_pretrained()
# Out:
# 09/28 14:18:03 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 261781476
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 261781476
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 09/28 14:18:03 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[
#             103.53,
#             116.28,
#             123.675,
#         ],
#         std=[
#             1.0,
#             1.0,
#             1.0,
#         ],
#         bgr_to_rgb=False,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=101,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet101_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[
#                 8,
#             ],
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=1,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)),
#     _scope_='mmdet')
# dataset_type = 'CocoDataset'
# data_root = '/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         )),
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmdet'),
#     batch_sampler=dict(type='AspectRatioBatchSampler', _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/',
#         ann_file='annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs'),
#         ],
#         backend_args=None,
#         _scope_='mmdet'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         _scope_='mmdet'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         _scope_='mmdet'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# train_cfg = dict(
#     type='EpochBasedTrainLoop', max_epochs=1, val_interval=1, _scope_='mmdet')
# val_cfg = dict(type='ValLoop', _scope_='mmdet')
# test_cfg = dict(type='TestLoop', _scope_='mmdet')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=8,
#         by_epoch=True,
#         milestones=[
#             7,
#         ],
#         gamma=0.1),
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0001),
#     _scope_='mmdet')
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmdet'),
#     logger=dict(type='LoggerHook', interval=500, _scope_='mmdet'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmdet'),
#     checkpoint=dict(type='CheckpointHook', interval=1, _scope_='mmdet'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmdet'),
#     visualization=dict(type='DetVisualizationHook', _scope_='mmdet'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmdet'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmdet')
# log_processor = dict(
#     type='LogProcessor', window_size=50, by_epoch=True, _scope_='mmdet')
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth'
# resume = False
# work_dir = './mmengine_workdir/human_detector'
# wandb: Currently logged in as: gentlerainsky. Use `wandb login --relogin` to force relogin
# wandb version 0.15.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/workspace/mmengine_workdir/human_detector/20230928_141803/vis_data/wandb/run-20230928_141805-ft8rcbin</code>
# Syncing run <strong><a href='https://wandb.ai/gentlerainsky/uncategorized/runs/ft8rcbin' target="_blank">warm-haze-45</a></strong> to <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gentlerainsky/uncategorized' target="_blank">https://wandb.ai/gentlerainsky/uncategorized</a>
#  View run at <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/ft8rcbin' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/ft8rcbin</a>
# 09/28 14:18:12 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 09/28 14:18:12 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 09/28 14:18:12 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.11 (main, Apr 20 2023, 19:02:41) [GCC 11.2.0]
#     CUDA available: True
#     numpy_random_seed: 1453589586
#     GPU 0: NVIDIA TITAN Xp
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     GCC: gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1453589586
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 09/28 14:18:12 - mmengine - INFO - Config:
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[
#             103.53,
#             116.28,
#             123.675,
#         ],
#         std=[
#             1.0,
#             1.0,
#             1.0,
#         ],
#         bgr_to_rgb=False,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=101,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=False),
#         norm_eval=True,
#         style='caffe',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint='open-mmlab://detectron2/resnet101_caffe')),
#     neck=dict(
#         type='FPN',
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[
#                 8,
#             ],
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=1,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[
#                     0.0,
#                     0.0,
#                     0.0,
#                     0.0,
#                 ],
#                 target_stds=[
#                     0.1,
#                     0.1,
#                     0.2,
#                     0.2,
#                 ]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)),
#     _scope_='mmdet')
# dataset_type = 'CocoDataset'
# data_root = '/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(
#         1333,
#         800,
#     ), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         )),
# ]
# train_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True, _scope_='mmdet'),
#     batch_sampler=dict(type='AspectRatioBatchSampler', _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/',
#         ann_file='annotations/person_keypoints_train.json',
#         data_prefix=dict(img='images/train/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs'),
#         ],
#         backend_args=None,
#         _scope_='mmdet'))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         _scope_='mmdet'))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=1,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False, _scope_='mmdet'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/',
#         ann_file='annotations/person_keypoints_val.json',
#         data_prefix=dict(img='images/val/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(
#                 1333,
#                 800,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 )),
#         ],
#         backend_args=None,
#         _scope_='mmdet'))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file=
#     '/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/annotations/person_keypoints_val.json',
#     metric='bbox',
#     format_only=False,
#     backend_args=None,
#     _scope_='mmdet')
# train_cfg = dict(
#     type='EpochBasedTrainLoop', max_epochs=1, val_interval=1, _scope_='mmdet')
# val_cfg = dict(type='ValLoop', _scope_='mmdet')
# test_cfg = dict(type='TestLoop', _scope_='mmdet')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=8,
#         by_epoch=True,
#         milestones=[
#             7,
#         ],
#         gamma=0.1),
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0001),
#     _scope_='mmdet')
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook', _scope_='mmdet'),
#     logger=dict(type='LoggerHook', interval=500, _scope_='mmdet'),
#     param_scheduler=dict(type='ParamSchedulerHook', _scope_='mmdet'),
#     checkpoint=dict(type='CheckpointHook', interval=1, _scope_='mmdet'),
#     sampler_seed=dict(type='DistSamplerSeedHook', _scope_='mmdet'),
#     visualization=dict(type='DetVisualizationHook', _scope_='mmdet'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend', _scope_='mmdet'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(type='WandbVisBackend'),
#     ],
#     name='visualizer',
#     _scope_='mmdet')
# log_processor = dict(
#     type='LogProcessor', window_size=50, by_epoch=True, _scope_='mmdet')
# log_level = 'INFO'
# load_from = 'https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth'
# resume = False
# work_dir = './mmengine_workdir/human_detector'
# /opt/conda/lib/python3.10/site-packages/mmengine/utils/manager.py:113: UserWarning: <class 'mmdet.visualization.local_visualizer.DetLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(
# 09/28 14:18:13 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 09/28 14:18:13 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.73s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# 09/28 14:18:15 - mmengine - INFO - load model from: open-mmlab://detectron2/resnet101_caffe
# 09/28 14:18:15 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://detectron2/resnet101_caffe
# Downloading: "https://download.openmmlab.com/pretrain/third_party/resnet101_msra-6cc46731.pth" to /root/.cache/torch/hub/checkpoints/resnet101_msra-6cc46731.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth
# Downloading: "https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth" to /root/.cache/torch/hub/checkpoints/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([2, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([2]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([4, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([4]).
# 09/28 14:18:48 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth
# 09/28 14:18:48 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 09/28 14:18:48 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 09/28 14:18:48 - mmengine - INFO - Checkpoints will be saved to /workspace/mmengine_workdir/human_detector.
# 09/28 14:20:30 - mmengine - INFO - Epoch(train) [1][  500/37499]  lr: 1.0000e-02  eta: 2:05:38  time: 0.2041  data_time: 0.0014  memory: 2397  loss: 0.0350  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0050  loss_cls: 0.0075  acc: 99.4141  loss_bbox: 0.0219
# 09/28 14:22:12 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 14:22:12 - mmengine - INFO - Epoch(train) [1][ 1000/37499]  lr: 1.0000e-02  eta: 2:04:35  time: 0.2045  data_time: 0.0016  memory: 2397  loss: 0.0236  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0036  loss_cls: 0.0050  acc: 100.0000  loss_bbox: 0.0144
# 09/28 14:23:55 - mmengine - INFO - Epoch(train) [1][ 1500/37499]  lr: 1.0000e-02  eta: 2:02:52  time: 0.2042  data_time: 0.0018  memory: 2397  loss: 0.0224  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0038  loss_cls: 0.0039  acc: 99.6094  loss_bbox: 0.0143
# 09/28 14:25:36 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 14:25:36 - mmengine - INFO - Epoch(train) [1][ 2000/37499]  lr: 1.0000e-02  eta: 2:00:56  time: 0.2035  data_time: 0.0017  memory: 2397  loss: 0.0177  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0041  loss_cls: 0.0033  acc: 100.0000  loss_bbox: 0.0098
# 09/28 14:27:19 - mmengine - INFO - Epoch(train) [1][ 2500/37499]  lr: 1.0000e-02  eta: 1:59:25  time: 0.2047  data_time: 0.0028  memory: 2397  loss: 0.0180  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0032  loss_cls: 0.0039  acc: 99.6094  loss_bbox: 0.0104
# 09/28 14:29:02 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28
- mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# ...
# 09/28 15:29:47 - mmengine - INFO - Epoch(train) [1][21000/37499]  lr: 1.0000e-02  eta: 0:55:46  time: 0.2074  data_time: 0.0018  memory: 2397  loss: 0.0086  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0014  loss_cls: 0.0018  acc: 99.8047  loss_bbox: 0.0051
# 09/28 15:31:30 - mmengine - INFO - Epoch(train) [1][21500/37499]  lr: 1.0000e-02  eta: 0:54:05  time: 0.2049  data_time: 0.0015  memory: 2397  loss: 0.0083  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0015  acc: 100.0000  loss_bbox: 0.0048
# 09/28 15:33:12 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:33:12 - mmengine - INFO - Epoch(train) [1][22000/37499]  lr: 1.0000e-02  eta: 0:52:24  time: 0.2006  data_time: 0.0015  memory: 2397  loss: 0.0093  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0020  loss_cls: 0.0019  acc: 100.0000  loss_bbox: 0.0052
# 09/28 15:34:54 - mmengine - INFO - Epoch(train) [1][22500/37499]  lr: 1.0000e-02  eta: 0:50:44  time: 0.2036  data_time: 0.0015  memory: 2397  loss: 0.0076  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0015  acc: 100.0000  loss_bbox: 0.0041
# 09/28 15:36:37 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:36:37 - mmengine - INFO - Epoch(train) [1][23000/37499]  lr: 1.0000e-02  eta: 0:49:03  time: 0.2045  data_time: 0.0016  memory: 2397  loss: 0.0114  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0019  loss_cls: 0.0024  acc: 99.6094  loss_bbox: 0.0068
# 09/28 15:38:19 - mmengine - INFO - Epoch(train) [1][23500/37499]  lr: 1.0000e-02  eta: 0:47:22  time: 0.2048  data_time: 0.0018  memory: 2397  loss: 0.0081  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0017  loss_cls: 0.0015  acc: 100.0000  loss_bbox: 0.0046
# 09/28 15:40:02 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:40:02 - mmengine - INFO - Epoch(train) [1][24000/37499]  lr: 1.0000e-02  eta: 0:45:41  time: 0.2041  data_time: 0.0015  memory: 2397  loss: 0.0082  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0014  acc: 100.0000  loss_bbox: 0.0049
# 09/28 15:41:44 - mmengine - INFO - Epoch(train) [1][24500/37499]  lr: 1.0000e-02  eta: 0:44:00  time: 0.2042  data_time: 0.0014  memory: 2397  loss: 0.0073  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0019  loss_cls: 0.0014  acc: 99.8047  loss_bbox: 0.0038
# 09/28 15:43:27 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:43:27 - mmengine - INFO - Epoch(train) [1][25000/37499]  lr: 1.0000e-02  eta: 0:42:19  time: 0.2080  data_time: 0.0021  memory: 2397  loss: 0.0079  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0021  loss_cls: 0.0013  acc: 100.0000  loss_bbox: 0.0042
# 09/28 15:45:10 - mmengine - INFO - Epoch(train) [1][25500/37499]  lr: 1.0000e-02  eta: 0:40:38  time: 0.2046  data_time: 0.0014  memory: 2397  loss: 0.0065  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0013  loss_cls: 0.0013  acc: 100.0000  loss_bbox: 0.0037
# 09/28 15:46:52 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:46:52 - mmengine - INFO - Epoch(train) [1][26000/37499]  lr: 1.0000e-02  eta: 0:38:56  time: 0.2049  data_time: 0.0018  memory: 2397  loss: 0.0074  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0017  loss_cls: 0.0012  acc: 99.8047  loss_bbox: 0.0044
# 09/28 15:48:35 - mmengine - INFO - Epoch(train) [1][26500/37499]  lr: 1.0000e-02  eta: 0:37:15  time: 0.2043  data_time: 0.0016  memory: 2397  loss: 0.0067  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0014  loss_cls: 0.0015  acc: 99.8047  loss_bbox: 0.0037
# 09/28 15:50:17 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:50:17 - mmengine - INFO - Epoch(train) [1][27000/37499]  lr: 1.0000e-02  eta: 0:35:34  time: 0.2046  data_time: 0.0015  memory: 2397  loss: 0.0097  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0018  loss_cls: 0.0025  acc: 100.0000  loss_bbox: 0.0052
# 09/28 15:52:00 - mmengine - INFO - Epoch(train) [1][27500/37499]  lr: 1.0000e-02  eta: 0:33:53  time: 0.2041  data_time: 0.0015  memory: 2397  loss: 0.0079  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0016  loss_cls: 0.0018  acc: 100.0000  loss_bbox: 0.0044
# 09/28 15:53:42 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:53:42 - mmengine - INFO - Epoch(train) [1][28000/37499]  lr: 1.0000e-02  eta: 0:32:11  time: 0.2047  data_time: 0.0014  memory: 2397  loss: 0.0083  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0017  acc: 100.0000  loss_bbox: 0.0047
# 09/28 15:55:25 - mmengine - INFO - Epoch(train) [1][28500/37499]  lr: 1.0000e-02  eta: 0:30:30  time: 0.2057  data_time: 0.0014  memory: 2397  loss: 0.0079  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0015  loss_cls: 0.0017  acc: 99.8047  loss_bbox: 0.0045
# 09/28 15:57:07 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 15:57:07 - mmengine - INFO - Epoch(train) [1][29000/37499]  lr: 1.0000e-02  eta: 0:28:48  time: 0.2052  data_time: 0.0016  memory: 2397  loss: 0.0084  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0017  acc: 100.0000  loss_bbox: 0.0047
# 09/28 15:58:50 - mmengine - INFO - Epoch(train) [1][29500/37499]  lr: 1.0000e-02  eta: 0:27:07  time: 0.2053  data_time: 0.0015  memory: 2397  loss: 0.0069  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0014  loss_cls: 0.0015  acc: 100.0000  loss_bbox: 0.0039
# 09/28 16:00:33 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:00:33 - mmengine - INFO - Epoch(train) [1][30000/37499]  lr: 1.0000e-02  eta: 0:25:25  time: 0.2020  data_time: 0.0015  memory: 2397  loss: 0.0065  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0017  loss_cls: 0.0011  acc: 100.0000  loss_bbox: 0.0035
# 09/28 16:02:16 - mmengine - INFO - Epoch(train) [1][30500/37499]  lr: 1.0000e-02  eta: 0:23:44  time: 0.2046  data_time: 0.0017  memory: 2397  loss: 0.0070  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0015  loss_cls: 0.0011  acc: 100.0000  loss_bbox: 0.0042
# 09/28 16:03:59 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:03:59 - mmengine - INFO - Epoch(train) [1][31000/37499]  lr: 1.0000e-02  eta: 0:22:02  time: 0.2047  data_time: 0.0015  memory: 2397  loss: 0.0075  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0021  loss_cls: 0.0008  acc: 100.0000  loss_bbox: 0.0042
# 09/28 16:05:42 - mmengine - INFO - Epoch(train) [1][31500/37499]  lr: 1.0000e-02  eta: 0:20:21  time: 0.2045  data_time: 0.0028  memory: 2397  loss: 0.0068  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0020  loss_cls: 0.0008  acc: 100.0000  loss_bbox: 0.0036
# 09/28 16:07:25 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:07:25 - mmengine - INFO - Epoch(train) [1][32000/37499]  lr: 1.0000e-02  eta: 0:18:39  time: 0.2047  data_time: 0.0017  memory: 2397  loss: 0.0071  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0013  acc: 99.8047  loss_bbox: 0.0039
# 09/28 16:09:07 - mmengine - INFO - Epoch(train) [1][32500/37499]  lr: 1.0000e-02  eta: 0:16:58  time: 0.2048  data_time: 0.0014  memory: 2397  loss: 0.0083  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0017  loss_cls: 0.0019  acc: 99.8047  loss_bbox: 0.0044
# 09/28 16:10:50 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:10:50 - mmengine - INFO - Epoch(train) [1][33000/37499]  lr: 1.0000e-02  eta: 0:15:16  time: 0.2047  data_time: 0.0015  memory: 2397  loss: 0.0068  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0013  loss_cls: 0.0012  acc: 100.0000  loss_bbox: 0.0040
# 09/28 16:12:32 - mmengine - INFO - Epoch(train) [1][33500/37499]  lr: 1.0000e-02  eta: 0:13:34  time: 0.2026  data_time: 0.0014  memory: 2397  loss: 0.0081  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0018  loss_cls: 0.0014  acc: 100.0000  loss_bbox: 0.0048
# 09/28 16:14:14 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:14:14 - mmengine - INFO - Epoch(train) [1][34000/37499]  lr: 1.0000e-02  eta: 0:11:52  time: 0.2042  data_time: 0.0014  memory: 2397  loss: 0.0065  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0013  loss_cls: 0.0011  acc: 99.8047  loss_bbox: 0.0039
# 09/28 16:15:57 - mmengine - INFO - Epoch(train) [1][34500/37499]  lr: 1.0000e-02  eta: 0:10:10  time: 0.2049  data_time: 0.0014  memory: 2397  loss: 0.0066  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0013  loss_cls: 0.0012  acc: 99.8047  loss_bbox: 0.0040
# 09/28 16:17:39 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:17:39 - mmengine - INFO - Epoch(train) [1][35000/37499]  lr: 1.0000e-02  eta: 0:08:29  time: 0.2036  data_time: 0.0015  memory: 2397  loss: 0.0065  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0016  loss_cls: 0.0010  acc: 100.0000  loss_bbox: 0.0038
# 09/28 16:19:21 - mmengine - INFO - Epoch(train) [1][35500/37499]  lr: 1.0000e-02  eta: 0:06:47  time: 0.2048  data_time: 0.0014  memory: 2397  loss: 0.0076  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0015  acc: 99.8047  loss_bbox: 0.0043
# 09/28 16:21:04 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:21:04 - mmengine - INFO - Epoch(train) [1][36000/37499]  lr: 1.0000e-02  eta: 0:05:05  time: 0.2053  data_time: 0.0014  memory: 2397  loss: 0.0064  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0015  loss_cls: 0.0011  acc: 100.0000  loss_bbox: 0.0036
# 09/28 16:22:48 - mmengine - INFO - Epoch(train) [1][36500/37499]  lr: 1.0000e-02  eta: 0:03:23  time: 0.2085  data_time: 0.0016  memory: 2397  loss: 0.0063  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0019  loss_cls: 0.0011  acc: 100.0000  loss_bbox: 0.0032
# 09/28 16:24:31 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:24:31 - mmengine - INFO - Epoch(train) [1][37000/37499]  lr: 1.0000e-02  eta: 0:01:41  time: 0.2090  data_time: 0.0017  memory: 2397  loss: 0.0068  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0017  loss_cls: 0.0011  acc: 100.0000  loss_bbox: 0.0038
# 09/28 16:26:14 - mmengine - INFO - Exp name: faster_rcnn_20230928_141812
# 09/28 16:26:14 - mmengine - INFO - Saving checkpoint at 1 epochs
# 09/28 16:26:55 - mmengine - INFO - Epoch(val) [1][ 500/6250]    eta: 0:07:37  time: 0.0756  data_time: 0.0011  memory: 2397
# 09/28 16:27:34 - mmengine - INFO - Epoch(val) [1][1000/6250]    eta: 0:06:52  time: 0.0765  data_time: 0.0010  memory: 754
# 09/28 16:28:13 - mmengine - INFO - Epoch(val) [1][1500/6250]    eta: 0:06:12  time: 0.0764  data_time: 0.0010  memory: 754
# 09/28 16:28:51 - mmengine - INFO - Epoch(val) [1][2000/6250]    eta: 0:05:31  time: 0.0790  data_time: 0.0010  memory: 754
# 09/28 16:29:31 - mmengine - INFO - Epoch(val) [1][2500/6250]    eta: 0:04:53  time: 0.0818  data_time: 0.0012  memory: 754
# 09/28 16:30:09 - mmengine - INFO - Epoch(val) [1][3000/6250]    eta: 0:04:13  time: 0.0774  data_time: 0.0010  memory: 754
# 09/28 16:30:49 - mmengine - INFO - Epoch(val) [1][3500/6250]    eta: 0:03:34  time: 0.0771  data_time: 0.0011  memory: 754
# 09/28 16:31:27 - mmengine - INFO - Epoch(val) [1][4000/6250]    eta: 0:02:55  time: 0.0764  data_time: 0.0010  memory: 754
# 09/28 16:32:06 - mmengine - INFO - Epoch(val) [1][4500/6250]    eta: 0:02:16  time: 0.0751  data_time: 0.0011  memory: 754
# 09/28 16:32:46 - mmengine - INFO - Epoch(val) [1][5000/6250]    eta: 0:01:37  time: 0.0771  data_time: 0.0011  memory: 754
# 09/28 16:33:25 - mmengine - INFO - Epoch(val) [1][5500/6250]    eta: 0:00:58  time: 0.0770  data_time: 0.0010  memory: 754
# 09/28 16:34:04 - mmengine - INFO - Epoch(val) [1][6000/6250]    eta: 0:00:19  time: 0.0798  data_time: 0.0010  memory: 754
# 09/28 16:34:24 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.10s).
# Accumulating evaluation results...
# DONE (t=0.14s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.996
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.996
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.998
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.998
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.998
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.998
# 09/28 16:34:25 - mmengine - INFO - bbox_mAP_copypaste: 0.996 1.000 1.000 -1.000 -1.000 0.996
# 09/28 16:34:25 - mmengine - INFO - Epoch(val) [1][6250/6250]    coco/bbox_mAP: 0.9960  coco/bbox_mAP_50: 1.0000  coco/bbox_mAP_75: 1.0000  coco/bbox_mAP_s: -1.0000  coco/bbox_mAP_m: -1.0000  coco/bbox_mAP_l: 0.9960  data_time: 0.0012  time: 0.0781
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'artifact' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁█████▆█▆▆█▆▆█▆▆██▃██▆▆███▆█▆█▆███▆█▆███</td></tr><tr><td>coco/bbox_mAP</td><td>▁</td></tr><tr><td>coco/bbox_mAP_50</td><td>▁</td></tr><tr><td>coco/bbox_mAP_75</td><td>▁</td></tr><tr><td>coco/bbox_mAP_l</td><td>▁</td></tr><tr><td>coco/bbox_mAP_m</td><td>▁</td></tr><tr><td>coco/bbox_mAP_s</td><td>▁</td></tr><tr><td>data_time</td><td>▂▃▃▂▂▂▃▂▂▂▃▂▂▂▁▁▂▂▂▁▃▃▃▂▃▂▅▃▂▂▂▂▃█▂▂▂▂▃▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>iter</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▃▃▃▃▂▃▂▂▂▂▂▃▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_bbox</td><td>█▅▃▃▃▃▃▂▂▂▂▂▂▂▃▂▂▂▂▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_cls</td><td>█▅▄▃▃▃▄▃▃▃▂▃▂▂▃▃▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_rpn_bbox</td><td>█▅▆▄▄▅▃▄▃▃▂▃▂▂▄▃▃▄▁▂▂▂▁▂▂▂▂▁▁▂▁▁▂▂▂▁▁▂▁▂</td></tr><tr><td>loss_rpn_cls</td><td>▅▅▄▂▂▅▃▃▂▂▂▃▂▄█▂▂▃▂▂▂▁▂▂▂▁▂▁▁▂▂▁▁▃▂▂▂▂▁▂</td></tr><tr><td>lr</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>memory</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time</td><td>████▇▇████████▇▇▇██████▇███████████████▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>100.0</td></tr><tr><td>coco/bbox_mAP</td><td>0.996</td></tr><tr><td>coco/bbox_mAP_50</td><td>1.0</td></tr><tr><td>coco/bbox_mAP_75</td><td>1.0</td></tr><tr><td>coco/bbox_mAP_l</td><td>0.996</td></tr><tr><td>coco/bbox_mAP_m</td><td>-1.0</td></tr><tr><td>coco/bbox_mAP_s</td><td>-1.0</td></tr><tr><td>data_time</td><td>0.00125</td></tr><tr><td>epoch</td><td>1</td></tr><tr><td>iter</td><td>37000</td></tr><tr><td>loss</td><td>0.00684</td></tr><tr><td>loss_bbox</td><td>0.00384</td></tr><tr><td>loss_cls</td><td>0.00109</td></tr><tr><td>loss_rpn_bbox</td><td>0.00175</td></tr><tr><td>loss_rpn_cls</td><td>0.00017</td></tr><tr><td>lr</td><td>0.01</td></tr><tr><td>memory</td><td>2397</td></tr><tr><td>time</td><td>0.07815</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">warm-haze-45</strong> at: <a href='https://wandb.ai/gentlerainsky/uncategorized/runs/ft8rcbin' target="_blank">https://wandb.ai/gentlerainsky/uncategorized/runs/ft8rcbin</a><br/>Synced 6 W&B file(s), 0 media file(s), 341 artifact file(s) and 0 other file(s)
# Find logs at: <code>./mmengine_workdir/human_detector/20230928_141803/vis_data/wandb/run-20230928_141805-ft8rcbin/logs</code>
# new_checkpoint_path /workspace/mmengine_workdir/human_detector/epoch_1.pth

# %%
# !ls '/root/data/processed/synthetic_cabin_bw'
# A_Pillar_Codriver  A_Pillar_Driver  Rear_Mirror

# 000000006251.jpg  000000018751.jpg  000000028126.jpg  000000037501.jpg
# 000000006252.jpg  000000018752.jpg  000000028127.jpg  000000037502.jpg

# %%
# img_path = '/root/data/processed/synthetic_cabin_bw/A_Pillar_Codriver/images/train/000000028126.jpg'
# result = detector.get_bbox(img_path)
# print(result)

# %%
# detector.visualise(img_path)
