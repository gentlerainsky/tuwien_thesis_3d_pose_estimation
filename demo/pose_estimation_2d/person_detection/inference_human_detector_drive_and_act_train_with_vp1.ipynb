# %%
from modules.human_detector.main import detect_person

# %%
# !rm -rf /root/data/processed/drive_and_act/person_detection_results

# %%
detect_person(
    config_path='./src/modules/human_detector/config/faster_rcnn.py',
    pretrained_path='https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/'\
        'faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth',
    checkpoint_path='https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/'\
        'faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth',
    dataset_root_path='/root/data/processed/drive_and_act_train_with_vp1/',
    device='cuda:0',
    working_directory='./mmengine_workdir/human_detector',
    log_level='CRITICAL'
)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth
# Downloading: "https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r101_caffe_fpn_1x_coco/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth" to /root/.cache/torch/hub/checkpoints/faster_rcnn_r101_caffe_fpn_1x_coco_bbox_mAP-0.398_20200504_180057-b269e9dd.pth
# 	image_set = train, start at = 2023-10-31 13:20:57.274448
# /root/data/processed/drive_and_act_train_with_vp1/images/train/8532.jpg has mask with 0.4291662573814392
# /root/data/processed/drive_and_act_train_with_vp1/images/train/8235.jpg has mask with 0.44854453206062317
# 		time = 2023-10-31 13:21:40.496864
# 			progress = 500/1588 = 0.3149
# problematic images = /root/data/processed/drive_and_act_train_with_vp1/images/train/8854.jpg
# /root/data/processed/drive_and_act_train_with_vp1/images/train/8819.jpg has mask with 0.24472759664058685
# 		time = 2023-10-31 13:22:23.935172
# 			progress = 1000/1588 = 0.6297
# problematic images = /root/data/processed/drive_and_act_train_with_vp1/images/train/8853.jpg
# /root/data/processed/drive_and_act_train_with_vp1/images/train/8314.jpg has mask with 0.4946945607662201
# /root/data/processed/drive_and_act_train_with_vp1/images/train/9695.jpg has mask with 0.45485919713974
# 		time = 2023-10-31 13:23:08.355649
# 			progress = 1500/1588 = 0.9446
# 		image_set = train, finish at = 2023-10-31 13:23:16.198046
# 		time spend = 2.32 mins (138.92 secs), fps = 11.4235 fps
# created a folder at /root/data/processed/drive_and_act_train_with_vp1/person_detection_results.
# 	image_set = val, start at = 2023-10-31 13:23:16.211316
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1659.jpg has mask with 0.4992908239364624
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2496.jpg has mask with 0.05660370737314224
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1784.jpg has mask with 0.17018695175647736
# /root/data/processed/drive_and_act_train_with_vp1/images/val/3166.jpg has mask with 0.4696674942970276
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2525.jpg has mask with 0.49339720606803894
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2531.jpg has mask with 0.47354692220687866
# 		time = 2023-10-31 13:24:01.411787
# 			progress = 500/3060 = 0.1634
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1848.jpg has mask with 0.47418013215065
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2614.jpg has mask with 0.4194389283657074
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1783.jpg has mask with 0.13822388648986816
# 		time = 2023-10-31 13:24:44.199945
# 			progress = 1000/3060 = 0.3268
# /root/data/processed/drive_and_act_train_with_vp1/images/val/3173.jpg has mask with 0.3695604205131531
# problematic images = /root/data/processed/drive_and_act_train_with_vp1/images/val/3283.jpg
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2654.jpg has mask with 0.3417988717556
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2532.jpg has mask with 0.459781289100647
# 		time = 2023-10-31 13:25:26.992372
# 			progress = 1500/3060 = 0.4902
# /root/data/processed/drive_and_act_train_with_vp1/images/val/3176.jpg has mask with 0.2983611226081848
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2536.jpg has mask with 0.44641178846359253
# /root/data/processed/drive_and_act_train_with_vp1/images/val/3282.jpg has mask with 0.22085729241371155
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1852.jpg has mask with 0.43481671810150146
# /root/data/processed/drive_and_act_train_with_vp1/images/val/6267.jpg has mask with 0.4417290687561035
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1674.jpg has mask with 0.3911754786968231
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1670.jpg has mask with 0.4184330105781555
# 		time = 2023-10-31 13:26:11.729739
# 			progress = 2000/3060 = 0.6536
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2623.jpg has mask with 0.3628072440624237
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1668.jpg has mask with 0.4238390028476715
# 		time = 2023-10-31 13:26:56.156014
# 			progress = 2500/3060 = 0.8170
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1658.jpg has mask with 0.3797159194946289
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1673.jpg has mask with 0.4479534924030304
# /root/data/processed/drive_and_act_train_with_vp1/images/val/1667.jpg has mask with 0.1272021234035492
# 		time = 2023-10-31 13:27:39.687604
# 			progress = 3000/3060 = 0.9804
# /root/data/processed/drive_and_act_train_with_vp1/images/val/2530.jpg has mask with 0.4680393636226654
# 		image_set = val, finish at = 2023-10-31 13:27:44.871271
# 		time spend = 4.48 mins (268.66 secs), fps = 11.3899 fps
# 	image_set = test, start at = 2023-10-31 13:27:45.005749
# /root/data/processed/drive_and_act_train_with_vp1/images/test/257.jpg has mask with 0.4888406991958618
# /root/data/processed/drive_and_act_train_with_vp1/images/test/533.jpg has mask with 0.48654258251190186
# /root/data/processed/drive_and_act_train_with_vp1/images/test/298.jpg has mask with 0.36661890149116516
# /root/data/processed/drive_and_act_train_with_vp1/images/test/319.jpg has mask with 0.49987444281578064
# /root/data/processed/drive_and_act_train_with_vp1/images/test/1329.jpg has mask with 0.43506908416748047
# /root/data/processed/drive_and_act_train_with_vp1/images/test/329.jpg has mask with 0.4781472384929657
# problematic images = /root/data/processed/drive_and_act_train_with_vp1/images/test/1497.jpg
# /root/data/processed/drive_and_act_train_with_vp1/images/test/324.jpg has mask with 0.4907185733318329
# 		time = 2023-10-31 13:28:29.140017
# 			progress = 500/5048 = 0.0990
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3564.jpg has mask with 0.3069702386856079
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3544.jpg has mask with 0.48241880536079407
# 		time = 2023-10-31 13:29:12.737269
# 			progress = 1000/5048 = 0.1981
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4344.jpg has mask with 0.3983682096004486
# /root/data/processed/drive_and_act_train_with_vp1/images/test/1397.jpg has mask with 0.473225861787796
# /root/data/processed/drive_and_act_train_with_vp1/images/test/6575.jpg has mask with 0.4508223533630371
# 		time = 2023-10-31 13:29:56.519868
# 			progress = 1500/5048 = 0.2971
# /root/data/processed/drive_and_act_train_with_vp1/images/test/7623.jpg has mask with 0.3149818778038025
# /root/data/processed/drive_and_act_train_with_vp1/images/test/1316.jpg has mask with 0.4936445355415344
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4362.jpg has mask with 0.477321594953537
# /root/data/processed/drive_and_act_train_with_vp1/images/test/1395.jpg has mask with 0.33882468938827515
# /root/data/processed/drive_and_act_train_with_vp1/images/test/7381.jpg has mask with 0.45477741956710815
# /root/data/processed/drive_and_act_train_with_vp1/images/test/320.jpg has mask with 0.4334452152252197
# /root/data/processed/drive_and_act_train_with_vp1/images/test/325.jpg has mask with 0.4312417805194855
# 		time = 2023-10-31 13:30:40.938700
# 			progress = 2000/5048 = 0.3962
# /root/data/processed/drive_and_act_train_with_vp1/images/test/6725.jpg has mask with 0.38167983293533325
# /root/data/processed/drive_and_act_train_with_vp1/images/test/326.jpg has mask with 0.4102906584739685
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3549.jpg has mask with 0.48953646421432495
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3768.jpg has mask with 0.4021933078765869
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4391.jpg has mask with 0.36724016070365906
# 		time = 2023-10-31 13:31:25.758773
# 			progress = 2500/5048 = 0.4952
# /root/data/processed/drive_and_act_train_with_vp1/images/test/6524.jpg has mask with 0.166949063539505
# /root/data/processed/drive_and_act_train_with_vp1/images/test/171.jpg has mask with 0.34154677391052246
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4611.jpg has mask with 0.35811376571655273
# /root/data/processed/drive_and_act_train_with_vp1/images/test/1328.jpg has mask with 0.4439925253391266
# 		time = 2023-10-31 13:32:10.665277
# 			progress = 3000/5048 = 0.5943
# /root/data/processed/drive_and_act_train_with_vp1/images/test/7363.jpg has mask with 0.3238067626953125
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3592.jpg has mask with 0.2565440237522125
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3548.jpg has mask with 0.4740557372570038
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3494.jpg has mask with 0.42653727531433105
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4399.jpg has mask with 0.49937379360198975
# 		time = 2023-10-31 13:32:55.553347
# 			progress = 3500/5048 = 0.6933
# /root/data/processed/drive_and_act_train_with_vp1/images/test/323.jpg has mask with 0.4938317835330963
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4993.jpg has mask with 0.08215992152690887
# 		time = 2023-10-31 13:33:42.029981
# 			progress = 4000/5048 = 0.7924
# /root/data/processed/drive_and_act_train_with_vp1/images/test/1324.jpg has mask with 0.48451897501945496
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4395.jpg has mask with 0.33990222215652466
# /root/data/processed/drive_and_act_train_with_vp1/images/test/297.jpg has mask with 0.4519197642803192
# /root/data/processed/drive_and_act_train_with_vp1/images/test/532.jpg has mask with 0.29373255372047424
# /root/data/processed/drive_and_act_train_with_vp1/images/test/6597.jpg has mask with 0.4527280926704407
# 		time = 2023-10-31 13:34:27.321882
# 			progress = 4500/5048 = 0.8914
# /root/data/processed/drive_and_act_train_with_vp1/images/test/7379.jpg has mask with 0.2761838734149933
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3546.jpg has mask with 0.4816769063472748
# /root/data/processed/drive_and_act_train_with_vp1/images/test/1388.jpg has mask with 0.4413689970970154
# /root/data/processed/drive_and_act_train_with_vp1/images/test/3496.jpg has mask with 0.37987130880355835
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4400.jpg has mask with 0.4679276645183563
# /root/data/processed/drive_and_act_train_with_vp1/images/test/4347.jpg has mask with 0.4315473437309265
# /root/data/processed/drive_and_act_train_with_vp1/images/test/317.jpg has mask with 0.45234793424606323
# 		time = 2023-10-31 13:35:12.657468
# 			progress = 5000/5048 = 0.9905
# 		image_set = test, finish at = 2023-10-31 13:35:17.092846
# 		time spend = 7.53 mins (452.09 secs), fps = 11.1660 fps
