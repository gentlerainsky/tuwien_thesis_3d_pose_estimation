# %%
from modules.pose_estimator_2d.main import infer_2d_pose_estimation
infer_2d_pose_estimation(
    dataset_root_path='/root/data/processed/drive_and_act',
    config_path='modules/pose_estimator_2d/config/hrnet.py',
    pretrained_path='https://download.openmmlab.com/mmpose/v1' \
        '/body_2d_keypoint/topdown_heatmap/coco'\
            '/td-hm_hrnet-w32_8xb64-210e_coco-256x192-81c58e40_20220909.pth',
    checkpoint_path='https://download.openmmlab.com/mmpose/v1' \
        '/body_2d_keypoint/topdown_heatmap/coco'\
            '/td-hm_hrnet-w32_8xb64-210e_coco-256x192-81c58e40_20220909.pth',
    device='cuda:0',
    working_directory='mmengine_workdir/pose_estimator_2d',
    log_level='CRITICAL'
)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/body_2d_keypoint/topdown_heatmap/coco/td-hm_hrnet-w32_8xb64-210e_coco-256x192-81c58e40_20220909.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: data_preprocessor.mean, data_preprocessor.std
#
# 	image_set = train, start at = 2023-10-18 16:34:49.013526
# 		time = 2023-10-18 16:35:12.039312
# 			progress = 500/7997 = 0.0625
# 		time = 2023-10-18 16:35:34.610034
# 			progress = 1000/7997 = 0.1250
# 		time = 2023-10-18 16:35:57.320628
# 			progress = 1500/7997 = 0.1876
# 		time = 2023-10-18 16:36:20.476321
# 			progress = 2000/7997 = 0.2501
# 		time = 2023-10-18 16:36:43.236500
# 			progress = 2500/7997 = 0.3126
# 		time = 2023-10-18 16:37:06.104540
# 			progress = 3000/7997 = 0.3751
# 		time = 2023-10-18 16:37:28.716193
# 			progress = 3500/7997 = 0.4377
# 		time = 2023-10-18 16:37:52.033014
# 			progress = 4000/7997 = 0.5002
# 		time = 2023-10-18 16:38:14.865595
# 			progress = 4500/7997 = 0.5627
# 		time = 2023-10-18 16:38:37.953160
# 			progress = 5000/7997 = 0.6252
# 		time = 2023-10-18 16:39:01.442686
# 			progress = 5500/7997 = 0.6878
# 		time = 2023-10-18 16:39:23.835893
# 			progress = 6000/7997 = 0.7503
# 		time = 2023-10-18 16:39:46.382562
# 			progress = 6500/7997 = 0.8128
# 		time = 2023-10-18 16:40:08.898109
# 			progress = 7000/7997 = 0.8753
# 		time = 2023-10-18 16:40:31.374062
# 			progress = 7500/7997 = 0.9379
# 		image_set = train, finish at = 2023-10-18 16:40:53.395205
# 		time spend = 6.07 mins (364.38 secs), fps = 21.9303 fps
# created a folder at /root/data/processed/drive_and_act/keypoint_detection_results.
# 	image_set = val, start at = 2023-10-18 16:40:53.706111
# 		time = 2023-10-18 16:41:16.163908
# 			progress = 500/1528 = 0.3272
# 		time = 2023-10-18 16:41:38.815215
# 			progress = 1000/1528 = 0.6545
# 		time = 2023-10-18 16:42:01.502593
# 			progress = 1500/1528 = 0.9817
# 		image_set = val, finish at = 2023-10-18 16:42:02.798063
# 		time spend = 1.15 mins (69.09 secs), fps = 22.1299 fps
# 	image_set = test, start at = 2023-10-18 16:42:02.884426
# 		time = 2023-10-18 16:42:25.458119
# 			progress = 500/2526 = 0.1979
# 		time = 2023-10-18 16:42:48.064879
# 			progress = 1000/2526 = 0.3959
# 		time = 2023-10-18 16:43:10.732669
# 			progress = 1500/2526 = 0.5938
# 		time = 2023-10-18 16:43:33.246299
# 			progress = 2000/2526 = 0.7918
# 		time = 2023-10-18 16:43:56.035627
# 			progress = 2500/2526 = 0.9897
# 		image_set = test, finish at = 2023-10-18 16:43:57.238455
# 		time spend = 1.91 mins (114.35 secs), fps = 22.0980 fps
